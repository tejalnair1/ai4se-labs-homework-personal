# %%
import re
import ast
import math
import json
import random
import pandas as pd
from collections import Counter, defaultdict
from typing import List, Iterable, Tuple, Dict, Optional

# %%
# load data
df = pd.read_csv('methods.csv')

# %%
df
# Out:
#                                                     file  \
# 0      spring-boot/smoke-test/spring-boot-smoke-test-...
# 1      spring-boot/buildpack/spring-boot-buildpack-pl...
# 2      spring-boot/smoke-test/spring-boot-smoke-test-...
# 3      spring-boot/documentation/spring-boot-docs/src...
# 4      spring-boot/module/spring-boot-security/src/ma...
# ...                                                  ...
# 34298  spring-boot/documentation/spring-boot-docs/src...
# 34299  spring-boot/core/spring-boot-autoconfigure/src...
# 34300  spring-boot/module/spring-boot-servlet/src/tes...
# 34301  spring-boot/module/spring-boot-actuator-autoco...
# 34302  spring-boot/loader/spring-boot-loader-classic/...
#
#                                                     name  start_line  \
# 0                                              configure          52
# 1                   loadJsonFromDistributionManifestList          33
# 2                                          testLegacyDot         165
# 3                                                setHost          41
# 4                                          healthMatcher          78
# ...                                                  ...         ...
# 34298                                   setCheckLocation          41
# 34299                                   expressionIsTrue          45
# 34300                                  dispatcherServlet         251
# 34301  runWhenEnabledPropertyIsFalseShouldNotHaveEndp...          60
# 34302                      inputStreamSkipPastSubsection         265
#
#        end_line                                          signature  \
# 0            56  protected SpringApplicationBuilder configure(S...
# 1            40        void loadJsonFromDistributionManifestList()
# 2           172                               void testLegacyDot()
# 3            52                     public void setHost(Host host)
# 4            81   private ServerWebExchangeMatcher healthMatcher()
# ...         ...                                                ...
# 34298        44  public void setCheckLocation(boolean checkLoca...
# 34299        50                            void expressionIsTrue()
# 34300       260              DispatcherServlet dispatcherServlet()
# 34301        65  void runWhenEnabledPropertyIsFalseShouldNotHav...
# 34302       272               void inputStreamSkipPastSubsection()
#
#                                              code_tokens dataset_split
# 0      ["protected", "SpringApplicationBuilder", "con...         train
# 1      ["void", "loadJsonFromDistributionManifestList...         train
# 2               ["void", "testLegacyDot", "(", ")", "{"]         train
# 3      ["public", "void", "setHost", "(", "Host", "ho...         train
# 4      ["private", "ServerWebExchangeMatcher", "healt...         train
# ...                                                  ...           ...
# 34298  ["public", "void", "setCheckLocation", "(", "b...          test
# 34299        ["void", "expressionIsTrue", "(", ")", "{"]          test
# 34300  ["DispatcherServlet", "dispatcherServlet", "("...          test
# 34301  ["void", "runWhenEnabledPropertyIsFalseShouldN...          test
# 34302  ["void", "inputStreamSkipPastSubsection", "(",...          test
#
# [34303 rows x 7 columns]

# %%
def split_train_test(df):
    """
    Split data into two dataframes for strictly train and strictly test. 
    """
    if "dataset_split" in df.columns and df["dataset_split"].notnull().any():
        train_df = df[df["dataset_split"].str.lower() == "train"]
        test_df = df[df["dataset_split"].str.lower() == "test"]
        return train_df, test_df

# %%
train_df, test_df = split_train_test(df)

# %%
train_df
# Out:
#                                                     file  \
# 0      spring-boot/smoke-test/spring-boot-smoke-test-...
# 1      spring-boot/buildpack/spring-boot-buildpack-pl...
# 2      spring-boot/smoke-test/spring-boot-smoke-test-...
# 3      spring-boot/documentation/spring-boot-docs/src...
# 4      spring-boot/module/spring-boot-security/src/ma...
# ...                                                  ...
# 24995  spring-boot/module/spring-boot-micrometer-trac...
# 24996  spring-boot/core/spring-boot/src/test/java/org...
# 24997  spring-boot/module/spring-boot-actuator-autoco...
# 24998  spring-boot/buildpack/spring-boot-buildpack-pl...
# 24999  spring-boot/core/spring-boot/src/test/java/org...
#
#                                                     name  start_line  \
# 0                                              configure          52
# 1                   loadJsonFromDistributionManifestList          33
# 2                                          testLegacyDot         165
# 3                                                setHost          41
# 4                                          healthMatcher          78
# ...                                                  ...         ...
# 24995                             shouldSupplyNoopTracer          42
# 24996            processNoMatchesReturnsNullContribution          61
# 24997  createWhenHasStatusAggregatorBeanReturnsInstan...         115
# 24998                                       decodeBase64          98
# 24999                                         noBrackets          98
#
#        end_line                                          signature  \
# 0            56  protected SpringApplicationBuilder configure(S...
# 1            40        void loadJsonFromDistributionManifestList()
# 2           172                               void testLegacyDot()
# 3            52                     public void setHost(Host host)
# 4            81   private ServerWebExchangeMatcher healthMatcher()
# ...         ...                                                ...
# 24995        50                      void shouldSupplyNoopTracer()
# 24996        65     void processNoMatchesReturnsNullContribution()
# 24997       130  void createWhenHasStatusAggregatorBeanReturnsI...
# 24998       103  private static byte[] decodeBase64(String cont...
# 24999       102  private boolean noBrackets(ConfigurationProper...
#
#                                              code_tokens dataset_split
# 0      ["protected", "SpringApplicationBuilder", "con...         train
# 1      ["void", "loadJsonFromDistributionManifestList...         train
# 2               ["void", "testLegacyDot", "(", ")", "{"]         train
# 3      ["public", "void", "setHost", "(", "Host", "ho...         train
# 4      ["private", "ServerWebExchangeMatcher", "healt...         train
# ...                                                  ...           ...
# 24995  ["void", "shouldSupplyNoopTracer", "(", ")", "{"]         train
# 24996  ["void", "processNoMatchesReturnsNullContribut...         train
# 24997  ["void", "createWhenHasStatusAggregatorBeanRet...         train
# 24998  ["private", "static", "byte", "[", "]", "decod...         train
# 24999  ["private", "boolean", "noBrackets", "(", "Con...         train
#
# [25000 rows x 7 columns]

# %% [markdown]
# Preprocessing helper functions

# %%
JAVA_SINGLE_LINE_COMMENT = re.compile(r"//.*?$", re.MULTILINE)
JAVA_MULTI_LINE_COMMENT  = re.compile(r"/\*.*?\*/", re.DOTALL)
JAVA_STRING_LITERAL      = re.compile(r"\"(?:\\.|[^\"\\])*\"")  # dealing with things in string. match string that starts with double quote, contains any sequence of characters and ends with double quote
JAVA_CHAR_LITERAL        = re.compile(r"'(?:\\.|[^'\\])'")      # dealing with char. match single quote string literals
IMPORT_OR_PACKAGE_LINE   = re.compile(r"^\s*(import|package)\b.*?$", re.MULTILINE) # deal with getting import/package declarations in code

# Token pattern: identifiers, numbers, multi-char ops, and single-char punctuation/operators.
TOKEN_PATTERN = re.compile(
    r"""
    [A-Za-z_][A-Za-z_0-9]*        |  # identifiers/keywords
    \d+\.\d+|\d+                  |  # numbers
    ==|!=|<=|>=|&&|\|\||::|->     |  # multi-char ops
    [{}()\[\].,;:+\-*/%<>!=&|^~?]    # single-char ops/punctuations
    """,
    re.VERBOSE
)
# adding these special tokens
BOS = "<BOS>"
EOS = "<EOS>"

# %%
def clean_java_code(text):
    """
    Remove comments, imports/package, and whitespace. Also format string/char literals to be a placeholder token so that we reduce noise.
    """
    # Remove comments
    text = re.sub(JAVA_MULTI_LINE_COMMENT, " ", text)
    text = re.sub(JAVA_SINGLE_LINE_COMMENT, " ", text)
    # remove import/packages
    text = re.sub(IMPORT_OR_PACKAGE_LINE, " ", text)
    # Replace string and char literals with placeholders
    text = re.sub(JAVA_STRING_LITERAL, "\"<STR>\"", text)
    text = re.sub(JAVA_CHAR_LITERAL, "'<CHR>'", text)
    # remove whitespace
    text = re.sub(r"\s+", " ", text).strip()
    return text

# %%
def tokenize_java(text):
    """
    Tokenize text
    """
    return re.findall(TOKEN_PATTERN, text)

# %%
def parse_tokens_field(val):
    """
    Interpret a 'tokens' cell as either:
    - JSON-like list ('["public","class","Foo"]')
    - Space-separated string ('public class Foo { }')
    """
    if val is None:
        return None
    if isinstance(val, list):
        return [str(t) for t in val] #all strings
    s = str(val).strip() #list of strings
    if not s:
        return None
    # JSON-like list?
    if s.startswith("[") and s.endswith("]"): # check if list
        try:
            arr = ast.literal_eval(s)
            if isinstance(arr, list):
                return [str(t) for t in arr]
        except Exception:
            pass
    #space-separated tokens
    if " " in s or "\t" in s:
        return s.split()
    # single token string if nothing else works
    return [s]

# %%
def extract_token_sequences(df):
    """
    Given a DataFrame row-wise, produce a list of token sequences.
    """
    cols = set(c.lower() for c in df.columns)
    tokenized = []

    tokens_col = None
    for cand in ["code_tokens"]:
        if cand in cols:
            tokens_col = [c for c in df.columns if c.lower() == cand][0]
            break

    if tokens_col:
        for _, row in df.iterrows():
            seq = parse_tokens_field(row[tokens_col])
            if seq:
                tokenized.append([BOS] * 2 + seq + [EOS])  # 2 BOS for >= trigram padding
        return tokenized

# %%
class NgramLM:
    """
    N-gram Language Model with:
      - Count-based
      - Add-k smoothing
    """
    def __init__(self, n = 3, smoothing = "add-k", k = 1.0):
        assert n >= 1
        self.n = n
        self.smoothing = smoothing
        self.k = k

        # Counts
        self.ngram_counts = [Counter() for _ in range(self.n)]  # 1..n
        self.context_counts = [Counter() for _ in range(self.n)]

        # vocal
        self.vocab = set()

    def fit(self, sequences):
        """
        Build n-gram and context counts.
        """
        for seq in sequences:
            self.vocab.update(seq) # add to vocab
            L = len(seq)
            for m in range(1, self.n + 1):
                for i in range(L - m + 1):
                    ngram = tuple(seq[i:i+m])
                    self.ngram_counts[m-1][ngram] += 1
                    context = ngram[:-1]  # empty for unigrams
                    self.context_counts[m-1][context] += 1
    @ property
    def V(self):
        return len(self.vocab)

    def prob(self, context, token):
        """
        P(token | context) using add-k smoothing.
        """
        # Iterate from full-order down to unigrams
        for m in range(self.n, 0, -1):
            ctx = context[-(m-1):] if m > 1 else tuple()
            ngram = ctx + (token,)
            num = self.ngram_counts[m-1][ngram] # numerator
            den = self.context_counts[m-1][ctx] # denominator
            if den > 0 or m == 1:
                if self.smoothing == "add-k":
                    return (num + self.k) / (den + self.k * self.V) # dealing with 0 case
                else:
                    # default to no smoothing
                    if den == 0:
                        # backoff to lower order so continue if doesn't work when context unseen; if we reach m=1, force tiny prob
                        continue
                    return num / den
        # If everything failed, return tiny prob
        return 1.0 / (self.V * 1e3 + 1)

    def next_token_dist(self, context_tokens):
        """
        Return a sorted distribution over next possible tokens for a given context.
        """
        context = tuple(context_tokens[-(self.n-1):]) if self.n > 1 else tuple()
        dist = []
        for tok in self.vocab:
            p = self.prob(context, tok)
            dist.append((tok, p))
        # sort by prob
        dist.sort(key=lambda x: x[1], reverse=True)
        return dist

    def sample(self, seed_tokens, max_len = 50):
        """
        Sample a full sequence continuation example from the model, starting with seed_tokens.
        Stops at EOS or when reached the max_len.
        """
        tokens = seed_tokens[:]
        for _ in range(max_len):
            dist = self.next_token_dist(tokens)
            # draw according to probabilities
            r = random.random()
            cum = 0.0
            for tok, p in dist:
                cum += p
                if r <= cum:
                    tokens.append(tok)
                    break
            if tokens[-1] == EOS:
                break
        return tokens

# %% [markdown]
# perplexity - accuracy evaluation

# %%
def sequence_logprob(model, seq):
    """
    Compute log probability of a single token sequence under the model.
    """
    logp = 0.0
    for i in range(len(seq)):
        context = tuple(seq[max(0, i - (model.n - 1)):i]) if model.n > 1 else tuple()
        tok = seq[i]
        p = model.prob(context, tok)
        # handling too small p
        p = max(p, 1e-12)
        logp += math.log(p)
    return logp


def perplexity(model, sequences):
    """
    Perplexity = exp( - (1/total_tokens) * sum_log_probs )
    """
    total_tokens = 0
    total_logp = 0.0
    for seq in sequences:
        total_logp += sequence_logprob(model, seq)
        total_tokens += len(seq)
    if total_tokens == 0: # handling 0 denom
        return float("inf")
    return math.exp(- total_logp / total_tokens)

# %%
# Build token sequences
train_sequences = extract_token_sequences(train_df)
test_sequences  = extract_token_sequences(test_df)

# %%
train_sequences
# Out:
# [['<BOS>',
#   '<BOS>',
#   'protected',
#   'SpringApplicationBuilder',
#   'configure',
#   '(',
#   'SpringApplicationBuilder',
#   'application',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'loadJsonFromDistributionManifestList',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>', '<BOS>', 'void', 'testLegacyDot', '(', ')', '{', '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'public',
#   'void',
#   'setHost',
#   '(',
#   'Host',
#   'host',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'private',
#   'ServerWebExchangeMatcher',
#   'healthMatcher',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'public',
#   'RepositoryDetectionStrategies',
#   'getDetectionStrategy',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'bootBuildImageWithDockerHostMinikube',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'final',
#   'protected',
#   'ConfigurableApplicationContext',
#   'createContext',
#   '(',
#   'String',
#   'driverClassName',
#   ',',
#   'Class',
#   '<',
#   '?',
#   '>',
#   '.',
#   '.',
#   '.',
#   'classes',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'public',
#   'Collection',
#   '<',
#   'Location',
#   '>',
#   'getTail',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'private',
#   'boolean',
#   'isClassPathUrl',
#   '(',
#   'String',
#   'location',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>', '<BOS>', 'int', 'getCounter', '(', ')', '{', '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'public',
#   'void',
#   'customize',
#   '(',
#   'RestAssuredRestDocumentationConfigurer',
#   'configurer',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'classpathJarsArePackagedBeneathLibPathAndAreStored',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'transactionManagerWithQuartzTransactionManagerUsedWhenMultiplePresent',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'public',
#   'Resource',
#   'getLocation',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'public',
#   'void',
#   'setSecond',
#   '(',
#   'String',
#   'second',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'testCustomizeNettyMaxKeepAliveRequests',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>', '<BOS>', 'void', 'userAgent', '(', ')', '{', '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'putProperty',
#   '(',
#   'LogbackConfigurator',
#   'config',
#   ',',
#   'String',
#   'name',
#   ',',
#   'String',
#   'val',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'private',
#   'Lifecycle',
#   'createLifecycle',
#   '(',
#   'BuildRequest',
#   'request',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'Map',
#   '<',
#   'String',
#   ',',
#   'String',
#   '>',
#   'getMapValue',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'toStringReturnsSensibleString',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>', '<BOS>', 'void', 'hashCodeAndEquals', '(', ')', '{', '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'connectionStringCreateEnvironmentAndCluster',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'testConnectionFactoryWithCustomConnectionNameStrategy',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>', '<BOS>', 'String', 'getPassword', '(', ')', '{', '<EOS>'],
#  ['<BOS>', '<BOS>', 'public', 'String', 'getName', '(', ')', '{', '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'Map',
#   '<',
#   'String',
#   ',',
#   'String',
#   '>',
#   'getValues',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'public',
#   'static',
#   'Object',
#   'from',
#   '(',
#   'BeanFactory',
#   'beanFactory',
#   ',',
#   'String',
#   'beanName',
#   ',',
#   'Class',
#   '<',
#   '?',
#   '>',
#   'beanType',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'matchesWhenContextClassIsExistingBeanShouldProvideBean',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'getWithResourceLoaderAndSpringFactoriesLoaderIncludesProtocolResolvers',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'StandardMongoClientSettingsBuilderCustomizer',
#   'standardMongoSettingsCustomizer',
#   '(',
#   'MongoProperties',
#   'properties',
#   ',',
#   'MongoConnectionDetails',
#   'connectionDetails',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>', '<BOS>', 'void', 'test507Template', '(', ')', '{', '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'singleWebEndpointCanBeExposed',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'public',
#   'int',
#   'getChildClassProperty',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>', '<BOS>', 'void', 'toInstanceWhenNull', '(', ')', '{', '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'attachShouldReattachInMergedSetup',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'getBuildRequestWhenHasImagePlatformUsesImagePlatform',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'runSignedJar',
#   '(',
#   'JavaRuntime',
#   'javaRuntime',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>', '<BOS>', 'void', 'init', '(', ')', '{', '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'getContributorReturnsAdaptedEntry',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'private',
#   'Server',
#   'createCustomizedServer',
#   '(',
#   'Ssl',
#   'ssl',
#   ',',
#   'Http2',
#   'http2',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'determinePortReturnsPortPropertyWhenNoAddresses',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>', '<BOS>', 'void', 'getActiveProfiles', '(', ')', '{', '<EOS>'],
#  ['<BOS>', '<BOS>', 'void', 'fromImageLoadsMetadata', '(', ')', '{', '<EOS>'],
#  ['<BOS>', '<BOS>', 'void', 'init', '(', ')', '{', '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'parseSpecialCharactersTest',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'public',
#   'List',
#   '<',
#   'String',
#   '>',
#   'getBootstrapServers',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'builderPatternWithGenericReturnType',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>', '<BOS>', 'void', 'toLinksShouldMatch', '(', ')', '{', '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'getReferenceDescriptionReturnsLocationString',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>', '<BOS>', 'void', 'allowsMatching', '(', ')', '{', '<EOS>'],
#  ['<BOS>', '<BOS>', 'Object', 'getAgain', '(', ')', '{', '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'ReactiveSessionsEndpoint',
#   'sessionsEndpoint',
#   '(',
#   'ReactiveSessionRepository',
#   '<',
#   '?',
#   '>',
#   'sessionRepository',
#   ',',
#   'ObjectProvider',
#   '<',
#   'ReactiveFindByIndexNameSessionRepository',
#   '<',
#   '?',
#   '>',
#   '>',
#   'indexedSessionRepository',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'public',
#   'void',
#   'setShowComponents',
#   '(',
#   'Show',
#   'showComponents',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'writeTo',
#   '(',
#   'OutputStream',
#   'outputStream',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'TomcatReactiveWebServerFactory',
#   'tomcatReactiveWebServerFactory',
#   '(',
#   'ObjectProvider',
#   '<',
#   'TomcatConnectorCustomizer',
#   '>',
#   'connectorCustomizers',
#   ',',
#   'ObjectProvider',
#   '<',
#   'TomcatContextCustomizer',
#   '>',
#   'contextCustomizers',
#   ',',
#   'ObjectProvider',
#   '<',
#   'TomcatProtocolHandlerCustomizer',
#   '<',
#   '?',
#   '>',
#   '>',
#   'protocolHandlerCustomizers',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'customize',
#   '(',
#   'WebHttpHandlerBuilder',
#   'webHttpHandlerBuilder',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>', '<BOS>', 'void', 'indexOfSeparator', '(', ')', '{', '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'public',
#   'String',
#   'welcome',
#   '(',
#   'Map',
#   '<',
#   'String',
#   ',',
#   'Object',
#   '>',
#   'model',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'testBootstrapper',
#   '(',
#   'CapturedOutput',
#   'output',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'private',
#   'File',
#   'createTestDirectoryStructure',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>', '<BOS>', 'public', 'String', 'secure', '(', ')', '{', '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'setOtherNested',
#   '(',
#   'OtherNested',
#   'otherNested',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'public',
#   'void',
#   'init',
#   '(',
#   'FilterConfig',
#   'filterConfig',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'getConfigurationPropertyShouldGetFromMemory',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'getWhenHasServiceHostEnv',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'applyWhenWithArgsUpdatesConfigurationWithArguments',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>', '<BOS>', 'TestServlet', 'testServlet', '(', ')', '{', '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'cachingConnectionFactoryNotOnTheClasspathAndCacheEnabledThenSimpleConnectionFactoryNotConfigured',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'whenTheUserDefinesAJobNameThatDoesNotExistWithJobInstancesFailsFast',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>', '<BOS>', 'void', 'buildInfoExcludeTime', '(', ')', '{', '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'nullSafeValueWhenClassIsBooleanShouldReturnBoolean',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'public',
#   'void',
#   'setName',
#   '(',
#   'String',
#   'name',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'public',
#   'int',
#   'optInt',
#   '(',
#   'int',
#   'index',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>', '<BOS>', 'public', 'boolean', 'isTrace', '(', ')', '{', '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'protected',
#   'ReactiveWebApplicationContextRunner',
#   'createContextRunner',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'abstract',
#   'public',
#   'ConfigurableFileCollection',
#   'getCompileClasspath',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'tomcatRedirectContextRootMatchesDefault',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'RestDocsWebTestClientConfigurationCustomizer',
#   'defaultSnippetsCustomizer',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>', '<BOS>', 'ExistingBean', 'getBean', '(', ')', '{', '<EOS>'],
#  ['<BOS>', '<BOS>', 'public', 'String', 'toString', '(', ')', '{', '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'public',
#   'void',
#   'registerBeanDefinitions',
#   '(',
#   'AnnotationMetadata',
#   'importingClassMetadata',
#   ',',
#   'BeanDefinitionRegistry',
#   'registry',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>', '<BOS>', 'void', 'testRepository', '(', ')', '{', '<EOS>'],
#  ['<BOS>', '<BOS>', 'void', 'disallowsWrongHeader', '(', ')', '{', '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'getResultWhenAlwaysShowIsFalseAndGroupIsTrueShowsComponents',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>', '<BOS>', 'void', 'shouldSupportPageable', '(', ')', '{', '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'whenArchiveIsLayeredThenLayerToolsAreAddedToTheJar',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'protected',
#   'String',
#   'getName',
#   '(',
#   'Entry',
#   'entry',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>', '<BOS>', 'void', 'info', '(', ')', '{', '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'public',
#   'V',
#   'getFileStoreAttributeView',
#   '(',
#   'Class',
#   '<',
#   'V',
#   '>',
#   'type',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>', '<BOS>', 'public', 'int', 'getMaxUriTags', '(', ')', '{', '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'boolean',
#   '[',
#   ']',
#   'match',
#   '(',
#   'String',
#   '[',
#   ']',
#   'autoConfigurationClasses',
#   ',',
#   'AutoConfigurationMetadata',
#   'autoConfigurationMetadata',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'public',
#   'void',
#   'afterPropertiesSet',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'public',
#   'void',
#   'setStartupDelay',
#   '(',
#   'Duration',
#   'startupDelay',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'iteratorWithProfileGroupsForDefault',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'private',
#   'void',
#   'setupSourceAnnotatedWithName',
#   '(',
#   'String',
#   'name',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'runWhenSpringIntegrationIsNotEnabledShouldNotHaveEndpointBean',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>', '<BOS>', 'public', 'String', 'getDetails', '(', ')', '{', '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'quartzTriggerDetailWithUnknownKey',
#   '(',
#   'WebTestClient',
#   'client',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>', '<BOS>', 'public', 'String', 'getNetwork', '(', ')', '{', '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'public',
#   'InputStream',
#   'getContent',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'private',
#   'TypeExcludeFilter',
#   'instantiateTypeExcludeFilter',
#   '(',
#   'Class',
#   '<',
#   '?',
#   '>',
#   'testClass',
#   ',',
#   'Class',
#   '<',
#   '?',
#   '>',
#   'filterClass',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'generatedBuildInfoUsesCustomBuildTime',
#   '(',
#   'MavenBuild',
#   'mavenBuild',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'public',
#   'String',
#   'VehicleDetailsHtml',
#   '(',
#   'String',
#   'username',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'private',
#   'void',
#   'runShutdownHandlers',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'public',
#   'void',
#   'setAge',
#   '(',
#   'int',
#   'age',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'private',
#   'static',
#   'List',
#   '<',
#   'BuildpackResolver',
#   '>',
#   'getResolvers',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'convertWhenSimpleWithoutSuffixShouldReturnPeriod',
#   '(',
#   'ConversionService',
#   'conversionService',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'public',
#   'void',
#   'setResourceLabels',
#   '(',
#   'Map',
#   '<',
#   'String',
#   ',',
#   'String',
#   '>',
#   'resourceLabels',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>', '<BOS>', 'public', 'String', 'getPassword', '(', ')', '{', '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'accessCanBeNoneByDefault',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'private',
#   'boolean',
#   'isMatch',
#   '(',
#   'String',
#   'principal',
#   ',',
#   'Instant',
#   'after',
#   ',',
#   'String',
#   'type',
#   ',',
#   'AuditEvent',
#   'event',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'posixPermissionsToUmaskWithNullPermissions',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'toEndpointClassShouldNotMatchOtherPath',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'static',
#   'void',
#   'containerProperties',
#   '(',
#   'DynamicPropertyRegistry',
#   'registry',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'private',
#   'void',
#   'applyKafkaConnectionDetailsForProducer',
#   '(',
#   'Map',
#   '<',
#   'String',
#   ',',
#   'Object',
#   '>',
#   'properties',
#   ',',
#   'KafkaConnectionDetails',
#   'connectionDetails',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'mapWhenConfigurationConverterIsNotQualifiedShouldNotConvert',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'public',
#   'void',
#   'setMinSpare',
#   '(',
#   'int',
#   'minSpare',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'ofWhenFileIsNotFileThrowsException',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'ofWithNullSetCreatesSslOptions',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>', '<BOS>', 'void', 'resolveNonExistent', '(', ')', '{', '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'getResponseHeadersIncludedReturnsHeaders',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'optionsWithReturnsNewOptions',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'setUsernamePasswordUrlAndDriverClassName',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'public',
#   'static',
#   'VolumeName',
#   'basedOn',
#   '(',
#   'S',
#   'source',
#   ',',
#   'Function',
#   '<',
#   'S',
#   ',',
#   'String',
#   '>',
#   'nameExtractor',
#   ',',
#   'String',
#   'prefix',
#   ',',
#   'String',
#   'suffix',
#   ',',
#   'int',
#   'digestLength',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'environmentWithNewProfile',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>', '<BOS>', 'public', 'int', 'available', '(', ')', '{', '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'private',
#   'Properties',
#   'buildLaunchScriptProperties',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'public',
#   'String',
#   'getFirstName',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>', '<BOS>', 'public', 'boolean', 'isEnabled', '(', ')', '{', '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'loadWhenSignatureDoesNotMatchThrowsException',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'private',
#   'RedisCache',
#   'getTestCache',
#   '(',
#   'AssertableApplicationContext',
#   'context',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'public',
#   'Trigger',
#   'everyDayTrigger',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'getPasswordWhenHasMariadbPasswordAndMysqlPassword',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>', '<BOS>', 'void', 'createFromBytes', '(', ')', '{', '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'isActiveWhenActivateIsNull',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'public',
#   'void',
#   'setResourceType',
#   '(',
#   'String',
#   'resourceType',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'jndiSessionIgnoredIfJndiNameNotSet',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'defaultValueShouldBeConsistent',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'getParametersShouldReturnParameters',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'DatabaseSelectionProvider',
#   'databaseSelectionProvider',
#   '(',
#   'DataNeo4jProperties',
#   'properties',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'getConfigEnvContainsParsedValues',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>', '<BOS>', 'int', 'getExitCode', '(', ')', '{', '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'public',
#   'void',
#   'setName',
#   '(',
#   'String',
#   'name',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'String',
#   'home',
#   '(',
#   'Model',
#   'model',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'abstract',
#   'public',
#   'Property',
#   '<',
#   'String',
#   '>',
#   'getName',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'default',
#   'Constructor',
#   '<',
#   '?',
#   '>',
#   'getBindConstructor',
#   '(',
#   'Class',
#   '<',
#   '?',
#   '>',
#   'type',
#   ',',
#   'boolean',
#   'isNestedConstructorBinding',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'private',
#   'void',
#   'controllerPointCut',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'public',
#   'FileCollection',
#   'getOptionalDependencies',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'subPathWithALeadingSlashIsSeparatedFromBasePathBySingleSlash',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'MapSessionRepository',
#   'mySessionRepository',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'public',
#   'void',
#   'updateBundle',
#   '(',
#   'String',
#   'name',
#   ',',
#   'SslBundle',
#   'updatedBundle',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'GitHubRepository',
#   'getRepository',
#   '(',
#   'String',
#   'organization',
#   ',',
#   'String',
#   'name',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'detectAndParseWhenSimpleMinutesShouldReturnDuration',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'pidFilenameCanBeReplaced',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'public',
#   'Map',
#   '<',
#   'String',
#   ',',
#   'Configuration',
#   '<',
#   '?',
#   ',',
#   '?',
#   '>',
#   '>',
#   'getConfigurations',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'public',
#   'Set',
#   '<',
#   'Session',
#   '>',
#   'getTrackingModes',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>', '<BOS>', 'public', 'String', 'apiToken', '(', ')', '{', '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'protected',
#   'String',
#   'getConfigFileName',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'private',
#   'void',
#   'registerReflectionHints',
#   '(',
#   'ReflectionHints',
#   'hints',
#   ',',
#   'Class',
#   '<',
#   'ClientHttpRequestFactory',
#   '>',
#   'requestFactoryType',
#   ',',
#   'Class',
#   '<',
#   '?',
#   '>',
#   'readTimeoutType',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'private',
#   'void',
#   'writeMainClass',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'fromMapWithAdapterReturnsCompositeHealthContributorMapAdapter',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>', '<BOS>', 'public', 'String', 'getJdbcUrl', '(', ')', '{', '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'public',
#   'static',
#   'void',
#   'main',
#   '(',
#   'String',
#   '[',
#   ']',
#   'args',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'runDueToExitDuringRefreshWhenContextHasBeenClosedDoesNotDeadlock',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'isEqualToWhenFileIsNotMatchingShouldFail',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'private',
#   'List',
#   '<',
#   'File',
#   '>',
#   'getCompileScopeJars',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'public',
#   'Step',
#   'getStep',
#   '(',
#   'String',
#   'stepName',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'doesNotInitializeSameContextMoreThanOnce',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'failFastWithVersionOfGradle8LowerThanRequired',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'shouldNotFailIfDirectoryIsNotEmptyButForceIsPassed',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'public',
#   'BuildRequest',
#   'withBuildWorkspace',
#   '(',
#   'Cache',
#   'buildWorkspace',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>', '<BOS>', 'void', 'setup', '(', ')', '{', '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'smtpOnDefaultHostAndPortIsUp',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'protected',
#   'void',
#   'doFilterInternal',
#   '(',
#   'HttpServletRequest',
#   'request',
#   ',',
#   'HttpServletResponse',
#   'response',
#   ',',
#   'FilterChain',
#   'filterChain',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'executeWithSecurityOptionsExecutesPhases',
#   '(',
#   'boolean',
#   'trustBuilder',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'public',
#   'JdkClientHttpConnectorBuilder',
#   'withCustomizers',
#   '(',
#   'Collection',
#   '<',
#   'Consumer',
#   '<',
#   'JdkClientHttpConnector',
#   '>',
#   '>',
#   'customizers',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'WebFilterChainProxy',
#   'webFilterChainProxy',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>', '<BOS>', 'void', 'environmentForWeb', '(', ')', '{', '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'getPasswordWhenHasSaPassword',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'isEqualToWhenResourceIsNotMatchingShouldFail',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'public',
#   'List',
#   '<',
#   'Tag',
#   '>',
#   'findAll',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'private',
#   'static',
#   'ClassLoader',
#   'decideClassloader',
#   '(',
#   'ClassLoader',
#   'classLoader',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>', '<BOS>', 'void', 'close', '(', ')', '{', '<EOS>'],
#  ['<BOS>', '<BOS>', 'void', 'jarIsOnlyRepackagedOnce', '(', ')', '{', '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'static',
#   'void',
#   'main',
#   '(',
#   'String',
#   '[',
#   ']',
#   'args',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>', '<BOS>', 'void', 'setUp', '(', ')', '{', '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'public',
#   'void',
#   'setUserInfoAuthenticationMethod',
#   '(',
#   'String',
#   'userInfoAuthenticationMethod',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'public',
#   'boolean',
#   'equals',
#   '(',
#   'Object',
#   'obj',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'createWhenParameterValueMapperIsNullShouldThrowException',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'public',
#   'Map',
#   '<',
#   'String',
#   ',',
#   'Registration',
#   '>',
#   'getRegistration',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>', '<BOS>', 'void', 'multiplePatterns', '(', ')', '{', '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'final',
#   'protected',
#   'T',
#   'tryParse',
#   '(',
#   'Callable',
#   '<',
#   'T',
#   '>',
#   'parser',
#   ',',
#   'Class',
#   '<',
#   'Exception',
#   '>',
#   'check',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'protected',
#   'Class',
#   '<',
#   '?',
#   '>',
#   'getConfiguration',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'private',
#   'Set',
#   '<',
#   'BinderOption',
#   '>',
#   'asBinderOptionsSet',
#   '(',
#   'BinderOption',
#   '.',
#   '.',
#   '.',
#   'options',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'public',
#   'void',
#   'setClasspath',
#   '(',
#   'Configuration',
#   'classpath',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>', '<BOS>', 'void', 'error', '(', ')', '{', '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'shouldProvideManagedTypes',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'liquibaseAutoConfigurationWasImported',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'ofSha256DigestWhenWrongLengthThrowsException',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'bindToMapWithWildcardShouldConvertToTheRightType',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>', '<BOS>', 'MimeType', 'getMediaType', '(', ')', '{', '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'includeJarWithStaticResourcesWithUrlEncodedSpaces',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'whenHasUserDefinedHttpServiceGroupConfigurer',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'private',
#   'Stream',
#   '<',
#   'DispatcherHandlerMappingDescription',
#   '>',
#   'describe',
#   '(',
#   'T',
#   'handlerMapping',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'private',
#   'Object',
#   'getFieldValue',
#   '(',
#   'Field',
#   'field',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'public',
#   'ConditionOutcome',
#   'getExposureOutcome',
#   '(',
#   'EndpointId',
#   'endpointId',
#   ',',
#   'Set',
#   '<',
#   'EndpointExposure',
#   '>',
#   'exposures',
#   ',',
#   'Builder',
#   'message',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>', '<BOS>', 'void', 'sendBadData', '(', ')', '{', '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'FreeMarkerConfigurer',
#   'freeMarkerConfigurer',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'shouldRegisterPropertyNamingStrategyHints',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'getPropertyOriginWhenMissingShouldReturnNull',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'public',
#   'BindableAssert',
#   'assertThat',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'private',
#   'record',
#   'CertificatesHolder',
#   '(',
#   'List',
#   '<',
#   'X509Certificate',
#   '>',
#   'certificates',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'private',
#   'void',
#   'tarGzipBuildpackContent',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'public',
#   'ObjectContent',
#   '<',
#   'T',
#   '>',
#   'read',
#   '(',
#   'Reader',
#   'reader',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'public',
#   'Duration',
#   'getAnalytics',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'started',
#   '(',
#   'ConfigurableApplicationContext',
#   'context',
#   ',',
#   'Duration',
#   'timeTaken',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'whenProjectVersionIsSnapshotThenTypeIsSnapshot',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'createWhenJsonIsNullShouldThrowException',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>', '<BOS>', 'public', 'Request', 'getRequest', '(', ')', '{', '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'availabilityOfTemplateWithCustomLoaderPathConfiguredAsAList',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'private',
#   'boolean',
#   'getMandatory',
#   '(',
#   'RabbitTemplate',
#   'rabbitTemplate',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'whenHalIsNotTheDefaultJsonMediaTypeThenMappingJacksonConverterCannotWriteHateoasTypeAsApplicationJson',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'public',
#   'void',
#   'setAutoStartup',
#   '(',
#   'boolean',
#   'autoStartup',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'getServerWhenNoServersAreBoundShouldThrowException',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'protected',
#   'void',
#   'mockSuccessfulMetadataTextGet',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'private',
#   'ExecutableElement',
#   'getMatchingAccessor',
#   '(',
#   'List',
#   '<',
#   'ExecutableElement',
#   '>',
#   'candidates',
#   ',',
#   'TypeMirror',
#   'type',
#   ',',
#   'Function',
#   '<',
#   'ExecutableElement',
#   ',',
#   'TypeMirror',
#   '>',
#   'typeExtractor',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>', '<BOS>', 'public', 'Host', 'getHost', '(', ')', '{', '<EOS>'],
#  ['<BOS>', '<BOS>', 'boolean', 'hasEmptyAuth', '(', ')', '{', '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'public',
#   'void',
#   'setJwsAlgorithms',
#   '(',
#   'List',
#   '<',
#   'String',
#   '>',
#   'jwsAlgorithms',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'hasSingleBeanWhenFailedToStartShouldFail',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'public',
#   'byte',
#   '[',
#   ']',
#   'toByteArray',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'shouldProvideReactiveNeo4jClientWithCustomDatabaseSelectionProvider',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'doWithDirectoryMainMethods',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>', '<BOS>', 'public', 'String', 'getName', '(', ')', '{', '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'private',
#   'static',
#   'KeyPair',
#   'generateRsaKey',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'public',
#   'void',
#   'setLocale',
#   '(',
#   'String',
#   'locale',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'outcomeWhenIncludeAllWebShouldMatchEnabledEndpoints',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'public',
#   'void',
#   'restart',
#   '(',
#   'FailureHandler',
#   'failureHandler',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>', '<BOS>', 'Propagator', 'propagator', '(', ')', '{', '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'RSocketWebSocketNettyRouteProvider',
#   'rSocketWebsocketRouteProvider',
#   '(',
#   'RSocketProperties',
#   'properties',
#   ',',
#   'RSocketMessageHandler',
#   'messageHandler',
#   ',',
#   'ObjectProvider',
#   '<',
#   'RSocketServerCustomizer',
#   '>',
#   'customizers',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'GraphQlRSocketController',
#   'graphQlRSocketController',
#   '(',
#   'GraphQlRSocketHandler',
#   'handler',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'getMatchOutcomeHasWhenPropertyIsNotSetHasDefaultDescription',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'customizeContainerProperties',
#   '(',
#   'ReactivePulsarContainerProperties',
#   '<',
#   'T',
#   '>',
#   'containerProperties',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>', '<BOS>', 'void', 'defaultServiceBacksOff', '(', ')', '{', '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'static',
#   'String',
#   'resolvePlaceholders',
#   '(',
#   'Properties',
#   'properties',
#   ',',
#   'String',
#   'text',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'redisSessionStoreWithCustomizations',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'private',
#   'static',
#   'String',
#   'buildMessage',
#   '(',
#   'Duration',
#   'timeout',
#   ',',
#   'List',
#   '<',
#   'ServiceNotReadyException',
#   '>',
#   'exceptions',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>', '<BOS>', 'Foo', 'foo', '(', ')', '{', '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'private',
#   'void',
#   'assertInvalid',
#   '(',
#   'String',
#   'value',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'shouldNotPrint',
#   '(',
#   'CapturedOutput',
#   'output',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'public',
#   'ChronoUnit',
#   'getSeconds',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'createWhenSourceDoesNotExistThrowsException',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'public',
#   'static',
#   'void',
#   'main',
#   '(',
#   'String',
#   '[',
#   ']',
#   'args',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'getWithResourceLoaderDelegatesLoading',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'shouldAutoConfigureCountedMeterTagAnnotationHandlerWhenValueExpressionResolverIsAvailable',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'private',
#   'boolean',
#   'nonLoaderResource',
#   '(',
#   'Resource',
#   'resource',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'getVehicleWhenRequestingJsonShouldReturnMakeAndModel',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'R',
#   'testNullSafeValue',
#   '(',
#   'JsonNode',
#   'jsonNode',
#   ',',
#   'Class',
#   '<',
#   'D',
#   '>',
#   'type',
#   ',',
#   'Function',
#   '<',
#   'D',
#   ',',
#   'R',
#   '>',
#   'mapper',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'public',
#   'void',
#   'processLoadFailure',
#   '(',
#   'ApplicationContext',
#   'context',
#   ',',
#   'Throwable',
#   'exception',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>', '<BOS>', 'DataAttributeDialect', 'dialect', '(', ')', '{', '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'userDefinedMappingsSecure',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'healthWithOneUnknownNodeShouldReturnDown',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'public',
#   'boolean',
#   'matches',
#   '(',
#   'TypeDescriptor',
#   'sourceType',
#   ',',
#   'TypeDescriptor',
#   'targetType',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'shouldCustomizeHttpTransportWithOtlpHttpSpanExporterBuilderCustomizer',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'jmxEndpointWithContextHierarchyGeneratesUniqueNamesForEachEndpoint',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'runWhenNoOtherIndicatorsCreatesPingHealthIndicator',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'public',
#   'Map',
#   '<',
#   'String',
#   ',',
#   'Object',
#   '>',
#   'getFieldValues',
#   '(',
#   'TypeElement',
#   'element',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'fromTomlWhenContainsBothStacksAndOrderThrowsException',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>', '<BOS>', 'void', 'setup', '(', ')', '{', '<EOS>'],
#  ['<BOS>', '<BOS>', 'void', 'setTrustedPackages', '(', ')', '{', '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'protected',
#   'MongoClient',
#   'createMongoClient',
#   '(',
#   'List',
#   '<',
#   'MongoClientSettingsBuilderCustomizer',
#   '>',
#   'customizers',
#   ',',
#   'MongoClientSettings',
#   'settings',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'pushWhenReferenceIsNullThrowsException',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'shouldHaveImportedValues',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'SpringLiquibase',
#   'springLiquibase',
#   '(',
#   'DataSource',
#   'dataSource',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'withLoadOnStartupNotSetShouldReturnDefaultValue',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'public',
#   'String',
#   'ServiceUnavailable',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'applyingApplicationPluginCreatesBootStartScriptsTask',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'private',
#   'HandlerMethod',
#   'handlerOf',
#   '(',
#   'Object',
#   'source',
#   ',',
#   'String',
#   'methodName',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>', '<BOS>', 'void', 'findAllCustomers', '(', ')', '{', '<EOS>'],
#  ['<BOS>', '<BOS>', 'void', 'testDatabaseClient', '(', ')', '{', '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'public',
#   'boolean',
#   'matches',
#   '(',
#   'ApplicationContext',
#   'context',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'replacedPropertySourceShouldBeOriginAware',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'callbacksInvokeAndWhenHasResolvableGenericMatchShouldReturnResult',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'public',
#   'String',
#   'getJwkSetUri',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'bindToMapWhenMapValueIsObjectAndNoRootShouldBindNestedMapValue',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'tryEnvironmentPreparedEvent',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'whenContextIsClosedThenWebServerIsStoppedAndDestroyed',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>', '<BOS>', 'void', 'after', '(', ')', '{', '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'public',
#   'void',
#   'setLoadTimeWeaver',
#   '(',
#   'LoadTimeWeaver',
#   'loadTimeWeaver',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'RSocketMessageHandler',
#   'customMessageHandler',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'tomcatProcessorCacheMatchesProtocolDefault',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'runWhenHasStatusAggregatorBeanIgnoresProperties',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'protected',
#   'File',
#   'jarFile',
#   '(',
#   'String',
#   'name',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'instantiateWhenMultipleConstructorPicksMostArguments',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'public',
#   'MetadataHintCondition',
#   'withProvider',
#   '(',
#   'String',
#   'provider',
#   ',',
#   'String',
#   'key',
#   ',',
#   'Object',
#   'value',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'private',
#   'DockerRegistryAuthentication',
#   'getRegistryAuthentication',
#   '(',
#   'String',
#   'type',
#   ',',
#   'DockerRegistry',
#   'registry',
#   ',',
#   'DockerRegistryAuthentication',
#   'fallback',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'public',
#   'static',
#   'String',
#   'getProperty',
#   '(',
#   'String',
#   'key',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'generateProjectAndExtractWithConvention',
#   '(',
#   'File',
#   'tempDir',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'createFromBeanHasDetails',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'private',
#   'URL',
#   'findDefaultScript',
#   '(',
#   'ExtensionContext',
#   'context',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'private',
#   'void',
#   'disableIncrementalCompilation',
#   '(',
#   'Project',
#   'project',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'getAggregateStatusWhenHasCustomStatusAndUsingCustomOrder',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'createWhenHasExceptionShouldSetFailure',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'whenTheAutoConfigurationIsUsedThenBeanDefinitionPlaceholdersAreResolved',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'private',
#   'static',
#   'ClassLoader',
#   'decideClassloader',
#   '(',
#   'ClassLoader',
#   'classLoader',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'private',
#   'T',
#   'doWithRetry',
#   '(',
#   'Callable',
#   '<',
#   'T',
#   '>',
#   'action',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'public',
#   'Message',
#   'findMessage',
#   '(',
#   'Long',
#   'id',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>', '<BOS>', 'void', 'listOfMaps', '(', ')', '{', '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'private',
#   'String',
#   'urlFor',
#   '(',
#   'RunningService',
#   'service',
#   ',',
#   'String',
#   'database',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'String',
#   'read',
#   '(',
#   'String',
#   'principal',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'private',
#   'void',
#   'collectAnnotations',
#   '(',
#   'Class',
#   '<',
#   '?',
#   '>',
#   'source',
#   ',',
#   'MultiValueMap',
#   '<',
#   'Class',
#   '<',
#   '?',
#   '>',
#   ',',
#   'Annotation',
#   '>',
#   'annotations',
#   ',',
#   'HashSet',
#   '<',
#   'Class',
#   '<',
#   '?',
#   '>',
#   '>',
#   'seen',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'public',
#   'boolean',
#   'equals',
#   '(',
#   'Object',
#   'obj',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'private',
#   'String',
#   'mavenRepositoryXml',
#   '(',
#   'String',
#   'indent',
#   ',',
#   'MavenArtifactRepository',
#   'repository',
#   ',',
#   'boolean',
#   'pluginRepository',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'testLogger',
#   '(',
#   'CapturedOutput',
#   'output',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'private',
#   'ArtifactVersionDependencyVersion',
#   'version',
#   '(',
#   'String',
#   'version',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'adaptWhenHealthIndicatorReturnsHealthIndicatorReactiveAdapter',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'public',
#   'void',
#   'setCredentials',
#   '(',
#   'List',
#   '<',
#   'Credential',
#   '>',
#   'credentials',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'public',
#   'OperationParameter',
#   'get',
#   '(',
#   'int',
#   'index',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'private',
#   'void',
#   'writeString',
#   '(',
#   'File',
#   'file',
#   ',',
#   'String',
#   'content',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'private',
#   'void',
#   'doDataSourceHealthCheck',
#   '(',
#   'Health',
#   'builder',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>', '<BOS>', 'int', 'getNumberOfRecords', '(', ')', '{', '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'getPropertySourceShouldReturnPropertySource',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>', '<BOS>', 'void', 'health', '(', ')', '{', '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'bindToInstanceWithNoPropertiesShouldReturnUnbound',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'shouldTriggerOnConfigMapAtomicMoveUpdates',
#   '(',
#   'Path',
#   'tempDir',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>', '<BOS>', 'void', 'rSocketEndpoint', '(', ')', '{', '<EOS>'],
#  ['<BOS>', '<BOS>', 'long', 'getSize', '(', ')', '{', '<EOS>'],
#  ['<BOS>', '<BOS>', 'Clock', 'clock', '(', ')', '{', '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'abstract',
#   'public',
#   'DirectoryProperty',
#   'getOutputDir',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'public',
#   'Object',
#   'mapParameterValue',
#   '(',
#   'OperationParameter',
#   'parameter',
#   ',',
#   'Object',
#   'value',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>', '<BOS>', 'public', 'String', 'toString', '(', ')', '{', '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'allDefaultMethodsAreImplemented',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'lengthReturnsCapturedLength',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'public',
#   'String',
#   'getDisplayName',
#   '(',
#   'int',
#   'invocationIndex',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>', '<BOS>', 'void', 'testEntityManager', '(', ')', '{', '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'DefaultSchemaResolver',
#   'pulsarSchemaResolver',
#   '(',
#   'ObjectProvider',
#   '<',
#   'SchemaResolverCustomizer',
#   '<',
#   '?',
#   '>',
#   '>',
#   'schemaResolverCustomizers',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'public',
#   'void',
#   'customize',
#   '(',
#   'Members',
#   '<',
#   'Object',
#   '>',
#   'members',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>', '<BOS>', 'void', 'withStackTrace', '(', ')', '{', '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'toDashedCaseConvertsValue',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>', '<BOS>', 'public', 'int', 'getOrder', '(', ')', '{', '<EOS>'],
#  ['<BOS>', '<BOS>', 'public', 'Client', 'getClient', '(', ')', '{', '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'getExoticTypeOnDefaultMimeMappingsLoadsMappings',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'PropertySource',
#   '<',
#   '?',
#   '>',
#   'getPropertySource',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'setEnvironment',
#   '(',
#   'Environment',
#   'environment',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'singleManuallyConfiguredConnectionFactoryIsNotClosed',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'private',
#   'ResponseFieldsSnippet',
#   'processInfo',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'private',
#   'File',
#   'makeJarFileWithUrlsInManifestClassPath',
#   '(',
#   'Object',
#   '.',
#   '.',
#   '.',
#   'urls',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'shouldSupplyRestClientBuilderConfigurerWithCustomSettings',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>', '<BOS>', 'void', 'camelCaseEndpoint', '(', ')', '{', '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'public',
#   'void',
#   'apply',
#   '(',
#   'IOConsumer',
#   '<',
#   'Layer',
#   '>',
#   'layers',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'private',
#   'String',
#   'readResources',
#   '(',
#   'Resource',
#   '[',
#   ']',
#   'resources',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'public',
#   'boolean',
#   'equals',
#   '(',
#   'Object',
#   'obj',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>', '<BOS>', 'void', 'loadMetadataBadRequest', '(', ')', '{', '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'RestClient',
#   'restClient',
#   '(',
#   'Builder',
#   'restClientBuilder',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'namedCacheWithSeveralCacheManagersWithCacheManagerFilter',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'protected',
#   'void',
#   'closeBeanFactory',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'unknownOptionShowsErrorAndCommandHelp',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'private',
#   'DirectRabbitListenerContainerFactoryConfigurer',
#   'directListenerConfigurer',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'private',
#   'String',
#   'buildAdditionalHints',
#   '(',
#   'ItemHint',
#   '.',
#   '.',
#   '.',
#   'hints',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>', '<BOS>', 'void', 'save', '(', ')', '{', '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'callbacksInvokeWhenMultipleShouldInvokeSuitable',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'ObservabilitySchedulingConfigurer',
#   'observabilitySchedulingConfigurer',
#   '(',
#   'ObservationRegistry',
#   'observationRegistry',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'quartzTriggerWithCronTrigger',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'public',
#   'Propagation',
#   'getPropagation',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'orderOfUnderlyingSourceIsPreserved',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'private',
#   'static',
#   'List',
#   '<',
#   'ManifestList',
#   '>',
#   'getManifestLists',
#   '(',
#   'Path',
#   'tarFile',
#   ',',
#   'Set',
#   '<',
#   'String',
#   '>',
#   'digests',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'public',
#   'Duration',
#   'getDuration',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'public',
#   'AcknowledgeMode',
#   'getAcknowledgeMode',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'getResourceReturnsResource',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'String',
#   'getJson',
#   '(',
#   'InputStream',
#   'source',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'shouldIncludePathByDefault',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'doesNotHaveJsonPathForMissing',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>', '<BOS>', 'void', 'shouldFormat', '(', ')', '{', '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'getNameWhenFromLogLevelReturnsName',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'thrownRuleWorksWithCheckedException',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>', '<BOS>', 'Validator', 'customValidator', '(', ')', '{', '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'bindWhenNoSchemaThrowsException',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>', '<BOS>', 'void', 'configureShouldApply', '(', ')', '{', '<EOS>'],
#  ['<BOS>', '<BOS>', 'File', 'getAppDirectory', '(', ')', '{', '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'public',
#   'void',
#   'setRefid',
#   '(',
#   'String',
#   'refid',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>', '<BOS>', 'public', 'int', 'length', '(', ')', '{', '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'public',
#   'String',
#   'getCurrentSpanId',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'public',
#   'void',
#   'setMyURL',
#   '(',
#   'String',
#   'myURL',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'ofWhenStartsWithUppercaseLetterThrowsException',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'private',
#   'void',
#   'addToZipContentsCollectorDependencies',
#   '(',
#   'GenerateAntoraPlaybook',
#   'task',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'public',
#   'Map',
#   '<',
#   'String',
#   ',',
#   'String',
#   '>',
#   'getProperties',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'public',
#   'ImageReference',
#   'getTag',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'public',
#   'boolean',
#   'supports',
#   '(',
#   'ConnectionFactoryOptions',
#   'connectionFactoryOptions',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'propertyMappingShouldNotBeUsedWithComponent',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
# ...
#   '<BOS>',
#   'brave',
#   'braveTracer',
#   '(',
#   'Tracing',
#   'tracing',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'private',
#   'static',
#   'SslStoreBundle',
#   'createPemKeyStoreBundle',
#   '(',
#   'Ssl',
#   'ssl',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>', '<BOS>', 'void', 'addContent', '(', ')', '{', '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'getBindsFromEnvironmentWhenHostIsPresentAndServiceIsMissingUsesApplicationVersion',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>', '<BOS>', 'String', 'home', '(', ')', '{', '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'createAuthHeaderReturnsEncodedHeader',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'public',
#   'static',
#   'void',
#   'main',
#   '(',
#   'String',
#   '[',
#   ']',
#   'args',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'TomcatReactiveWebServerFactory',
#   'webServerFactory',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'accessCanBeReadOnlyByDefault',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>', '<BOS>', 'void', 'removeRemovesContainer', '(', ')', '{', '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'convertFromStringToCharArrayShouldConvert',
#   '(',
#   'ConversionService',
#   'conversionService',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'public',
#   'void',
#   'setFieldNamingPolicy',
#   '(',
#   'FieldNamingPolicy',
#   'fieldNamingPolicy',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'getOsWhenOsIsNotDefaultOsReturnsOs',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'static',
#   'SecurityInfo',
#   'get',
#   '(',
#   'ZipContent',
#   'content',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'private',
#   'BuilderDockerConfiguration',
#   'customizeHost',
#   '(',
#   'BuilderDockerConfiguration',
#   'dockerConfiguration',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>', '<BOS>', 'public', 'Foo', 'foo', '(', ')', '{', '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'containsPropertyWhenEnvironmentIsNullReturnsFalse',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'info',
#   '(',
#   'WebTestClient',
#   'client',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'public',
#   'void',
#   'setMap',
#   '(',
#   'String',
#   'map',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>', '<BOS>', 'void', 'teardown', '(', ')', '{', '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'public',
#   'Map',
#   '<',
#   'String',
#   ',',
#   'String',
#   '>',
#   'getTags',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>', '<BOS>', 'void', 'start', '(', ')', '{', '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'public',
#   'static',
#   'void',
#   'main',
#   '(',
#   'String',
#   '[',
#   ']',
#   'args',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'StatusAggregator',
#   'statusAggregator',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'EmbeddedDatabaseConnection',
#   'getConnection',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'public',
#   'void',
#   'setLocation',
#   '(',
#   'Resource',
#   'location',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'private',
#   'ConfigurableApplicationContext',
#   'initializeAndRun',
#   '(',
#   'Class',
#   '<',
#   '?',
#   '>',
#   'config',
#   ',',
#   'String',
#   '.',
#   '.',
#   '.',
#   'args',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'error',
#   '(',
#   'Exception',
#   'ex',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'RSocketServerFactory',
#   'rSocketServerFactory',
#   '(',
#   'RSocketProperties',
#   'properties',
#   ',',
#   'ReactorResourceFactory',
#   'resourceFactory',
#   ',',
#   'ObjectProvider',
#   '<',
#   'RSocketServerCustomizer',
#   '>',
#   'customizers',
#   ',',
#   'ObjectProvider',
#   '<',
#   'SslBundles',
#   '>',
#   'sslBundles',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'public',
#   'RandomAccessData',
#   'getSubsection',
#   '(',
#   'long',
#   'offset',
#   ',',
#   'long',
#   'length',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>', '<BOS>', 'void', 'loadLoadsImage', '(', ')', '{', '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'static',
#   'ClientHttpConnectorBuilder',
#   '<',
#   'ClientHttpConnector',
#   '>',
#   'detect',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'shouldConfigureRestClientUsingBundle',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'withProcessedImportsProvidesLocationResolverContextWithAccessToBinder',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'public',
#   'String',
#   'getDriverClassName',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'public',
#   'Boolean',
#   'getMustRevalidate',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'whenMetricsCommandListenerEnabledPropertyFalseThenNoMetricsCommandListenerIsAdded',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'Collection',
#   '<',
#   'O',
#   '>',
#   'createOperations',
#   '(',
#   'EndpointId',
#   'id',
#   ',',
#   'Object',
#   'target',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'shutdownHookIsNotAddedUntilHandlerIsRegistered',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'unresolvedGenericProperties',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'diskSpaceMetricsWithCustomTags',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'private',
#   'void',
#   'configureJavaPlugin',
#   '(',
#   'Project',
#   'project',
#   ',',
#   'TaskProvider',
#   '<',
#   'CycloneDxTask',
#   '>',
#   'cycloneDxTaskProvider',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>', '<BOS>', 'void', 'shouldRenderTemplate', '(', ')', '{', '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'ofSimpleNameWithSingleCharacterSuffix',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'interpolateWhenParametersAreNestedShouldFullyReplaceAllParameters',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'public',
#   'void',
#   'setConsistency',
#   '(',
#   'InfluxConsistency',
#   'consistency',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'whenPropertiesPipelineIsSetAdapterPipelineReturnsIt',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>', '<BOS>', 'void', 'defaults', '(', ')', '{', '<EOS>'],
#  ['<BOS>', '<BOS>', 'void', 'createDecodesUrlPath', '(', ')', '{', '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'public',
#   'static',
#   'void',
#   'main',
#   '(',
#   'String',
#   '[',
#   ']',
#   'args',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'List',
#   '<',
#   'AddedPropertySource',
#   '>',
#   'getAddedPropertySources',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'public',
#   'void',
#   'debug',
#   '(',
#   'String',
#   'message',
#   ',',
#   'Throwable',
#   'throwable',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'printSimpleWhenZeroWithoutUnitShouldPrintInDays',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>', '<BOS>', 'public', 'String', 'getApiToken', '(', ')', '{', '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'private',
#   'int',
#   'getPort',
#   '(',
#   'AnnotationConfigServletWebServerApplicationContext',
#   'context',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>', '<BOS>', 'void', 'configureMock', '(', ')', '{', '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'private',
#   'String',
#   'getMessage',
#   '(',
#   'BindException',
#   'cause',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'public',
#   'void',
#   'failed',
#   '(',
#   'Throwable',
#   'exc',
#   ',',
#   'A',
#   'attachment',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'setKafkaProperties',
#   '(',
#   'KafkaProperties',
#   'properties',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'asDockerConfigurationWithDefaults',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'public',
#   'List',
#   '<',
#   'String',
#   '>',
#   'getProduced',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'private',
#   'String',
#   '[',
#   ']',
#   'getElements',
#   '(',
#   'String',
#   'source',
#   ',',
#   'String',
#   'delimiter',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'protected',
#   'RepositoryConfigurationExtension',
#   'getRepositoryConfigurationExtension',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'MetricsRepositoryMethodInvocationListener',
#   'metricsRepositoryMethodInvocationListener',
#   '(',
#   'ObjectProvider',
#   '<',
#   'MeterRegistry',
#   '>',
#   'registry',
#   ',',
#   'RepositoryTagsProvider',
#   'tagsProvider',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'getActiveWhenEnvironmentProfilesAndBinderProperty',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'fromResourceShouldReturnJsonContent',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'static',
#   'void',
#   'register',
#   '(',
#   'BeanDefinitionRegistry',
#   'registry',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'public',
#   'Object',
#   'getProperty',
#   '(',
#   'String',
#   'name',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'bootBuildImageWithDockerTokenAuth',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'bindToAnnotationNamedConstructorParameter',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'getUserWhenHasNoActiveMqUser',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>', '<BOS>', 'Resource', 'staticIndexPage', '(', ')', '{', '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'final',
#   'protected',
#   'Mono',
#   '<',
#   'Health',
#   '>',
#   'doHealthCheck',
#   '(',
#   'Health',
#   'builder',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>', '<BOS>', 'String', 'getDockerHost', '(', ')', '{', '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'whenNoPropertyCreatesBean',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'readOperationWithListQueryParameterAndSingleValue',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>', '<BOS>', 'void', 'convertWhenTargetIsList', '(', ')', '{', '<EOS>'],
#  ['<BOS>', '<BOS>', 'void', 'customView', '(', ')', '{', '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'runWithBitnamiImageCreatesConnectionDetails',
#   '(',
#   'R2dbcConnectionDetails',
#   'connectionDetails',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>', '<BOS>', 'void', 'jmsBrokerIsUp', '(', ')', '{', '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'whenAProjectUsesPomPackagingRepackagingIsSkipped',
#   '(',
#   'MavenBuild',
#   'mavenBuild',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>', '<BOS>', 'void', 'extractResources', '(', ')', '{', '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'public',
#   'URLStreamHandler',
#   'createURLStreamHandler',
#   '(',
#   'String',
#   'protocol',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'private',
#   'void',
#   'updateBuildFile',
#   '(',
#   'Upgrade',
#   'upgrade',
#   ',',
#   'String',
#   'buildFileContents',
#   ',',
#   'int',
#   'versionStart',
#   ',',
#   'int',
#   'versionEnd',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>', '<BOS>', 'void', 'errorWithThrowable', '(', ')', '{', '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'whenAutoConfiguredCompositeThenPostProcessAndInitializeAutoConfiguredCompositeBindsTo',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>', '<BOS>', 'String', 'getProperty3', '(', ')', '{', '<EOS>'],
#  ['<BOS>', '<BOS>', 'void', 'getSubDir', '(', ')', '{', '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'environmentWithNewProfile',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'ServletRegistrationBean',
#   '<',
#   'JakartaWebServlet',
#   '>',
#   'h2Console',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'shouldBackOffIfSslBundlesIsMissing',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'public',
#   'static',
#   'void',
#   'initFields',
#   '(',
#   'Object',
#   'testInstance',
#   ',',
#   'Gson',
#   'gson',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'default',
#   'Iterator',
#   '<',
#   'SpanProcessor',
#   '>',
#   'iterator',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'createWithCustomizersShouldApplyCustomizers',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'public',
#   'List',
#   '<',
#   'String',
#   '>',
#   'check',
#   '(',
#   'Library',
#   'library',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'protected',
#   'Stream',
#   '<',
#   'Entry',
#   '>',
#   'stream',
#   '(',
#   'CompositeReactiveHealthContributor',
#   'composite',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>', '<BOS>', 'JarFileType', 'getType', '(', ')', '{', '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'public',
#   'PrivateKey',
#   'privateKey',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'AbstractWebEndpointIntegrationTests',
#   'endpointDelegate',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'findWhenWorkingDirectoryDoesNotExistReturnsNull',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>', '<BOS>', 'void', 'getNameReturnsName', '(', ')', '{', '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'compareToComparesOnNestedEntryName',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>', '<BOS>', 'void', 'deleteSnippets', '(', ')', '{', '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'logFileWebEndpointCanBeDisabled',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'public',
#   'Set',
#   '<',
#   'Artifact',
#   '>',
#   'filter',
#   '(',
#   'Set',
#   '<',
#   'Artifact',
#   '>',
#   'artifacts',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'private',
#   'void',
#   'load',
#   '(',
#   'Class',
#   '<',
#   '?',
#   '>',
#   'config',
#   ',',
#   'String',
#   '.',
#   '.',
#   '.',
#   'environment',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>', '<BOS>', 'void', 'setup', '(', ')', '{', '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'private',
#   'static',
#   'Set',
#   '<',
#   'String',
#   '>',
#   'getDigests',
#   '(',
#   'Stream',
#   '<',
#   'ImageArchiveIndex',
#   '>',
#   'indexes',
#   ',',
#   'Predicate',
#   '<',
#   'BlobReference',
#   '>',
#   'predicate',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'containsDescendantOfWhenSourceReturnsPresentShouldReturnPresent',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>', '<BOS>', 'void', 'failsWithoutAnApiKey', '(', ')', '{', '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'createWhenPathIsNullThrowsException',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'EndpointMediaTypes',
#   'EndpointMediaTypes',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'createRetryPolicyWithDefaultsMatchesBackOffDefaults',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'public',
#   'BuildInfoProperties',
#   'getProperties',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'ExcludedService',
#   'excludedService',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'ignoresMissingHomeProperties',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>', '<BOS>', 'String', 'getName', '(', ')', '{', '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'public',
#   'void',
#   'send',
#   '(',
#   'SampleMessage',
#   'message',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'private',
#   'Executor',
#   'createCustomAsyncExecutor',
#   '(',
#   'String',
#   'threadNamePrefix',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'protected',
#   'NamedValueInfo',
#   'createNamedValueInfo',
#   '(',
#   'MethodParameter',
#   'parameter',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'public',
#   'void',
#   'forEach',
#   '(',
#   'Consumer',
#   '<',
#   'Resource',
#   '>',
#   'action',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'DefaultTopicResolver',
#   'pulsarTopicResolver',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'public',
#   'void',
#   'apply',
#   '(',
#   'IOConsumer',
#   '<',
#   'Layer',
#   '>',
#   'layers',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>', '<BOS>', 'void', 'snippetGeneration', '(', ')', '{', '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'abstract',
#   'void',
#   'produceFrom',
#   '(',
#   'CopySpec',
#   'copySpec',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'public',
#   'void',
#   'setSessionName',
#   '(',
#   'String',
#   'sessionName',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'public',
#   'int',
#   'getMaxQueueCapacity',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'void',
#   'shouldNotCreateClientBuilderIfAlreadyPresent',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'private',
#   'static',
#   'int',
#   'getChronoValue',
#   '(',
#   'long',
#   'value',
#   ',',
#   'ChronoField',
#   'field',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'public',
#   'void',
#   'setFlag',
#   '(',
#   'boolean',
#   'flag',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'public',
#   'String',
#   'getUsageHelp',
#   '(',
#   ')',
#   '{',
#   '<EOS>'],
#  ['<BOS>',
#   '<BOS>',
#   'public',
#   'void',
#   'failed',
#   '(',
#   'Throwable',
#   'exc',
#   ',',
#   'Object',
#   'attachment',
#   ')',
#   '{',
#   '<EOS>'],
#  ...]

# %%
# Try varying N size and get each perplexity from them
results = []
for N in [2, 3, 5, 7]:
    lm = NgramLM(n=N, smoothing="add-k", k=1.0)
    lm.fit(train_sequences)
    ppl = perplexity(lm, test_sequences)
    results.append((N, ppl, lm.V))
    print(f"N={N} | Vocab={lm.V} | Test Perplexity={ppl}")
# Out:
# N=2 | Vocab=21209 | Test Perplexity=46.659859797654114
# N=3 | Vocab=21209 | Test Perplexity=77.84711852208532
# N=5 | Vocab=21209 | Test Perplexity=159.74469082646425
# N=7 | Vocab=21209 | Test Perplexity=169.44302466198585

# %% [markdown]
# Demo Sampled completion

# %%
demo_seq = ['static']
# Use first 20 tokens (without trailing EOS) as context
demo_prefix = [t for t in demo_seq if t != EOS][:20]

# Use best (so lowest) perplexity model among tried ones
best_N, _, _ = min(results, key=lambda x: x[1])
print('best N')
print(best_N) # this should be 2 for checking
best_model = NgramLM(n=best_N, smoothing="add-k", k=1.0)
best_model.fit(train_sequences)

dist = best_model.next_token_dist(demo_prefix)
top10 = dist[:10]

print("Context prefix:", " ".join(demo_prefix[-(best_N-1):]))
print("Top-10 candidates:")
for tok, p in top10:
    print(f"{tok}  p={p}")

# Sampling continuation
sampled = best_model.sample(demo_prefix, max_len=40)
print("Sampled continuation:")
print(" ".join(sampled))
# Out:
# best N
# 2
# Context prefix: static
# Top-10 candidates:
# void  p=0.015486527616148956
# String  p=0.004699668785247516
# boolean  p=0.0016560737624205532
# Stream  p=0.0012980037597350282
# List  p=0.0012532450093993375
# int  p=0.0007608987557067407
# T  p=0.0004475875033569063
# PropertySourcesPlaceholderConfigurer  p=0.0004028287530212156
# SslBundle  p=0.0004028287530212156
# ImageReference  p=0.0004028287530212156
# Sampled continuation:
# static bindWhenCollectionParameterWithEmptyDefaultValueShouldReturnEmptyInstance setTlsVerify setTrustStore SortHandlerMethodArgumentResolverCustomizer usesMatchersBasedOffConfiguredActuatorBasePath generatedBuildInfoUsesCustomBuildTime matchWhenHasNoEndpoints setSourceType toHierarchicalName setBatchSize withRunImage ofWhenHasIllegalCharacterThrowsException publicDefineClass getBindConstructorWhenIsTypeWithPrivateConstructorReturnsNull singleWebEndpointCanBeExposed validateWithWrappedExceptionMessageWhenInvalidThrowsException warnIfNotHttps testPasswordEncoding graphQlWebSocketMapping deleteSnippets errorResponseParamsFalse BasicErrorController couchbaseConnectionDetails routerFunction registerHintsWhenHasRecursiveType slowRestart mavenPublish getExpiringChains throwableTagProvider setResolvedBoms customContentTypeCustomCharset producedAndConsumed availabilityOfTemplateThatDoesNotExist createFromFileWhenDirectoryReturnsExplodedFileArchive scrapeCanProduceOpenMetrics100 getMaxDays testMustacheTemplate resp ZipInfo additionalProfiles
