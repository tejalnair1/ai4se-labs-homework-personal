# %%
import os
import re
import javalang
from git import Repo
from javalang import tokenizer as jtok

# %%
# github repo
repo_url = "https://github.com/spring-projects/spring-boot.git"
repo_name = repo_url.split('/')[-1].removesuffix('.git')

# %%
repo_name
# Out:
# 'spring-boot'

# %%
# clone repo
Repo.clone_from(repo_url, repo_name)
print("Cloned")

# %%
HEX_HASH_RE = re.compile(r"#([0-9a-fA-F]{3,8})\b") # #RGB, #RRGGBB,
LINE_START_HASH_RE = re.compile(r"(?m)^\s*#.*$") # lines that start with '#'

def remove_hashes(code: str) -> str:
    # remove alone # at start of line
    code = LINE_START_HASH_RE.sub("/* removed-nonjava-hash-line */", code)
    # convert #hex color tokens into comments so lexer ignores them
    code = HEX_HASH_RE.sub(r"/*#\1*/", code)
    return code

# %%
def parse(code: str):
  try:
    return javalang.parse.parse(code)
  except jtok.LexerError:
    cleaned = remove_hashes(code)
    return javalang.parse.parse(cleaned)

# %%
def _dims_count(dims_attr):
    # javalang may give an int or a list for dimensions want to convert this to an int
    if dims_attr is None:
        return 0
    if isinstance(dims_attr, int):
        return dims_attr
    if isinstance(dims_attr, (list, tuple)):
        return len(dims_attr)
    try:
        return int(dims_attr)
    except Exception:
        return 0

# %%
# def _dims_count(dims_attr):
#     if dims_attr is None: return 0
#     if isinstance(dims_attr, int): return dims_attr
#     if isinstance(dims_attr, (list, tuple)): return len(dims_attr)
#     try: return int(dims_attr)
#     except Exception: return 0

def type_to_str(t) -> str:
    """Pretty-print type name"""
    if t is None:
        return ""
    if isinstance(t, javalang.tree.BasicType):
        name = t.name # then will get 'int', 'void'
    elif isinstance(t, javalang.tree.ReferenceType):
        name = ".".join(t.name) if isinstance(t.name, list) else t.name
        args = getattr(t, "arguments", None)
        if args:
            rendered = []
            for a in args:
                if hasattr(a, "type") and a.type is not None:
                    rendered.append(type_to_str(a.type))
                else:
                    rendered.append("?")
            name += "<" + ", ".join(rendered) + ">"
    else:
        name = getattr(t, "name", str(t))
    dims = "[]" * _dims_count(getattr(t, "dimensions", 0))
    return name + dims

def param_to_str(p) -> str:
    """Pretty-print param names"""
    t_str = type_to_str(getattr(p, "type", None))
    varargs = "..." if getattr(p, "varargs", False) else ""
    extra_dims = "[]" * _dims_count(getattr(p, "dimensions", 0))
    return f"{t_str}{varargs}{extra_dims} {p.name}".strip()

def simple_signature(node) -> str:
    """public static int gcd(int a, int b)"""
    mods = " ".join(sorted(getattr(node, "modifiers", []) or [])) # this gets the 'public static'
    ret  = type_to_str(getattr(node, "return_type", None)) or "void" # this get return type, default 'void'
    name = node.name
    params = ", ".join(param_to_str(p) for p in (node.parameters or []))
    # join all together using single spaces
    left = " ".join(x for x in [mods, ret, name] if x)
    return f"{left}({params})"

# %%
# multi-char operators first
TOKEN_RE = re.compile(r"""(?:==|!=|<=|>=|&&|\|\||::|->) | [A-Za-z_][A-Za-z0-9_]* | \d+\.\d+|\d+| [{}()\[\],.;<>+\-*/%&|^!?=~]""", re.VERBOSE)

def tokenize_code(s: str):
    return TOKEN_RE.findall(s)

# %%
java_files = [
    os.path.join(dp, f) for dp, dn, fn in os.walk(repo_name)
    for f in fn if f.endswith(".java")
]
methods = []
for file_path in java_files:
    try:
        with open(file_path, "r", encoding="utf-8", errors="ignore") as f:
            code = f.read()

        tree = parse(code)
        lines = code.splitlines()

        method_declarations = list(tree.filter(javalang.tree.MethodDeclaration))
        # sort methods by starting line number
        method_declarations.sort(key=lambda item: item[1].position.line)

        for i, (path, node) in enumerate(method_declarations):
            print('im here')
            start_line = node.position.line
            print('start line')
            
            # end line = start of next method or end of file
            if i + 1 < len(method_declarations):
                next_method_node = method_declarations[i+1][1]
                end_line = next_method_node.position.line - 1
            else:
                # if last method, find end of class body
                end_line = len(lines)
            print('end line')
            print(node.name)
            sig = simple_signature(node)
            methods.append({
                'file': file_path,
                'name': node.name,
                'start_line': start_line,
                'end_line': end_line,
                'signature': sig,
                "code_tokens": tokenize_code(sig + " {")
            })

    except (javalang.parser.JavaSyntaxError, jtok.LexerError) as e:
        print(f"Could not parse {file_path}: {e}")
# Out:
# im here
# start line
# end line
# getStatusReturnsStatus
# im here
# start line
# end line
# getProgressDetailReturnsProgressDetails
# im here
# start line
# end line
# getProgressDetailReturnsProgressDetailsForLongNumbers
# im here
# start line
# end line
# getProgressReturnsProgress
# im here
# start line
# end line
# createEvent
# im here
# start line
# end line
# createEvent
# im here
# start line
# end line
# test
# im here
# start line
# end line
# getIdReturnsId
# im here
# start line
# end line
# getErrorReturnsErrorDetail
# im here
# start line
# end line
# createEvent
# im here
# start line
# end line
# toSystemOutPrintsToSystemOut
# im here
# start line
# end line
# toPrintsToOutput
# im here
# start line
# end line
# getIdReturnsId
# im here
# start line
# end line
# createEvent
# im here
# start line
# end line
# totalProgress
# im here
# start line
# end line
# totalProgressUpdatesSmoothly
# im here
# start line
# end line
# run
# im here
# start line
# end line
# onUpdate
# im here
# start line
# end line
# setup
# im here
# start line
# end line
# http
# im here
# start line
# end line
# emptyResponse
# im here
# start line
# end line
# responseOf
# im here
# start line
# end line
# close
# im here
# start line
# end line
# getContent
# im here
# start line
# end line
# responseWithHeaders
# im here
# start line
# end line
# getContent
# im here
# start line
# end line
# getHeader
# im here
# start line
# end line
# close
# im here
# start line
# end line
# createDockerApi
# im here
# start line
# end line
# setup
# im here
# start line
# end line
# pullWhenReferenceIsNullThrowsException
# im here
# start line
# end line
# pullWhenListenerIsNullThrowsException
# im here
# start line
# end line
# pullPullsImageAndProducesEvents
# im here
# start line
# end line
# pullWithRegistryAuthPullsImageAndProducesEvents
# im here
# start line
# end line
# pullWithPlatformPullsImageAndProducesEvents
# im here
# start line
# end line
# pullWithPlatformAndInsufficientApiVersionThrowsException
# im here
# start line
# end line
# pushWhenReferenceIsNullThrowsException
# im here
# start line
# end line
# pushWhenListenerIsNullThrowsException
# im here
# start line
# end line
# pushPushesImageAndProducesEvents
# im here
# start line
# end line
# pushWithErrorInStreamThrowsException
# im here
# start line
# end line
# loadWhenArchiveIsNullThrowsException
# im here
# start line
# end line
# loadWhenListenerIsNullThrowsException
# im here
# start line
# end line
# loadWithEmptyResponseThrowsException
# im here
# start line
# end line
# loadWithErrorResponseThrowsException
# im here
# start line
# end line
# loadLoadsImage
# im here
# start line
# end line
# removeWhenReferenceIsNullThrowsException
# im here
# start line
# end line
# removeRemovesContainer
# im here
# start line
# end line
# removeWhenForceIsTrueRemovesContainer
# im here
# start line
# end line
# inspectWhenReferenceIsNullThrowsException
# im here
# start line
# end line
# inspectInspectImage
# im here
# start line
# end line
# exportLayersExportsLayerTars
# im here
# start line
# end line
# exportLayersWithSymlinksExportsLayerTars
# im here
# start line
# end line
# tagWhenReferenceIsNullThrowsException
# im here
# start line
# end line
# tagWhenTargetIsNullThrowsException
# im here
# start line
# end line
# tagTagsImage
# im here
# start line
# end line
# tagRenamesImage
# im here
# start line
# end line
# setup
# im here
# start line
# end line
# createWhenConfigIsNullThrowsException
# im here
# start line
# end line
# createCreatesContainer
# im here
# start line
# end line
# createWhenHasContentContainerWithContent
# im here
# start line
# end line
# createWithPlatformCreatesContainer
# im here
# start line
# end line
# createWithPlatformAndUnknownApiVersionAttemptsCreate
# im here
# start line
# end line
# createWithPlatform
# im here
# start line
# end line
# createWithPlatformAndKnownInsufficientApiVersionThrowsException
# im here
# start line
# end line
# startWhenReferenceIsNullThrowsException
# im here
# start line
# end line
# startStartsContainer
# im here
# start line
# end line
# logsWhenReferenceIsNullThrowsException
# im here
# start line
# end line
# logsWhenListenerIsNullThrowsException
# im here
# start line
# end line
# logsProducesEvents
# im here
# start line
# end line
# waitWhenReferenceIsNullThrowsException
# im here
# start line
# end line
# waitReturnsStatus
# im here
# start line
# end line
# removeWhenReferenceIsNullThrowsException
# im here
# start line
# end line
# removeRemovesContainer
# im here
# start line
# end line
# removeWhenForceIsTrueRemovesContainer
# im here
# start line
# end line
# setup
# im here
# start line
# end line
# deleteWhenNameIsNullThrowsException
# im here
# start line
# end line
# deleteDeletesContainer
# im here
# start line
# end line
# deleteWhenForceIsTrueDeletesContainer
# im here
# start line
# end line
# setup
# im here
# start line
# end line
# getApiVersionWithVersionHeaderReturnsVersion
# im here
# start line
# end line
# getApiVersionWithEmptyVersionHeaderReturnsUnknownVersion
# im here
# start line
# end line
# getApiVersionWithNoVersionHeaderReturnsUnknownVersion
# im here
# start line
# end line
# getApiVersionWithExceptionReturnsUnknownVersion
# im here
# start line
# end line
# getStreamReturnsStream
# im here
# start line
# end line
# getErrorDetailReturnsErrorDetail
# im here
# start line
# end line
# createEvent
# im here
# start line
# end line
# readValueWhenFullDeserializesJson
# im here
# start line
# end line
# readValueWhenMinimalDeserializesJson
# im here
# start line
# end line
# readValueWhenEmptyDetailsDeserializesJson
# im here
# start line
# end line
# readAllWhenSimpleStreamReturnsEvents
# im here
# start line
# end line
# readAllWhenAnsiStreamReturnsEvents
# im here
# start line
# end line
# readSucceedsWhenStreamTypeIsInvalid
# im here
# start line
# end line
# readAll
# im here
# start line
# end line
# withPrefixAndBookends
# im here
# start line
# end line
# withoutPrefix
# im here
# start line
# end line
# withoutBookends
# im here
# start line
# end line
# toString
# im here
# start line
# end line
# create
# im here
# start line
# end line
# createWhenPercentLessThanZeroThrowsException
# im here
# start line
# end line
# createWhenEventMoreThanOneHundredThrowsException
# im here
# start line
# end line
# configWithContextIsRead
# im here
# start line
# end line
# configWithoutContextIsRead
# im here
# start line
# end line
# configWithDefaultContextIsRead
# im here
# start line
# end line
# configIsReadWithProvidedContext
# im here
# start line
# end line
# invalidContextThrowsException
# im here
# start line
# end line
# configIsEmptyWhenConfigFileDoesNotExist
# im here
# start line
# end line
# configWithAuthIsRead
# im here
# start line
# end line
# pathToResource
# Could not parse spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/configuration/CredentialTests.java:
# im here
# start line
# end line
# createAuthHeaderReturnsEncodedHeader
# im here
# start line
# end line
# resolveWhenDockerHostIsNullReturnsLinuxDefault
# im here
# start line
# end line
# resolveWhenDockerHostIsNullReturnsWindowsDefault
# im here
# start line
# end line
# resolveWhenUsingDefaultContextReturnsWindowsDefault
# im here
# start line
# end line
# resolveWhenUsingDefaultContextReturnsLinuxDefault
# im here
# start line
# end line
# resolveWhenDockerHostAddressIsLocalReturnsAddress
# im here
# start line
# end line
# resolveWhenDockerHostAddressIsLocalWithSchemeReturnsAddress
# im here
# start line
# end line
# resolveWhenDockerHostAddressIsHttpReturnsAddress
# im here
# start line
# end line
# resolveWhenDockerHostAddressIsHttpsReturnsAddress
# im here
# start line
# end line
# resolveWhenDockerHostAddressIsTcpReturnsAddress
# im here
# start line
# end line
# resolveWhenEnvironmentAddressIsLocalReturnsAddress
# im here
# start line
# end line
# resolveWhenEnvironmentAddressIsLocalWithSchemeReturnsAddress
# im here
# start line
# end line
# resolveWhenEnvironmentAddressIsTcpReturnsAddress
# im here
# start line
# end line
# resolveWithDockerHostContextReturnsAddress
# im here
# start line
# end line
# resolveWithDockerConfigMetadataContextReturnsAddress
# im here
# start line
# end line
# resolveWhenEnvironmentHasAddressAndContextPrefersContext
# im here
# start line
# end line
# pathToResource
# im here
# start line
# end line
# setUp
# im here
# start line
# end line
# getWhenKnowUser
# im here
# start line
# end line
# getWhenKnowToken
# im here
# start line
# end line
# getWhenCredentialsMissingMessageReturnsNull
# im here
# start line
# end line
# getWhenUsernameMissingMessageReturnsNull
# im here
# start line
# end line
# getWhenUrlMissingMessageReturnsNull
# im here
# start line
# end line
# getWhenUnknownErrorThrowsException
# im here
# start line
# end line
# getWhenExecutableDoesNotExistErrorThrowsException
# Could not parse spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/configuration/DockerRegistryConfigAuthenticationTests.java: Unterminated character/string literal at """, line 245: .containsEntry("email", "test@example.com");
# im here
# start line
# end line
# createMinimalAuthHeaderReturnsEncodedHeader
# im here
# start line
# end line
# createFullAuthHeaderReturnsEncodedHeader
# im here
# start line
# end line
# jsonContent
# im here
# start line
# end line
# decoded
# Could not parse spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/ssl/PemFileWriter.java:
# im here
# start line
# end line
# setUp
# im here
# start line
# end line
# tearDown
# im here
# start line
# end line
# createKeyStoreWithCertChain
# im here
# start line
# end line
# createKeyStoreWithCertChainAndRsaPrivateKey
# im here
# start line
# end line
# codeShouldMatchSpringBootSslPackage
# im here
# start line
# end line
# codeShouldMatchSpringBootSslPackage
# im here
# start line
# end line
# setUp
# im here
# start line
# end line
# tearDown
# im here
# start line
# end line
# createKeyStoreWithCertChain
# im here
# start line
# end line
# loadBuildpackVersion
# im here
# start line
# end line
# loadSpringBootVersion
# im here
# start line
# end line
# load
# im here
# start line
# end line
# setup
# im here
# start line
# end line
# getShouldExecuteHttpGet
# im here
# start line
# end line
# postShouldExecuteHttpPost
# im here
# start line
# end line
# postWithRegistryAuthShouldExecuteHttpPostWithHeader
# im here
# start line
# end line
# postWithEmptyRegistryAuthShouldExecuteHttpPostWithoutHeader
# im here
# start line
# end line
# postWithJsonContentShouldExecuteHttpPost
# im here
# start line
# end line
# postWithArchiveContentShouldExecuteHttpPost
# im here
# start line
# end line
# putWithJsonContentShouldExecuteHttpPut
# im here
# start line
# end line
# putWithArchiveContentShouldExecuteHttpPut
# im here
# start line
# end line
# deleteShouldExecuteHttpDelete
# im here
# start line
# end line
# executeWhenResponseIsIn400RangeShouldThrowDockerException
# im here
# start line
# end line
# executeWhenResponseIsIn500RangeWithNoContentShouldThrowDockerException
# im here
# start line
# end line
# executeWhenResponseIsIn500RangeWithMessageShouldThrowDockerException
# im here
# start line
# end line
# executeWhenResponseIsIn500RangeWithOtherContentShouldThrowDockerException
# im here
# start line
# end line
# shouldReturnErrorsAndMessage
# im here
# start line
# end line
# executeWhenClientThrowsIOExceptionRethrowsAsDockerException
# im here
# start line
# end line
# writeToString
# im here
# start line
# end line
# givenClientWillReturnResponse
# im here
# start line
# end line
# createIfPossibleWhenDockerHostIsNotSetReturnsNull
# im here
# start line
# end line
# createIfPossibleWhenDockerHostIsFileReturnsNull
# im here
# start line
# end line
# createIfPossibleWhenDockerHostIsAddressReturnsTransport
# im here
# start line
# end line
# createIfPossibleWhenNoTlsVerifyUsesHttp
# im here
# start line
# end line
# createIfPossibleWhenTlsVerifyUsesHttps
# im here
# start line
# end line
# createIfPossibleWhenTlsVerifyWithMissingCertPathThrowsException
# im here
# start line
# end line
# hostOf
# im here
# start line
# end line
# createWhenHostIsNullThrowsException
# im here
# start line
# end line
# createWhenUriIsNullThrowsException
# im here
# start line
# end line
# create
# im here
# start line
# end line
# createWhenReasonPhraseIsNull
# im here
# start line
# end line
# createWhenErrorsIsNull
# im here
# start line
# end line
# createWhenErrorsIsEmpty
# im here
# start line
# end line
# createWhenMessageIsNull
# im here
# start line
# end line
# createWhenMessageIsEmpty
# im here
# start line
# end line
# readValueDeserializesJson
# im here
# start line
# end line
# toStringHasErrorDetails
# im here
# start line
# end line
# createWhenDockerHostVariableIsAddressReturnsRemote
# im here
# start line
# end line
# createWhenDockerHostVariableIsFileReturnsLocal
# im here
# start line
# end line
# createWhenDockerHostVariableIsUnixSchemePrefixedFileReturnsLocal
# im here
# start line
# end line
# createWhenDockerHostIsFileReturnsTransport
# im here
# start line
# end line
# createWhenDockerHostIsFileThatDoesNotExistReturnsTransport
# im here
# start line
# end line
# createWhenDockerHostIsAddressReturnsTransport
# im here
# start line
# end line
# readValueDeserializesJson
# im here
# start line
# end line
# toStringHasErrorDetails
# im here
# start line
# end line
# createWhenHostIsNullThrowsException
# im here
# start line
# end line
# createWhenCauseIsNullThrowsException
# im here
# start line
# end line
# createWithIOException
# im here
# start line
# end line
# createWithLastErrorException
# im here
# start line
# end line
# getConfigEnvContainsParsedValues
# im here
# start line
# end line
# getConfigLabelsReturnsLabels
# im here
# start line
# end line
# getLayersReturnsImageLayers
# im here
# start line
# end line
# getOsReturnsOs
# im here
# start line
# end line
# getOsWhenOsIsNotDefaultOsReturnsOs
# im here
# start line
# end line
# getOsWhenOsIsEmptyReturnsDefaultOs
# im here
# start line
# end line
# getArchitectureReturnsArchitecture
# im here
# start line
# end line
# getVariantReturnsVariant
# im here
# start line
# end line
# getCreatedReturnsDate
# im here
# start line
# end line
# getImage
# im here
# start line
# end line
# loadJsonFromDistributionManifestList
# im here
# start line
# end line
# getManifestList
# im here
# start line
# end line
# loadJsonFromDistributionManifest
# im here
# start line
# end line
# loadJsonFromImageManifest
# im here
# start line
# end line
# getManifest
# im here
# start line
# end line
# ofWhenArchiveIsNullThrowsException
# im here
# start line
# end line
# ofWhenDestinationPathIsNullThrowsException
# im here
# start line
# end line
# ofWhenDestinationPathIsEmptyThrowsException
# im here
# start line
# end line
# ofCreatesContainerContent
# im here
# start line
# end line
# ofWithDestinationPathCreatesContainerContent
# im here
# start line
# end line
# ofCreatesFromJson
# im here
# start line
# end line
# ofCreatesFromValues
# im here
# start line
# end line
# ofWhenNameOnlyCreatesImageName
# im here
# start line
# end line
# ofWhenSlashedNameCreatesImageName
# im here
# start line
# end line
# ofWhenLocalhostNameCreatesImageName
# im here
# start line
# end line
# ofWhenDomainAndNameCreatesImageName
# im here
# start line
# end line
# ofWhenDomainNameAndPortCreatesImageName
# im here
# start line
# end line
# ofWhenSimpleNameAndPortCreatesImageName
# im here
# start line
# end line
# ofWhenSimplePathAndPortCreatesImageName
# im here
# start line
# end line
# ofWhenNameWithLongPathCreatesImageName
# im here
# start line
# end line
# ofWhenLocalhostDomainCreatesImageName
# im here
# start line
# end line
# ofWhenLocalhostDomainAndPathCreatesImageName
# im here
# start line
# end line
# ofWhenLegacyDomainUsesNewDomain
# im here
# start line
# end line
# ofWhenNameIsNullThrowsException
# im here
# start line
# end line
# ofWhenNameIsEmptyThrowsException
# im here
# start line
# end line
# ofWhenContainsUppercaseThrowsException
# im here
# start line
# end line
# ofWhenNameIncludesTagThrowsException
# im here
# start line
# end line
# ofWhenNameIncludeDigestThrowsException
# im here
# start line
# end line
# hashCodeAndEquals
# im here
# start line
# end line
# ofCreatesInstance
# im here
# start line
# end line
# ofWhenNullThrowsException
# im here
# start line
# end line
# ofWhenEmptyThrowsException
# im here
# start line
# end line
# hashCodeAndEquals
# im here
# start line
# end line
# ofReturnsLayerId
# im here
# start line
# end line
# hashCodeAndEquals
# im here
# start line
# end line
# ofWhenValueIsNullThrowsException
# im here
# start line
# end line
# ofWhenValueIsEmptyThrowsException
# im here
# start line
# end line
# ofSha256Digest
# im here
# start line
# end line
# ofSha256DigestWithZeroPadding
# im here
# start line
# end line
# ofSha256DigestWhenNullThrowsException
# im here
# start line
# end line
# ofSha256DigestWhenWrongLengthThrowsException
# Could not parse spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/type/ApiVersionTests.java:
# im here
# start line
# end line
# randomWhenPrefixIsNullThrowsException
# im here
# start line
# end line
# randomGeneratesRandomString
# im here
# start line
# end line
# randomStringWithLengthGeneratesRandomString
# im here
# start line
# end line
# basedOnWhenSourceIsNullThrowsException
# im here
# start line
# end line
# basedOnWhenNameExtractorIsNullThrowsException
# im here
# start line
# end line
# basedOnWhenPrefixIsNullThrowsException
# im here
# start line
# end line
# basedOnWhenSuffixIsNullThrowsException
# im here
# start line
# end line
# basedOnGeneratesHashBasedName
# im here
# start line
# end line
# basedOnWhenSizeIsTooBigThrowsException
# im here
# start line
# end line
# ofWhenValueIsNullThrowsException
# im here
# start line
# end line
# ofGeneratesValue
# im here
# start line
# end line
# equalsAndHashCode
# im here
# start line
# end line
# loadJson
# im here
# start line
# end line
# getIndex
# im here
# start line
# end line
# ofWithOsParses
# im here
# start line
# end line
# ofWithOsAndArchitectureParses
# im here
# start line
# end line
# ofWithOsAndArchitectureAndVariantParses
# im here
# start line
# end line
# ofWithEmptyValueFails
# im here
# start line
# end line
# ofWithTooManySegmentsFails
# im here
# start line
# end line
# fromImageMatchesImage
# im here
# start line
# end line
# getImage
# im here
# start line
# end line
# ofSimpleName
# im here
# start line
# end line
# ofSimpleNameWithSingleCharacterSuffix
# im here
# start line
# end line
# ofLibrarySlashName
# im here
# start line
# end line
# ofSlashName
# im here
# start line
# end line
# ofCustomDomain
# im here
# start line
# end line
# ofCustomDomainAndPort
# im here
# start line
# end line
# ofLegacyDomain
# im here
# start line
# end line
# ofNameAndTag
# im here
# start line
# end line
# ofDomainPortAndTag
# im here
# start line
# end line
# ofNameAndDigest
# im here
# start line
# end line
# ofNameAndTagAndDigest
# im here
# start line
# end line
# ofCustomDomainAndPortWithTag
# im here
# start line
# end line
# ofImageName
# im here
# start line
# end line
# ofImageNameAndTag
# im here
# start line
# end line
# ofImageNameTagAndDigest
# im here
# start line
# end line
# ofWhenHasIllegalCharacterThrowsException
# im here
# start line
# end line
# ofWhenContainsUpperCaseThrowsException
# im here
# start line
# end line
# ofWhenIsVeryLongAndHasIllegalCharacter
# im here
# start line
# end line
# forJarFile
# im here
# start line
# end line
# assertForJarFile
# im here
# start line
# end line
# randomGeneratesRandomName
# im here
# start line
# end line
# randomWithLengthGeneratesRandomName
# im here
# start line
# end line
# randomWherePrefixIsNullThrowsException
# im here
# start line
# end line
# inTaggedFormWhenHasDigestThrowsException
# im here
# start line
# end line
# inTaggedFormWhenHasNoTagUsesLatest
# im here
# start line
# end line
# inTaggedFormWhenHasTagUsesTag
# im here
# start line
# end line
# inTaggedOrDigestFormWhenHasDigestUsesDigest
# im here
# start line
# end line
# inTaggedOrDigestFormWhenHasTagUsesTag
# im here
# start line
# end line
# inTaggedOrDigestFormWhenHasNoTagOrDigestUsesLatest
# im here
# start line
# end line
# equalsAndHashCode
# im here
# start line
# end line
# withDigest
# im here
# start line
# end line
# inTaglessFormWithDigest
# im here
# start line
# end line
# inTaglessForm
# im here
# start line
# end line
# fromImageWritesToValidArchiveTar
# im here
# start line
# end line
# assertExpectedLayer
# im here
# start line
# end line
# assertExpectedConfig
# im here
# start line
# end line
# assertExpectedManifest
# im here
# start line
# end line
# read
# im here
# start line
# end line
# ofWhenLayoutIsNullThrowsException
# im here
# start line
# end line
# fromTarArchiveWhenTarArchiveIsNullThrowsException
# im here
# start line
# end line
# ofCreatesLayer
# im here
# start line
# end line
# getLayersReturnsLayers
# im here
# start line
# end line
# getLayersWithNoLayersReturnsEmptyList
# im here
# start line
# end line
# getLayersWithEmptyManifestReturnsEmptyList
# im here
# start line
# end line
# getManifest
# im here
# start line
# end line
# getEnvContainsParsedValues
# im here
# start line
# end line
# whenConfigHasNoEnvThenImageConfigEnvIsEmpty
# im here
# start line
# end line
# whenConfigHasNoLabelsThenImageConfigLabelsIsEmpty
# im here
# start line
# end line
# getLabelsReturnsLabels
# im here
# start line
# end line
# updateWithLabelUpdatesLabels
# im here
# start line
# end line
# getImageConfig
# im here
# start line
# end line
# getMinimalImageConfig
# im here
# start line
# end line
# generateWhenPrefixIsNullThrowsException
# im here
# start line
# end line
# generateGeneratesRandomString
# Could not parse spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/type/BindingTests.java:
# im here
# start line
# end line
# ofWhenImageReferenceIsNullThrowsException
# im here
# start line
# end line
# ofWhenUpdateIsNullThrowsException
# im here
# start line
# end line
# writeToWritesJson
# im here
# start line
# end line
# ofWhenInputStreamThrowsException
# im here
# start line
# end line
# ofWhenContentIsNullThrowsException
# im here
# start line
# end line
# ofWhenConsumerIsNullThrowsException
# im here
# start line
# end line
# ofFromContent
# im here
# start line
# end line
# ofSmallContent
# im here
# start line
# end line
# ofLargeContent
# im here
# start line
# end line
# ofWithInspector
# im here
# start line
# end line
# readBytes
# im here
# start line
# end line
# ofWhenSupplierIsNullThrowsException
# im here
# start line
# end line
# ofWhenStreamReturnsWritable
# im here
# start line
# end line
# ofWhenStringIsNullThrowsException
# im here
# start line
# end line
# ofWhenStringReturnsWritable
# im here
# start line
# end line
# ofWhenBytesIsNullThrowsException
# im here
# start line
# end line
# ofWhenBytesReturnsWritable
# im here
# start line
# end line
# writeToAndGetBytes
# im here
# start line
# end line
# createWhenZipIsNullThrowsException
# im here
# start line
# end line
# createWhenOwnerIsNullThrowsException
# im here
# start line
# end line
# writeToAdaptsContent
# im here
# start line
# end line
# writeTestZip
# im here
# start line
# end line
# writesTarArchive
# im here
# start line
# end line
# getUidReturnsUid
# im here
# start line
# end line
# getGidReturnsGid
# im here
# start line
# end line
# toStringReturnsString
# im here
# start line
# end line
# ofReturnsNewOwner
# im here
# start line
# end line
# umaskForPath
# im here
# start line
# end line
# umaskForPathWithNonExistentFile
# im here
# start line
# end line
# umaskForPathOnWindowsFails
# im here
# start line
# end line
# umaskForPathWithNullPath
# im here
# start line
# end line
# posixPermissionsToUmask
# im here
# start line
# end line
# posixPermissionsToUmaskWithEmptyPermissions
# im here
# start line
# end line
# posixPermissionsToUmaskWithNullPermissions
# im here
# start line
# end line
# ofWritesTarContent
# im here
# start line
# end line
# fromZipFileReturnsZipFileAdapter
# im here
# start line
# end line
# writeTestZip
# im here
# start line
# end line
# ofReadsJson
# im here
# start line
# end line
# valueAtWhenStringReturnsValue
# im here
# start line
# end line
# valueAtWhenStringArrayReturnsValue
# im here
# start line
# end line
# valueAtWhenMissingReturnsNull
# im here
# start line
# end line
# valueAtWhenInterfaceReturnsProxy
# im here
# start line
# end line
# valueAtWhenInterfaceAndMissingReturnsProxy
# im here
# start line
# end line
# valueAtWhenActualPropertyStartsWithUppercaseReturnsValue
# im here
# start line
# end line
# valueAtWhenDefaultMethodReturnsValue
# im here
# start line
# end line
# of
# im here
# start line
# end line
# getName
# im here
# start line
# end line
# getFirst
# im here
# start line
# end line
# getLast
# im here
# start line
# end line
# getFullName
# im here
# start line
# end line
# getReturnsConfiguredObjectMapper
# im here
# start line
# end line
# getWhenReadingObjectNodeReturnsNodes
# im here
# start line
# end line
# getWhenReadTypesReturnsTypes
# im here
# start line
# end line
# getId
# im here
# start line
# end line
# getStatus
# im here
# start line
# end line
# getObjectMapper
# im here
# start line
# end line
# getContent
# im here
# start line
# end line
# getContentAsString
# im here
# start line
# end line
# fromImageLoadsMetadata
# im here
# start line
# end line
# fromImageWhenImageIsNullThrowsException
# im here
# start line
# end line
# fromImageWhenImageConfigIsNullThrowsException
# im here
# start line
# end line
# fromImageConfigWhenLabelIsMissingThrowsException
# im here
# start line
# end line
# fromJsonLoadsMetadata
# im here
# start line
# end line
# toSystemOutPrintsToSystemOut
# im here
# start line
# end line
# toPrintsToOutput
# im here
# start line
# end line
# setUp
# im here
# start line
# end line
# resolveWhenFilePathReturnsBuildpack
# im here
# start line
# end line
# resolveWhenFileUrlReturnsBuildpack
# im here
# start line
# end line
# resolveWhenArchiveWithoutDescriptorThrowsException
# im here
# start line
# end line
# resolveWhenArchiveWithDirectoryReturnsNull
# im here
# start line
# end line
# resolveWhenArchiveThatDoesNotExistReturnsNull
# im here
# start line
# end line
# getCoordinates
# im here
# start line
# end line
# apply
# im here
# start line
# end line
# getContent
# im here
# start line
# end line
# getNameReturnsName
# im here
# start line
# end line
# toStringReturnsName
# im here
# start line
# end line
# applyUpdatesConfiguration
# im here
# start line
# end line
# applyWhenWithDaemonAccessUpdatesConfigurationWithRootUser
# im here
# start line
# end line
# applyWhenWithLogLevelArgAndVerboseLoggingUpdatesConfigurationWithLogLevel
# im here
# start line
# end line
# applyWhenWithLogLevelArgAndNonVerboseLoggingDoesNotUpdateLogLevel
# im here
# start line
# end line
# applyWhenWithArgsUpdatesConfigurationWithArguments
# im here
# start line
# end line
# applyWhenWithBindsUpdatesConfigurationWithBinds
# im here
# start line
# end line
# applyWhenWithEnvUpdatesConfigurationWithEnv
# im here
# start line
# end line
# applyWhenWithNetworkModeUpdatesConfigurationWithNetworkMode
# im here
# start line
# end line
# applyWhenWithSecurityOptionsUpdatesConfigurationWithSecurityOptions
# im here
# start line
# end line
# setup
# im here
# start line
# end line
# resolveAllWithBuilderBuildpackReferenceReturnsExpectedBuildpack
# im here
# start line
# end line
# resolveAllWithDirectoryBuildpackReferenceReturnsExpectedBuildpack
# im here
# start line
# end line
# resolveAllWithTarGzipBuildpackReferenceReturnsExpectedBuildpack
# im here
# start line
# end line
# resolveAllWithImageBuildpackReferenceReturnsExpectedBuildpack
# im here
# start line
# end line
# resolveAllWithInvalidLocatorThrowsException
# im here
# start line
# end line
# fromEnvReturnsOwner
# im here
# start line
# end line
# fromEnvWhenEnvIsNullThrowsException
# im here
# start line
# end line
# fromEnvWhenUserPropertyIsMissingThrowsException
# im here
# start line
# end line
# fromEnvWhenGroupPropertyIsMissingThrowsException
# im here
# start line
# end line
# fromEnvWhenUserPropertyIsMalformedThrowsException
# im here
# start line
# end line
# fromEnvWhenGroupPropertyIsMalformedThrowsException
# im here
# start line
# end line
# fromImageWhenImageIsNullThrowsException
# im here
# start line
# end line
# fromImageWhenLabelIsMissingHasNoId
# im here
# start line
# end line
# fromImageCreatesStackId
# im here
# start line
# end line
# ofCreatesStackId
# im here
# start line
# end line
# equalsAndHashCode
# im here
# start line
# end line
# toStringReturnsValue
# im here
# start line
# end line
# findsLatestWhenOneMatchesMajor
# im here
# start line
# end line
# findsLatestWhenOneMatchesWithReleaseVersions
# im here
# start line
# end line
# findsLatestWhenOneMatchesWithPreReleaseVersions
# im here
# start line
# end line
# findsLatestWhenMultipleMatchesWithReleaseVersions
# im here
# start line
# end line
# findsLatestWhenMultipleMatchesWithPreReleaseVersions
# im here
# start line
# end line
# findLatestWhenNoneSupportedThrowsException
# im here
# start line
# end line
# createFromRange
# im here
# start line
# end line
# toStringReturnsString
# im here
# start line
# end line
# equalsAndHashCode
# im here
# start line
# end line
# create
# im here
# start line
# end line
# createWhenOperationIsNull
# im here
# start line
# end line
# fromToml
# im here
# start line
# end line
# fromTomlWhenMissingDescriptorThrowsException
# im here
# start line
# end line
# fromTomlWhenMissingIDThrowsException
# im here
# start line
# end line
# fromTomlWhenMissingVersionThrowsException
# im here
# start line
# end line
# fromTomlWhenMissingStacksAndOrderThrowsException
# im here
# start line
# end line
# fromTomlWhenContainsBothStacksAndOrderThrowsException
# im here
# start line
# end line
# fromBuildpackMetadataWhenMetadataIsNullThrowsException
# im here
# start line
# end line
# fromBuildpackMetadataReturnsCoordinates
# im here
# start line
# end line
# ofWhenIdIsNullThrowsException
# im here
# start line
# end line
# ofReturnsCoordinates
# im here
# start line
# end line
# getIdReturnsId
# im here
# start line
# end line
# getVersionReturnsVersion
# im here
# start line
# end line
# getVersionWhenVersionIsNullReturnsNull
# im here
# start line
# end line
# toStringReturnsNiceString
# im here
# start line
# end line
# equalsAndHashCode
# im here
# start line
# end line
# createTomlStream
# im here
# start line
# end line
# setup
# im here
# start line
# end line
# executeExecutesPhases
# im here
# start line
# end line
# executeWithBindingsExecutesPhases
# im here
# start line
# end line
# executeExecutesPhasesWithPlatformApi03
# im here
# start line
# end line
# executeOnlyUploadsContentOnce
# im here
# start line
# end line
# executeWhenAlreadyRunThrowsException
# im here
# start line
# end line
# executeWhenBuilderReturnsErrorThrowsException
# im here
# start line
# end line
# executeWhenCleanCacheClearsCache
# im here
# start line
# end line
# executeWhenPlatformApiNotSupportedThrowsException
# im here
# start line
# end line
# executeWhenMultiplePlatformApisNotSupportedThrowsException
# im here
# start line
# end line
# executeWhenMultiplePlatformApisSupportedExecutesPhase
# im here
# start line
# end line
# closeClearsVolumes
# im here
# start line
# end line
# executeWithNetworkExecutesPhases
# im here
# start line
# end line
# executeWithCacheVolumeNamesExecutesPhases
# im here
# start line
# end line
# executeWithCacheBindMountsExecutesPhases
# im here
# start line
# end line
# executeWithCreatedDateExecutesPhases
# im here
# start line
# end line
# executeWithApplicationDirectoryExecutesPhases
# im here
# start line
# end line
# executeWithSecurityOptionsExecutesPhases
# im here
# start line
# end line
# executeWithDockerHostAndRemoteAddressExecutesPhases
# im here
# start line
# end line
# executeWithDockerHostAndLocalAddressExecutesPhases
# im here
# start line
# end line
# executeWithImagePlatformExecutesPhases
# im here
# start line
# end line
# mockDockerApi
# im here
# start line
# end line
# getTestRequest
# im here
# start line
# end line
# createLifecycle
# im here
# start line
# end line
# createLifecycle
# im here
# start line
# end line
# createLifecycle
# im here
# start line
# end line
# createLifecycle
# im here
# start line
# end line
# createLifecycle
# im here
# start line
# end line
# mockEphemeralBuilder
# im here
# start line
# end line
# mockEphemeralBuilder
# im here
# start line
# end line
# answerWithGeneratedContainerId
# im here
# start line
# end line
# getCommand
# im here
# start line
# end line
# assertPhaseWasRun
# im here
# start line
# end line
# withExpectedConfig
# im here
# start line
# end line
# withExpectedConfig
# im here
# start line
# end line
# createRandomVolumeName
# im here
# start line
# end line
# toString
# im here
# start line
# end line
# setup
# im here
# start line
# end line
# getNameHasRandomName
# im here
# start line
# end line
# getArchiveHasCreatedByConfig
# im here
# start line
# end line
# getArchiveHasTag
# im here
# start line
# end line
# getArchiveHasFixedCreatedDate
# im here
# start line
# end line
# getArchiveContainsEnvLayer
# im here
# start line
# end line
# getArchiveHasBuilderForLabel
# im here
# start line
# end line
# getArchiveContainsBuildpackLayers
# im here
# start line
# end line
# getArchiveHasApplicationDirectoryLayer
# im here
# start line
# end line
# assertBuildpackLayerContent
# im here
# start line
# end line
# getLayer
# im here
# start line
# end line
# unpack
# im here
# start line
# end line
# content
# im here
# start line
# end line
# parseWhenValueIsNullThrowsException
# im here
# start line
# end line
# parseWhenTooLongThrowsException
# im here
# start line
# end line
# parseWhenNonNumericThrowsException
# im here
# start line
# end line
# compareTo
# im here
# start line
# end line
# isEqualOrGreaterThan
# im here
# start line
# end line
# parseReturnsVersion
# im here
# start line
# end line
# fromImageLoadsMetadata
# im here
# start line
# end line
# fromImageWhenImageIsNullThrowsException
# im here
# start line
# end line
# fromImageWhenImageConfigIsNullThrowsException
# im here
# start line
# end line
# fromImageConfigWhenLabelIsMissingThrowsException
# im here
# start line
# end line
# fromJsonLoadsMetadata
# im here
# start line
# end line
# setUp
# im here
# start line
# end line
# resolveWhenFullyQualifiedBuildpackWithVersionResolves
# im here
# start line
# end line
# resolveWhenFullyQualifiedBuildpackWithoutVersionResolves
# im here
# start line
# end line
# resolveWhenUnqualifiedBuildpackWithVersionResolves
# im here
# start line
# end line
# resolveWhenUnqualifiedBuildpackWithoutVersionResolves
# im here
# start line
# end line
# resolveWhenFullyQualifiedBuildpackWithVersionNotInBuilderThrowsException
# im here
# start line
# end line
# resolveWhenFullyQualifiedBuildpackWithoutVersionNotInBuilderThrowsException
# im here
# start line
# end line
# resolveWhenUnqualifiedBuildpackNotInBuilderReturnsNull
# im here
# start line
# end line
# assertThatNoLayersAreAdded
# im here
# start line
# end line
# forJarFileReturnsRequest
# im here
# start line
# end line
# forJarFileWithNameReturnsRequest
# im here
# start line
# end line
# forJarFileWhenJarFileIsNullThrowsException
# im here
# start line
# end line
# forJarFileWhenJarFileIsMissingThrowsException
# im here
# start line
# end line
# forJarFileWhenJarFileIsDirectoryThrowsException
# im here
# start line
# end line
# withBuilderUpdatesBuilder
# im here
# start line
# end line
# withBuilderWhenHasDigestUpdatesBuilder
# im here
# start line
# end line
# withoutBuilderTrustsDefaultBuilder
# im here
# start line
# end line
# withoutBuilderTrustsDefaultBuilderWithDifferentTag
# im here
# start line
# end line
# withoutBuilderTrustsDefaultBuilderWithDigest
# im here
# start line
# end line
# withKnownTrustedBuilderTrustsBuilder
# im here
# start line
# end line
# trustedBuilders
# im here
# start line
# end line
# withoutTrustBuilderAndDefaultBuilderUpdatesTrustsBuilder
# im here
# start line
# end line
# withTrustBuilderAndBuilderUpdatesTrustBuilder
# im here
# start line
# end line
# withRunImageUpdatesRunImage
# im here
# start line
# end line
# withRunImageWhenHasDigestUpdatesRunImage
# im here
# start line
# end line
# withCreatorUpdatesCreator
# im here
# start line
# end line
# withEnvAddsEnvEntry
# im here
# start line
# end line
# withEnvMapAddsEnvEntries
# im here
# start line
# end line
# withEnvWhenKeyIsNullThrowsException
# im here
# start line
# end line
# withEnvWhenValueIsNullThrowsException
# im here
# start line
# end line
# withBuildpacksAddsBuildpacks
# im here
# start line
# end line
# withBuildpacksWhenBuildpacksIsNullThrowsException
# im here
# start line
# end line
# withBindingsAddsBindings
# im here
# start line
# end line
# withBindingsWhenBindingsIsNullThrowsException
# im here
# start line
# end line
# withNetworkUpdatesNetwork
# im here
# start line
# end line
# withTagsAddsTags
# im here
# start line
# end line
# withTagsWhenTagsIsNullThrowsException
# im here
# start line
# end line
# withBuildWorkspaceVolumeAddsWorkspace
# im here
# start line
# end line
# withBuildWorkspaceBindAddsWorkspace
# im here
# start line
# end line
# withBuildVolumeCacheAddsCache
# im here
# start line
# end line
# withBuildBindCacheAddsCache
# im here
# start line
# end line
# withBuildVolumeCacheWhenCacheIsNullThrowsException
# im here
# start line
# end line
# withLaunchVolumeCacheAddsCache
# im here
# start line
# end line
# withLaunchBindCacheAddsCache
# im here
# start line
# end line
# withLaunchVolumeCacheWhenCacheIsNullThrowsException
# im here
# start line
# end line
# withCreatedDateSetsCreatedDate
# im here
# start line
# end line
# withCreatedDateNowSetsCreatedDate
# im here
# start line
# end line
# withCreatedDateAndInvalidDateThrowsException
# im here
# start line
# end line
# withApplicationDirectorySetsApplicationDirectory
# im here
# start line
# end line
# withSecurityOptionsSetsSecurityOptions
# im here
# start line
# end line
# withPlatformSetsPlatform
# im here
# start line
# end line
# hasExpectedJarContent
# im here
# start line
# end line
# writeTestJarFile
# im here
# start line
# end line
# writeTestJarFile
# im here
# start line
# end line
# ofWhenValueIsEmptyThrowsException
# im here
# start line
# end line
# ofCreatesInstance
# im here
# start line
# end line
# toStringReturnsValue
# im here
# start line
# end line
# equalsAndHashCode
# im here
# start line
# end line
# hasPrefixWhenPrefixMatchReturnsTrue
# im here
# start line
# end line
# hasPrefixWhenPrefixMismatchReturnsFalse
# im here
# start line
# end line
# getSubReferenceWhenPrefixMatchReturnsSubReference
# im here
# start line
# end line
# getSubReferenceWhenPrefixMismatchReturnsNull
# im here
# start line
# end line
# asPathWhenFileUrlReturnsPath
# im here
# start line
# end line
# asPathWhenPathReturnsPath
# im here
# start line
# end line
# ofWhenBuildpacksIsNullReturnsEmpty
# im here
# start line
# end line
# ofReturnsBuildpacks
# im here
# start line
# end line
# applyWritesLayersAndOrderLayer
# im here
# start line
# end line
# assertThatLayerContentIsCorrect
# im here
# start line
# end line
# assertThatOrderLayerContentIsCorrect
# im here
# start line
# end line
# getExpectedToml
# Could not parse spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/build/TestTarGzip.java:
# im here
# start line
# end line
# printsExpectedOutput
# im here
# start line
# end line
# mockLogEvent
# im here
# start line
# end line
# toString
# im here
# start line
# end line
# setUp
# im here
# start line
# end line
# resolveWhenPath
# im here
# start line
# end line
# resolveWhenFileUrl
# im here
# start line
# end line
# resolveWhenDirectoryWithoutBuildpackTomlThrowsException
# im here
# start line
# end line
# resolveWhenFileReturnsNull
# im here
# start line
# end line
# resolveWhenDirectoryDoesNotExistReturnsNull
# im here
# start line
# end line
# locateDirectoryAsUrlThatDoesNotExistThrowsException
# im here
# start line
# end line
# assertHasExpectedLayers
# im here
# start line
# end line
# writeBuildpackDescriptor
# im here
# start line
# end line
# writeScripts
# im here
# start line
# end line
# fromImageLoadsMetadata
# im here
# start line
# end line
# fromImageWithoutStackLoadsMetadata
# im here
# start line
# end line
# fromImageWhenImageIsNullThrowsException
# im here
# start line
# end line
# fromImageWhenImageConfigIsNullThrowsException
# im here
# start line
# end line
# fromImageConfigWhenLabelIsMissingThrowsException
# im here
# start line
# end line
# fromJsonLoadsMetadataWithoutSupportedApis
# im here
# start line
# end line
# fromJsonLoadsMetadataWithSupportedApis
# im here
# start line
# end line
# copyWithUpdatedCreatedByReturnsNewMetadata
# im here
# start line
# end line
# attachToUpdatesMetadata
# im here
# start line
# end line
# createWhenLogIsNullThrowsException
# im here
# start line
# end line
# createWithDockerConfiguration
# im here
# start line
# end line
# createDockerApiWithLogDockerLogDelegate
# im here
# start line
# end line
# createDockerApiWithLogDockerSystemOutDelegate
# im here
# start line
# end line
# buildWhenRequestIsNullThrowsException
# im here
# start line
# end line
# buildInvokesBuilder
# im here
# start line
# end line
# buildInvokesBuilderAndPublishesImage
# im here
# start line
# end line
# buildInvokesBuilderWithDefaultImageTags
# im here
# start line
# end line
# buildInvokesBuilderWithRunImageInDigestForm
# im here
# start line
# end line
# buildInvokesBuilderWithNoStack
# im here
# start line
# end line
# buildInvokesBuilderWithRunImageFromRequest
# im here
# start line
# end line
# buildInvokesBuilderWithNeverPullPolicy
# im here
# start line
# end line
# buildInvokesBuilderWithAlwaysPullPolicy
# im here
# start line
# end line
# buildInvokesBuilderWithIfNotPresentPullPolicy
# im here
# start line
# end line
# buildInvokesBuilderWithTags
# im here
# start line
# end line
# buildInvokesBuilderWithTagsAndPublishesImageAndTags
# im here
# start line
# end line
# buildInvokesBuilderWithPlatform
# im here
# start line
# end line
# buildWhenStackIdDoesNotMatchThrowsException
# im here
# start line
# end line
# buildWhenBuilderReturnsErrorThrowsException
# im here
# start line
# end line
# buildWhenRequestedBuildpackNotInBuilderThrowsException
# im here
# start line
# end line
# logsWarningIfBindingWithSensitiveTargetIsDetected
# im here
# start line
# end line
# mockDockerApi
# im here
# start line
# end line
# mockDockerApi
# im here
# start line
# end line
# mockDockerApiLifecycleError
# im here
# start line
# end line
# getTestRequest
# im here
# start line
# end line
# loadImage
# im here
# start line
# end line
# withPulledImage
# im here
# start line
# end line
# regAuthEq
# im here
# start line
# end line
# toString
# im here
# start line
# end line
# setUp
# im here
# start line
# end line
# resolveWhenFullyQualifiedReferenceReturnsBuildpack
# im here
# start line
# end line
# resolveWhenUnqualifiedReferenceReturnsBuildpack
# im here
# start line
# end line
# resolveReferenceWithoutTagUsesLatestTag
# im here
# start line
# end line
# resolveReferenceWithDigestUsesDigest
# im here
# start line
# end line
# resolveWhenBuildpackExistsInBuilderSkipsLayers
# im here
# start line
# end line
# resolveWhenWhenImageNotPulledThrowsException
# im here
# start line
# end line
# resolveWhenMissingMetadataLabelThrowsException
# im here
# start line
# end line
# resolveWhenFullyQualifiedReferenceWithInvalidImageReferenceThrowsException
# im here
# start line
# end line
# resolveWhenUnqualifiedReferenceWithInvalidImageReferenceReturnsNull
# im here
# start line
# end line
# withMockLayers
# im here
# start line
# end line
# writeTarEntry
# im here
# start line
# end line
# assertAppliesExpectedLayers
# im here
# start line
# end line
# assertAppliesNoLayers
# im here
# start line
# end line
# acquireReturnsHandle
# im here
# start line
# end line
# acquireWhenClosedReturnsClosedHandle
# im here
# start line
# end line
# acquireWhenPendingCloseReturnsClosedHandle
# im here
# start line
# end line
# finalizeTriggersClose
# im here
# start line
# end line
# closeWhenHandleAcquiredClosesOnRelease
# im here
# start line
# end line
# closeWhenHandleNotAcquiredClosesImmediately
# im here
# start line
# end line
# close
# im here
# start line
# end line
# pullImage
# im here
# start line
# end line
# getStream
# im here
# start line
# end line
# getErrorDetail
# im here
# start line
# end line
# getMessage
# im here
# start line
# end line
# toString
# im here
# start line
# end line
# getErrorDetail
# im here
# start line
# end line
# getMessage
# im here
# start line
# end line
# toString
# im here
# start line
# end line
# accept
# im here
# start line
# end line
# getId
# im here
# start line
# end line
# onStart
# im here
# start line
# end line
# onUpdate
# im here
# start line
# end line
# onFinish
# im here
# start line
# end line
# publish
# im here
# start line
# end line
# withinPercentageBounds
# im here
# start line
# end line
# update
# im here
# start line
# end line
# updateProgress
# im here
# start line
# end line
# finish
# im here
# start line
# end line
# getProgress
# Could not parse spring-boot/buildpack/spring-boot-buildpack-platform/src/main/java/org/springframework/boot/buildpack/platform/docker/LogUpdateEvent.java:
# im here
# start line
# end line
# log
# im here
# start line
# end line
# toSystemOut
# im here
# start line
# end line
# to
# im here
# start line
# end line
# onStart
# im here
# start line
# end line
# onUpdate
# im here
# start line
# end line
# onFinish
# im here
# start line
# end line
# none
# im here
# start line
# end line
# getStatus
# im here
# start line
# end line
# getProgressDetail
# im here
# start line
# end line
# getProgress
# im here
# start line
# end line
# asPercentage
# im here
# start line
# end line
# isEmpty
# im here
# start line
# end line
# getPercent
# Could not parse spring-boot/buildpack/spring-boot-buildpack-platform/src/main/java/org/springframework/boot/buildpack/platform/docker/DockerApi.java:
# im here
# start line
# end line
# exportLayers
# im here
# start line
# end line
# openTar
# im here
# start line
# end line
# close
# im here
# start line
# end line
# getLayerArchive
# im here
# start line
# end line
# create
# im here
# start line
# end line
# withNestedIndexes
# im here
# start line
# end line
# getDigests
# im here
# start line
# end line
# getDigests
# im here
# start line
# end line
# getManifestLists
# im here
# start line
# end line
# getManifests
# im here
# start line
# end line
# getDigestMatches
# im here
# start line
# end line
# isManifest
# im here
# start line
# end line
# isIndex
# im here
# start line
# end line
# isManifestList
# im here
# start line
# end line
# isJsonWithPrefix
# im here
# start line
# end line
# getEntryName
# im here
# start line
# end line
# getEntryName
# im here
# start line
# end line
# getLayerArchive
# im here
# start line
# end line
# getCompression
# im here
# start line
# end line
# getLayerArchive
# im here
# start line
# end line
# getAddress
# im here
# start line
# end line
# isSecure
# im here
# start line
# end line
# getCertificatePath
# Could not parse spring-boot/buildpack/spring-boot-buildpack-platform/src/main/java/org/springframework/boot/buildpack/platform/docker/configuration/DockerRegistryConfigAuthentication.java:
# Could not parse spring-boot/buildpack/spring-boot-buildpack-platform/src/main/java/org/springframework/boot/buildpack/platform/docker/configuration/DockerConnectionConfiguration.java:
# im here
# start line
# end line
# getConfiguration
# im here
# start line
# end line
# getContext
# im here
# start line
# end line
# forContext
# im here
# start line
# end line
# from
# im here
# start line
# end line
# create
# im here
# start line
# end line
# getUserHomeConfigLocation
# im here
# start line
# end line
# createDockerConfig
# im here
# start line
# end line
# createDockerContext
# im here
# start line
# end line
# asHash
# im here
# start line
# end line
# readPathContent
# im here
# start line
# end line
# getCurrentContext
# im here
# start line
# end line
# getCredsStore
# im here
# start line
# end line
# getCredHelpers
# im here
# start line
# end line
# getAuths
# im here
# start line
# end line
# fromJson
# im here
# start line
# end line
# empty
# im here
# start line
# end line
# getUsername
# im here
# start line
# end line
# getPassword
# im here
# start line
# end line
# getEmail
# im here
# start line
# end line
# trim
# im here
# start line
# end line
# getDockerHost
# im here
# start line
# end line
# isTlsVerify
# im here
# start line
# end line
# getTlsPath
# im here
# start line
# end line
# withTlsPath
# im here
# start line
# end line
# fromJson
# im here
# start line
# end line
# empty
# im here
# start line
# end line
# extractSecret
# im here
# start line
# end line
# extractUsername
# im here
# start line
# end line
# getUsername
# im here
# start line
# end line
# getSecret
# im here
# start line
# end line
# getServerUrl
# im here
# start line
# end line
# isIdentityToken
# im here
# start line
# end line
# getUsername
# im here
# start line
# end line
# getPassword
# im here
# start line
# end line
# getUrl
# im here
# start line
# end line
# getEmail
# im here
# start line
# end line
# getAuthHeader
# im here
# start line
# end line
# getAuthHeader
# im here
# start line
# end line
# token
# im here
# start line
# end line
# user
# im here
# start line
# end line
# configuration
# im here
# start line
# end line
# configuration
# im here
# start line
# end line
# getAuthHeader
# im here
# start line
# end line
# createAuthHeader
# im here
# start line
# end line
# get
# im here
# start line
# end line
# processBuilder
# im here
# start line
# end line
# start
# im here
# start line
# end line
# isCredentialsNotFoundError
# Could not parse spring-boot/buildpack/spring-boot-buildpack-platform/src/main/java/org/springframework/boot/buildpack/platform/docker/configuration/ResolvedDockerHost.java:
# im here
# start line
# end line
# getToken
# Could not parse spring-boot/buildpack/spring-boot-buildpack-platform/src/main/java/org/springframework/boot/buildpack/platform/docker/ssl/PemPrivateKeyParser.java:
# im here
# start line
# end line
# forDirectory
# im here
# start line
# end line
# getKeyManagerFactory
# im here
# start line
# end line
# getTrustManagerFactory
# im here
# start line
# end line
# verifyCertificateFiles
# im here
# start line
# end line
# parse
# im here
# start line
# end line
# getCertificateFactory
# im here
# start line
# end line
# readCertificates
# im here
# start line
# end line
# decodeBase64
# Could not parse spring-boot/buildpack/spring-boot-buildpack-platform/src/main/java/org/springframework/boot/buildpack/platform/docker/ssl/KeyStoreFactory.java:
# im here
# start line
# end line
# getMessage
# im here
# start line
# end line
# toString
# im here
# start line
# end line
# getStatusCode
# im here
# start line
# end line
# getReasonPhrase
# im here
# start line
# end line
# getErrors
# im here
# start line
# end line
# getResponseMessage
# im here
# start line
# end line
# buildMessage
# im here
# start line
# end line
# buildMessage
# im here
# start line
# end line
# getCauseMessage
# im here
# start line
# end line
# createIfPossible
# im here
# start line
# end line
# createIfPossible
# im here
# start line
# end line
# create
# im here
# start line
# end line
# getTlsSocketStrategy
# Could not parse spring-boot/buildpack/spring-boot-buildpack-platform/src/main/java/org/springframework/boot/buildpack/platform/docker/transport/LocalHttpClientTransport.java:
# im here
# start line
# end line
# get
# im here
# start line
# end line
# post
# im here
# start line
# end line
# post
# im here
# start line
# end line
# post
# im here
# start line
# end line
# put
# im here
# start line
# end line
# delete
# im here
# start line
# end line
# head
# im here
# start line
# end line
# create
# im here
# start line
# end line
# getContent
# im here
# start line
# end line
# getHeader
# im here
# start line
# end line
# iterator
# im here
# start line
# end line
# stream
# im here
# start line
# end line
# isEmpty
# im here
# start line
# end line
# toString
# im here
# start line
# end line
# getCode
# im here
# start line
# end line
# getMessage
# im here
# start line
# end line
# toString
# Could not parse spring-boot/buildpack/spring-boot-buildpack-platform/src/main/java/org/springframework/boot/buildpack/platform/docker/transport/HttpClientTransport.java:
# im here
# start line
# end line
# getArchive
# im here
# start line
# end line
# getDestinationPath
# im here
# start line
# end line
# of
# im here
# start line
# end line
# of
# im here
# start line
# end line
# getArchive
# im here
# start line
# end line
# getDestinationPath
# im here
# start line
# end line
# extractStatusCode
# im here
# start line
# end line
# getStatusCode
# im here
# start line
# end line
# getWaitingErrorMessage
# im here
# start line
# end line
# of
# im here
# start line
# end line
# of
# im here
# start line
# end line
# oneOrMoreTimes
# im here
# start line
# end line
# zeroOrOnce
# im here
# start line
# end line
# compile
# im here
# start line
# end line
# length
# im here
# start line
# end line
# charAt
# im here
# start line
# end line
# subSequence
# im here
# start line
# end line
# toString
# im here
# start line
# end line
# of
# im here
# start line
# end line
# oneOf
# im here
# start line
# end line
# group
# Could not parse spring-boot/buildpack/spring-boot-buildpack-platform/src/main/java/org/springframework/boot/buildpack/platform/docker/type/ImageConfig.java:
# ...
# end line
# resolveItemMetadataProperty
# im here
# start line
# end line
# resolveItemDeprecation
# im here
# start line
# end line
# resolveType
# im here
# start line
# end line
# resolveDescription
# im here
# start line
# end line
# resolveDefaultValue
# im here
# start line
# end line
# resolveItemDeprecation
# im here
# start line
# end line
# isProperty
# im here
# start line
# end line
# process
# im here
# start line
# end line
# processMethod
# im here
# start line
# end line
# isPublic
# im here
# start line
# end line
# getMatchingGetter
# im here
# start line
# end line
# getMatchingSetter
# im here
# start line
# end line
# getMatchingAccessor
# im here
# start line
# end line
# isGetter
# im here
# start line
# end line
# isSetter
# im here
# start line
# end line
# isSetterReturnType
# im here
# start line
# end line
# getAccessorName
# im here
# start line
# end line
# lowerCaseFirstCharacter
# im here
# start line
# end line
# processField
# im here
# start line
# end line
# processRecordComponent
# im here
# start line
# end line
# getFields
# im here
# start line
# end line
# getRecordComponents
# im here
# start line
# end line
# getPublicGetters
# im here
# start line
# end line
# getPublicGetter
# im here
# start line
# end line
# getPublicSetter
# im here
# start line
# end line
# getPublicAccessor
# im here
# start line
# end line
# processing
# im here
# start line
# end line
# getModuleMetadataCollector
# im here
# start line
# end line
# getMetadataCollector
# im here
# start line
# end line
# getSourceTypes
# im here
# start line
# end line
# shouldBeMerged
# im here
# start line
# end line
# deletedInCurrentBuild
# im here
# start line
# end line
# processedInCurrentBuild
# Could not parse spring-boot/configuration-metadata/spring-boot-configuration-processor/src/main/java/org/springframework/boot/configurationprocessor/MetadataStore.java:
# im here
# start line
# end line
# getSetter
# im here
# start line
# end line
# isMarkedAsNested
# im here
# start line
# end line
# resolveDescription
# im here
# start line
# end line
# resolveDefaultValue
# im here
# start line
# end line
# resolveItemDeprecation
# im here
# start line
# end line
# isProperty
# im here
# start line
# end line
# getFieldValues
# im here
# start line
# end line
# accept
# im here
# start line
# end line
# invoke
# im here
# start line
# end line
# getName
# im here
# start line
# end line
# getType
# im here
# start line
# end line
# getInitializer
# im here
# start line
# end line
# getModifierFlags
# im here
# start line
# end line
# getFieldValues
# im here
# start line
# end line
# visitVariable
# im here
# start line
# end line
# getValue
# im here
# start line
# end line
# getValue
# im here
# start line
# end line
# getFactoryValue
# im here
# start line
# end line
# getFactoryValue
# im here
# start line
# end line
# getFieldValues
# im here
# start line
# end line
# getTree
# im here
# start line
# end line
# instance
# im here
# start line
# end line
# unwrap
# im here
# start line
# end line
# visitVariable
# im here
# start line
# end line
# getKind
# im here
# start line
# end line
# getLiteralValue
# im here
# start line
# end line
# getFactoryValue
# im here
# start line
# end line
# getSelectedMember
# im here
# start line
# end line
# getArrayExpression
# im here
# start line
# end line
# Member
# im here
# start line
# end line
# getInstance
# im here
# start line
# end line
# toString
# im here
# start line
# end line
# findClass
# im here
# start line
# end line
# findMethod
# im here
# start line
# end line
# findClass
# im here
# start line
# end line
# findMethod
# im here
# start line
# end line
# toDashedCase
# im here
# start line
# end line
# getReason
# im here
# start line
# end line
# setReason
# im here
# start line
# end line
# getReplacement
# im here
# start line
# end line
# setReplacement
# im here
# start line
# end line
# getSince
# im here
# start line
# end line
# setSince
# im here
# start line
# end line
# getLevel
# im here
# start line
# end line
# setLevel
# im here
# start line
# end line
# equals
# im here
# start line
# end line
# hashCode
# im here
# start line
# end line
# toString
# im here
# start line
# end line
# nullSafeEquals
# im here
# start line
# end line
# nullSafeHashCode
# im here
# start line
# end line
# getName
# im here
# start line
# end line
# getType
# im here
# start line
# end line
# compareTo
# im here
# start line
# end line
# forProperty
# im here
# start line
# end line
# equals
# im here
# start line
# end line
# hashCode
# im here
# start line
# end line
# toString
# im here
# start line
# end line
# add
# im here
# start line
# end line
# addIfMissing
# im here
# start line
# end line
# add
# im here
# start line
# end line
# add
# im here
# start line
# end line
# removeMetadata
# im here
# start line
# end line
# merge
# im here
# start line
# end line
# getItems
# im here
# start line
# end line
# getHints
# im here
# start line
# end line
# getIgnored
# im here
# start line
# end line
# mergeItemMetadata
# im here
# start line
# end line
# add
# im here
# start line
# end line
# findMatchingItemMetadata
# im here
# start line
# end line
# nullSafeEquals
# im here
# start line
# end line
# nestedPrefix
# im here
# start line
# end line
# flattenValues
# im here
# start line
# end line
# toString
# im here
# start line
# end line
# toCanonicalName
# im here
# start line
# end line
# getName
# im here
# start line
# end line
# getValues
# im here
# start line
# end line
# getProviders
# im here
# start line
# end line
# applyPrefix
# im here
# start line
# end line
# compareTo
# im here
# start line
# end line
# newHint
# im here
# start line
# end line
# toString
# im here
# start line
# end line
# getValue
# im here
# start line
# end line
# getDescription
# im here
# start line
# end line
# toString
# im here
# start line
# end line
# getName
# im here
# start line
# end line
# getParameters
# im here
# start line
# end line
# toString
# Could not parse spring-boot/configuration-metadata/spring-boot-configuration-processor/src/main/java/org/springframework/boot/configurationprocessor/metadata/JsonMarshaller.java:
# im here
# start line
# end line
# toJsonArray
# im here
# start line
# end line
# toJsonArray
# im here
# start line
# end line
# toJsonObject
# im here
# start line
# end line
# ignoreToJsonArray
# im here
# start line
# end line
# toJsonObject
# im here
# start line
# end line
# toJsonObject
# im here
# start line
# end line
# toJsonObject
# im here
# start line
# end line
# getItemHintValues
# im here
# start line
# end line
# getItemHintValue
# im here
# start line
# end line
# getItemHintProviders
# im here
# start line
# end line
# getItemHintProvider
# im here
# start line
# end line
# putHintValue
# im here
# start line
# end line
# putDefaultValue
# im here
# start line
# end line
# extractItemValue
# im here
# start line
# end line
# compare
# im here
# start line
# end line
# isDeprecated
# im here
# start line
# end line
# getKind
# im here
# start line
# end line
# buildName
# im here
# start line
# end line
# isOfItemType
# im here
# start line
# end line
# hasSameType
# im here
# start line
# end line
# getName
# im here
# start line
# end line
# setName
# im here
# start line
# end line
# getType
# im here
# start line
# end line
# setType
# im here
# start line
# end line
# getDescription
# im here
# start line
# end line
# setDescription
# im here
# start line
# end line
# getSourceType
# im here
# start line
# end line
# setSourceType
# im here
# start line
# end line
# getSourceMethod
# im here
# start line
# end line
# setSourceMethod
# im here
# start line
# end line
# getDefaultValue
# im here
# start line
# end line
# setDefaultValue
# im here
# start line
# end line
# getDeprecation
# im here
# start line
# end line
# setDeprecation
# im here
# start line
# end line
# equals
# im here
# start line
# end line
# hashCode
# im here
# start line
# end line
# nullSafeEquals
# im here
# start line
# end line
# nullSafeHashCode
# im here
# start line
# end line
# toString
# im here
# start line
# end line
# buildToStringProperty
# im here
# start line
# end line
# compareTo
# im here
# start line
# end line
# newGroup
# im here
# start line
# end line
# newProperty
# im here
# start line
# end line
# newItemMetadataPrefix
# im here
# start line
# end line
# diffContainsDifferencesBetweenLeftAndRightInputs
# im here
# start line
# end line
# assertProperty
# im here
# start line
# end line
# load
# im here
# start line
# end line
# load
# im here
# start line
# end line
# generateChangeLog
# im here
# start line
# end line
# addJar
# im here
# start line
# end line
# writeChangelog
# Could not parse spring-boot/configuration-metadata/spring-boot-configuration-metadata-changelog-generator/src/main/java/org/springframework/boot/configurationmetadata/changelog/Changelog.java:
# Could not parse spring-boot/configuration-metadata/spring-boot-configuration-metadata-changelog-generator/src/main/java/org/springframework/boot/configurationmetadata/changelog/Difference.java:
# im here
# start line
# end line
# main
# im here
# start line
# end line
# generate
# im here
# start line
# end line
# buildRepository
# Could not parse spring-boot/configuration-metadata/spring-boot-configuration-metadata-changelog-generator/src/main/java/org/springframework/boot/configurationmetadata/changelog/ChangelogWriter.java:
# im here
# start line
# end line
# assertSource
# im here
# start line
# end line
# assertProperty
# im here
# start line
# end line
# assertItem
# im here
# start line
# end line
# getInputStreamFor
# im here
# start line
# end line
# extractFirstSentence
# im here
# start line
# end line
# extractFirstSentenceNewLineBeforeDot
# im here
# start line
# end line
# extractFirstSentenceNewLineBeforeDotWithSpaces
# im here
# start line
# end line
# extractFirstSentenceNoDot
# im here
# start line
# end line
# extractFirstSentenceNoDotMultipleLines
# im here
# start line
# end line
# extractFirstSentenceNull
# im here
# start line
# end line
# emptyMetadata
# im here
# start line
# end line
# invalidMetadata
# im here
# start line
# end line
# emptyGroupName
# im here
# start line
# end line
# simpleMetadata
# im here
# start line
# end line
# metadataHints
# im here
# start line
# end line
# rootMetadata
# im here
# start line
# end line
# deprecatedMetadata
# im here
# start line
# end line
# multiGroupsMetadata
# im here
# start line
# end line
# readFor
# im here
# start line
# end line
# nullResource
# im here
# start line
# end line
# simpleRepository
# im here
# start line
# end line
# hintsOnMaps
# im here
# start line
# end line
# severalRepositoriesNoConflict
# im here
# start line
# end line
# repositoryWithRoot
# im here
# start line
# end line
# severalRepositoriesIdenticalGroups
# im here
# start line
# end line
# severalRepositoriesIdenticalGroupsWithSameType
# im here
# start line
# end line
# severalRepositoriesIdenticalGroupsWithSameTypeDoesNotOverrideSource
# im here
# start line
# end line
# emptyGroups
# im here
# start line
# end line
# multiGroups
# im here
# start line
# end line
# builderInstancesAreIsolated
# im here
# start line
# end line
# validateFoo
# im here
# start line
# end line
# validateBar
# im here
# start line
# end line
# validateMap
# im here
# start line
# end line
# validateEmptyGroup
# im here
# start line
# end line
# validatePropertyHints
# im here
# start line
# end line
# contains
# im here
# start line
# end line
# length
# im here
# start line
# end line
# put
# im here
# start line
# end line
# put
# im here
# start line
# end line
# put
# im here
# start line
# end line
# put
# im here
# start line
# end line
# put
# im here
# start line
# end line
# put
# im here
# start line
# end line
# put
# im here
# start line
# end line
# put
# im here
# start line
# end line
# put
# im here
# start line
# end line
# put
# im here
# start line
# end line
# isNull
# im here
# start line
# end line
# get
# im here
# start line
# end line
# opt
# im here
# start line
# end line
# remove
# im here
# start line
# end line
# getBoolean
# im here
# start line
# end line
# optBoolean
# im here
# start line
# end line
# optBoolean
# im here
# start line
# end line
# getDouble
# im here
# start line
# end line
# optDouble
# im here
# start line
# end line
# optDouble
# im here
# start line
# end line
# getInt
# im here
# start line
# end line
# optInt
# im here
# start line
# end line
# optInt
# im here
# start line
# end line
# getLong
# im here
# start line
# end line
# optLong
# im here
# start line
# end line
# optLong
# im here
# start line
# end line
# getString
# im here
# start line
# end line
# optString
# im here
# start line
# end line
# optString
# im here
# start line
# end line
# getJSONArray
# im here
# start line
# end line
# optJSONArray
# im here
# start line
# end line
# getJSONObject
# im here
# start line
# end line
# optJSONObject
# im here
# start line
# end line
# toJSONObject
# im here
# start line
# end line
# join
# im here
# start line
# end line
# toString
# im here
# start line
# end line
# toString
# im here
# start line
# end line
# writeTo
# im here
# start line
# end line
# equals
# im here
# start line
# end line
# hashCode
# Could not parse spring-boot/configuration-metadata/spring-boot-configuration-metadata/src/json-shade/java/org/springframework/boot/configurationmetadata/json/JSONStringer.java:
# Could not parse spring-boot/configuration-metadata/spring-boot-configuration-metadata/src/json-shade/java/org/springframework/boot/configurationmetadata/json/JSONTokener.java:
# Could not parse spring-boot/configuration-metadata/spring-boot-configuration-metadata/src/json-shade/java/org/springframework/boot/configurationmetadata/json/JSON.java:
# Could not parse spring-boot/configuration-metadata/spring-boot-configuration-metadata/src/json-shade/java/org/springframework/boot/configurationmetadata/json/JSONObject.java:
# im here
# start line
# end line
# getValue
# im here
# start line
# end line
# setValue
# im here
# start line
# end line
# getDescription
# im here
# start line
# end line
# setDescription
# im here
# start line
# end line
# getShortDescription
# im here
# start line
# end line
# setShortDescription
# im here
# start line
# end line
# toString
# im here
# start line
# end line
# getId
# im here
# start line
# end line
# getSources
# im here
# start line
# end line
# getProperties
# im here
# start line
# end line
# isMapKeyHints
# im here
# start line
# end line
# isMapValueHints
# im here
# start line
# end line
# resolveId
# im here
# start line
# end line
# getId
# im here
# start line
# end line
# setId
# im here
# start line
# end line
# getValueHints
# im here
# start line
# end line
# getValueProviders
# im here
# start line
# end line
# getKeyHints
# im here
# start line
# end line
# getKeyProviders
# im here
# start line
# end line
# getValueHints
# im here
# start line
# end line
# getValueProviders
# im here
# start line
# end line
# getLevel
# im here
# start line
# end line
# setLevel
# im here
# start line
# end line
# getReason
# im here
# start line
# end line
# setReason
# im here
# start line
# end line
# getShortReason
# im here
# start line
# end line
# setShortReason
# im here
# start line
# end line
# getReplacement
# im here
# start line
# end line
# setReplacement
# im here
# start line
# end line
# toString
# im here
# start line
# end line
# getGroupId
# im here
# start line
# end line
# setGroupId
# im here
# start line
# end line
# getType
# im here
# start line
# end line
# setType
# im here
# start line
# end line
# getDescription
# im here
# start line
# end line
# setDescription
# im here
# start line
# end line
# getShortDescription
# im here
# start line
# end line
# setShortDescription
# im here
# start line
# end line
# getSourceType
# im here
# start line
# end line
# setSourceType
# im here
# start line
# end line
# getSourceMethod
# im here
# start line
# end line
# setSourceMethod
# im here
# start line
# end line
# getProperties
# im here
# start line
# end line
# getSources
# im here
# start line
# end line
# getSource
# im here
# start line
# end line
# getItems
# im here
# start line
# end line
# getHints
# im here
# start line
# end line
# resolveName
# im here
# start line
# end line
# hasLength
# im here
# start line
# end line
# getSourceType
# im here
# start line
# end line
# setSourceType
# im here
# start line
# end line
# getSourceMethod
# im here
# start line
# end line
# setSourceMethod
# im here
# start line
# end line
# getAllGroups
# im here
# start line
# end line
# getAllProperties
# Could not parse spring-boot/configuration-metadata/spring-boot-configuration-metadata/src/main/java/org/springframework/boot/configurationmetadata/JsonReader.java:
# im here
# start line
# end line
# getId
# im here
# start line
# end line
# setId
# im here
# start line
# end line
# getName
# im here
# start line
# end line
# setName
# im here
# start line
# end line
# getType
# im here
# start line
# end line
# setType
# im here
# start line
# end line
# getDescription
# im here
# start line
# end line
# setDescription
# im here
# start line
# end line
# getShortDescription
# im here
# start line
# end line
# setShortDescription
# im here
# start line
# end line
# getDefaultValue
# im here
# start line
# end line
# setDefaultValue
# im here
# start line
# end line
# getHints
# im here
# start line
# end line
# getDeprecation
# im here
# start line
# end line
# setDeprecation
# im here
# start line
# end line
# isDeprecated
# im here
# start line
# end line
# getAllGroups
# im here
# start line
# end line
# getAllProperties
# im here
# start line
# end line
# add
# im here
# start line
# end line
# add
# im here
# start line
# end line
# include
# im here
# start line
# end line
# getGroup
# im here
# start line
# end line
# addOrMergeSource
# im here
# start line
# end line
# getFirstSentence
# im here
# start line
# end line
# removeSpaceBetweenLine
# im here
# start line
# end line
# withJsonResource
# im here
# start line
# end line
# withJsonResource
# im here
# start line
# end line
# build
# im here
# start line
# end line
# add
# im here
# start line
# end line
# create
# im here
# start line
# end line
# addValueHints
# im here
# start line
# end line
# addMapHints
# im here
# start line
# end line
# create
# im here
# start line
# end line
# create
# im here
# start line
# end line
# create
# im here
# start line
# end line
# getName
# im here
# start line
# end line
# setName
# im here
# start line
# end line
# getParameters
# im here
# start line
# end line
# toString

# %%
methods
# Out:
# [{'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/ProgressUpdateEventTests.java',
#   'name': 'getStatusReturnsStatus',
#   'start_line': 36,
#   'end_line': 41,
#   'signature': 'void getStatusReturnsStatus()',
#   'code_tokens': ['void', 'getStatusReturnsStatus', '(', ')', '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/ProgressUpdateEventTests.java',
#   'name': 'getProgressDetailReturnsProgressDetails',
#   'start_line': 42,
#   'end_line': 47,
#   'signature': 'void getProgressDetailReturnsProgressDetails()',
#   'code_tokens': ['void',
#    'getProgressDetailReturnsProgressDetails',
#    '(',
#    ')',
#    '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/ProgressUpdateEventTests.java',
#   'name': 'getProgressDetailReturnsProgressDetailsForLongNumbers',
#   'start_line': 48,
#   'end_line': 53,
#   'signature': 'void getProgressDetailReturnsProgressDetailsForLongNumbers()',
#   'code_tokens': ['void',
#    'getProgressDetailReturnsProgressDetailsForLongNumbers',
#    '(',
#    ')',
#    '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/ProgressUpdateEventTests.java',
#   'name': 'getProgressReturnsProgress',
#   'start_line': 54,
#   'end_line': 58,
#   'signature': 'void getProgressReturnsProgress()',
#   'code_tokens': ['void', 'getProgressReturnsProgress', '(', ')', '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/ProgressUpdateEventTests.java',
#   'name': 'createEvent',
#   'start_line': 59,
#   'end_line': 62,
#   'signature': 'protected E createEvent()',
#   'code_tokens': ['protected', 'E', 'createEvent', '(', ')', '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/ProgressUpdateEventTests.java',
#   'name': 'createEvent',
#   'start_line': 63,
#   'end_line': 65,
#   'signature': 'abstract protected E createEvent(String status, ProgressDetail progressDetail, String progress)',
#   'code_tokens': ['abstract',
#    'protected',
#    'E',
#    'createEvent',
#    '(',
#    'String',
#    'status',
#    ',',
#    'ProgressDetail',
#    'progressDetail',
#    ',',
#    'String',
#    'progress',
#    ')',
#    '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/ExportedImageTarTests.java',
#   'name': 'test',
#   'start_line': 42,
#   'end_line': 59,
#   'signature': 'void test(String tarFile)',
#   'code_tokens': ['void', 'test', '(', 'String', 'tarFile', ')', '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/PushImageUpdateEventTests.java',
#   'name': 'getIdReturnsId',
#   'start_line': 33,
#   'end_line': 38,
#   'signature': 'void getIdReturnsId()',
#   'code_tokens': ['void', 'getIdReturnsId', '(', ')', '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/PushImageUpdateEventTests.java',
#   'name': 'getErrorReturnsErrorDetail',
#   'start_line': 39,
#   'end_line': 45,
#   'signature': 'void getErrorReturnsErrorDetail()',
#   'code_tokens': ['void', 'getErrorReturnsErrorDetail', '(', ')', '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/PushImageUpdateEventTests.java',
#   'name': 'createEvent',
#   'start_line': 46,
#   'end_line': 50,
#   'signature': 'protected PushImageUpdateEvent createEvent(String status, ProgressDetail progressDetail, String progress)',
#   'code_tokens': ['protected',
#    'PushImageUpdateEvent',
#    'createEvent',
#    '(',
#    'String',
#    'status',
#    ',',
#    'ProgressDetail',
#    'progressDetail',
#    ',',
#    'String',
#    'progress',
#    ')',
#    '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/DockerLogTests.java',
#   'name': 'toSystemOutPrintsToSystemOut',
#   'start_line': 36,
#   'end_line': 43,
#   'signature': 'void toSystemOutPrintsToSystemOut(CapturedOutput output)',
#   'code_tokens': ['void',
#    'toSystemOutPrintsToSystemOut',
#    '(',
#    'CapturedOutput',
#    'output',
#    ')',
#    '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/DockerLogTests.java',
#   'name': 'toPrintsToOutput',
#   'start_line': 44,
#   'end_line': 51,
#   'signature': 'void toPrintsToOutput(CapturedOutput output)',
#   'code_tokens': ['void',
#    'toPrintsToOutput',
#    '(',
#    'CapturedOutput',
#    'output',
#    ')',
#    '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/PullImageUpdateEventTests.java',
#   'name': 'getIdReturnsId',
#   'start_line': 34,
#   'end_line': 39,
#   'signature': 'void getIdReturnsId()',
#   'code_tokens': ['void', 'getIdReturnsId', '(', ')', '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/PullImageUpdateEventTests.java',
#   'name': 'createEvent',
#   'start_line': 40,
#   'end_line': 44,
#   'signature': 'protected PullImageUpdateEvent createEvent(String status, ProgressDetail progressDetail, String progress)',
#   'code_tokens': ['protected',
#    'PullImageUpdateEvent',
#    'createEvent',
#    '(',
#    'String',
#    'status',
#    ',',
#    'ProgressDetail',
#    'progressDetail',
#    ',',
#    'String',
#    'progress',
#    ')',
#    '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/TotalProgressListenerTests.java',
#   'name': 'totalProgress',
#   'start_line': 42,
#   'end_line': 55,
#   'signature': 'void totalProgress()',
#   'code_tokens': ['void', 'totalProgress', '(', ')', '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/TotalProgressListenerTests.java',
#   'name': 'totalProgressUpdatesSmoothly',
#   'start_line': 56,
#   'end_line': 60,
#   'signature': 'void totalProgressUpdatesSmoothly()',
#   'code_tokens': ['void', 'totalProgressUpdatesSmoothly', '(', ')', '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/TotalProgressListenerTests.java',
#   'name': 'run',
#   'start_line': 61,
#   'end_line': 74,
#   'signature': 'private void run(TestTotalProgressListener listener)',
#   'code_tokens': ['private',
#    'void',
#    'run',
#    '(',
#    'TestTotalProgressListener',
#    'listener',
#    ')',
#    '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/TotalProgressListenerTests.java',
#   'name': 'onUpdate',
#   'start_line': 75,
#   'end_line': 96,
#   'signature': 'public void onUpdate(TestImageUpdateEvent event)',
#   'code_tokens': ['public',
#    'void',
#    'onUpdate',
#    '(',
#    'TestImageUpdateEvent',
#    'event',
#    ')',
#    '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/DockerApiTests.java',
#   'name': 'setup',
#   'start_line': 112,
#   'end_line': 115,
#   'signature': 'void setup()',
#   'code_tokens': ['void', 'setup', '(', ')', '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/DockerApiTests.java',
#   'name': 'http',
#   'start_line': 116,
#   'end_line': 119,
#   'signature': 'private HttpTransport http()',
#   'code_tokens': ['private', 'HttpTransport', 'http', '(', ')', '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/DockerApiTests.java',
#   'name': 'emptyResponse',
#   'start_line': 120,
#   'end_line': 123,
#   'signature': 'private Response emptyResponse()',
#   'code_tokens': ['private', 'Response', 'emptyResponse', '(', ')', '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/DockerApiTests.java',
#   'name': 'responseOf',
#   'start_line': 124,
#   'end_line': 127,
#   'signature': 'private Response responseOf(String name)',
#   'code_tokens': ['private',
#    'Response',
#    'responseOf',
#    '(',
#    'String',
#    'name',
#    ')',
#    '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/DockerApiTests.java',
#   'name': 'close',
#   'start_line': 128,
#   'end_line': 131,
#   'signature': 'public void close()',
#   'code_tokens': ['public', 'void', 'close', '(', ')', '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/DockerApiTests.java',
#   'name': 'getContent',
#   'start_line': 132,
#   'end_line': 141,
#   'signature': 'public InputStream getContent()',
#   'code_tokens': ['public', 'InputStream', 'getContent', '(', ')', '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/DockerApiTests.java',
#   'name': 'responseWithHeaders',
#   'start_line': 142,
#   'end_line': 145,
#   'signature': 'private Response responseWithHeaders(Header... headers)',
#   'code_tokens': ['private',
#    'Response',
#    'responseWithHeaders',
#    '(',
#    'Header',
#    '.',
#    '.',
#    '.',
#    'headers',
#    ')',
#    '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/DockerApiTests.java',
#   'name': 'getContent',
#   'start_line': 146,
#   'end_line': 150,
#   'signature': 'public InputStream getContent()',
#   'code_tokens': ['public', 'InputStream', 'getContent', '(', ')', '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/DockerApiTests.java',
#   'name': 'getHeader',
#   'start_line': 151,
#   'end_line': 158,
#   'signature': 'public Header getHeader(String name)',
#   'code_tokens': ['public',
#    'Header',
#    'getHeader',
#    '(',
#    'String',
#    'name',
#    ')',
#    '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/DockerApiTests.java',
#   'name': 'close',
#   'start_line': 159,
#   'end_line': 165,
#   'signature': 'public void close()',
#   'code_tokens': ['public', 'void', 'close', '(', ')', '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/DockerApiTests.java',
#   'name': 'createDockerApi',
#   'start_line': 166,
#   'end_line': 188,
#   'signature': 'void createDockerApi()',
#   'code_tokens': ['void', 'createDockerApi', '(', ')', '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/DockerApiTests.java',
#   'name': 'setup',
#   'start_line': 189,
#   'end_line': 193,
#   'signature': 'void setup()',
#   'code_tokens': ['void', 'setup', '(', ')', '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/DockerApiTests.java',
#   'name': 'pullWhenReferenceIsNullThrowsException',
#   'start_line': 194,
#   'end_line': 199,
#   'signature': 'void pullWhenReferenceIsNullThrowsException()',
#   'code_tokens': ['void',
#    'pullWhenReferenceIsNullThrowsException',
#    '(',
#    ')',
#    '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/DockerApiTests.java',
#   'name': 'pullWhenListenerIsNullThrowsException',
#   'start_line': 200,
#   'end_line': 206,
#   'signature': 'void pullWhenListenerIsNullThrowsException()',
#   'code_tokens': ['void',
#    'pullWhenListenerIsNullThrowsException',
#    '(',
#    ')',
#    '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/DockerApiTests.java',
#   'name': 'pullPullsImageAndProducesEvents',
#   'start_line': 207,
#   'end_line': 221,
#   'signature': 'void pullPullsImageAndProducesEvents()',
#   'code_tokens': ['void', 'pullPullsImageAndProducesEvents', '(', ')', '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/DockerApiTests.java',
#   'name': 'pullWithRegistryAuthPullsImageAndProducesEvents',
#   'start_line': 222,
#   'end_line': 236,
#   'signature': 'void pullWithRegistryAuthPullsImageAndProducesEvents()',
#   'code_tokens': ['void',
#    'pullWithRegistryAuthPullsImageAndProducesEvents',
#    '(',
#    ')',
#    '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/DockerApiTests.java',
#   'name': 'pullWithPlatformPullsImageAndProducesEvents',
#   'start_line': 237,
#   'end_line': 255,
#   'signature': 'void pullWithPlatformPullsImageAndProducesEvents()',
#   'code_tokens': ['void',
#    'pullWithPlatformPullsImageAndProducesEvents',
#    '(',
#    ')',
#    '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/DockerApiTests.java',
#   'name': 'pullWithPlatformAndInsufficientApiVersionThrowsException',
#   'start_line': 256,
#   'end_line': 266,
#   'signature': 'void pullWithPlatformAndInsufficientApiVersionThrowsException()',
#   'code_tokens': ['void',
#    'pullWithPlatformAndInsufficientApiVersionThrowsException',
#    '(',
#    ')',
#    '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/DockerApiTests.java',
#   'name': 'pushWhenReferenceIsNullThrowsException',
#   'start_line': 267,
#   'end_line': 272,
#   'signature': 'void pushWhenReferenceIsNullThrowsException()',
#   'code_tokens': ['void',
#    'pushWhenReferenceIsNullThrowsException',
#    '(',
#    ')',
#    '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/DockerApiTests.java',
#   'name': 'pushWhenListenerIsNullThrowsException',
#   'start_line': 273,
#   'end_line': 279,
#   'signature': 'void pushWhenListenerIsNullThrowsException()',
#   'code_tokens': ['void',
#    'pushWhenListenerIsNullThrowsException',
#    '(',
#    ')',
#    '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/DockerApiTests.java',
#   'name': 'pushPushesImageAndProducesEvents',
#   'start_line': 280,
#   'end_line': 291,
#   'signature': 'void pushPushesImageAndProducesEvents()',
#   'code_tokens': ['void', 'pushPushesImageAndProducesEvents', '(', ')', '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/DockerApiTests.java',
#   'name': 'pushWithErrorInStreamThrowsException',
#   'start_line': 292,
#   'end_line': 301,
#   'signature': 'void pushWithErrorInStreamThrowsException()',
#   'code_tokens': ['void',
#    'pushWithErrorInStreamThrowsException',
#    '(',
#    ')',
#    '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/DockerApiTests.java',
#   'name': 'loadWhenArchiveIsNullThrowsException',
#   'start_line': 302,
#   'end_line': 307,
#   'signature': 'void loadWhenArchiveIsNullThrowsException()',
#   'code_tokens': ['void',
#    'loadWhenArchiveIsNullThrowsException',
#    '(',
#    ')',
#    '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/DockerApiTests.java',
#   'name': 'loadWhenListenerIsNullThrowsException',
#   'start_line': 308,
#   'end_line': 314,
#   'signature': 'void loadWhenListenerIsNullThrowsException()',
#   'code_tokens': ['void',
#    'loadWhenListenerIsNullThrowsException',
#    '(',
#    ')',
#    '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/DockerApiTests.java',
#   'name': 'loadWithEmptyResponseThrowsException',
#   'start_line': 315,
#   'end_line': 324,
#   'signature': 'void loadWithEmptyResponseThrowsException()',
#   'code_tokens': ['void',
#    'loadWithEmptyResponseThrowsException',
#    '(',
#    ')',
#    '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/DockerApiTests.java',
#   'name': 'loadWithErrorResponseThrowsException',
#   'start_line': 325,
#   'end_line': 334,
#   'signature': 'void loadWithErrorResponseThrowsException()',
#   'code_tokens': ['void',
#    'loadWithErrorResponseThrowsException',
#    '(',
#    ')',
#    '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/DockerApiTests.java',
#   'name': 'loadLoadsImage',
#   'start_line': 335,
#   'end_line': 351,
#   'signature': 'void loadLoadsImage()',
#   'code_tokens': ['void', 'loadLoadsImage', '(', ')', '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/DockerApiTests.java',
#   'name': 'removeWhenReferenceIsNullThrowsException',
#   'start_line': 352,
#   'end_line': 357,
#   'signature': 'void removeWhenReferenceIsNullThrowsException()',
#   'code_tokens': ['void',
#    'removeWhenReferenceIsNullThrowsException',
#    '(',
#    ')',
#    '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/DockerApiTests.java',
#   'name': 'removeRemovesContainer',
#   'start_line': 358,
#   'end_line': 368,
#   'signature': 'void removeRemovesContainer()',
#   'code_tokens': ['void', 'removeRemovesContainer', '(', ')', '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/DockerApiTests.java',
#   'name': 'removeWhenForceIsTrueRemovesContainer',
#   'start_line': 369,
#   'end_line': 379,
#   'signature': 'void removeWhenForceIsTrueRemovesContainer()',
#   'code_tokens': ['void',
#    'removeWhenForceIsTrueRemovesContainer',
#    '(',
#    ')',
#    '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/DockerApiTests.java',
#   'name': 'inspectWhenReferenceIsNullThrowsException',
#   'start_line': 380,
#   'end_line': 385,
#   'signature': 'void inspectWhenReferenceIsNullThrowsException()',
#   'code_tokens': ['void',
#    'inspectWhenReferenceIsNullThrowsException',
#    '(',
#    ')',
#    '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/DockerApiTests.java',
#   'name': 'inspectInspectImage',
#   'start_line': 386,
#   'end_line': 394,
#   'signature': 'void inspectInspectImage()',
#   'code_tokens': ['void', 'inspectInspectImage', '(', ')', '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/DockerApiTests.java',
#   'name': 'exportLayersExportsLayerTars',
#   'start_line': 395,
#   'end_line': 422,
#   'signature': 'void exportLayersExportsLayerTars()',
#   'code_tokens': ['void', 'exportLayersExportsLayerTars', '(', ')', '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/DockerApiTests.java',
#   'name': 'exportLayersWithSymlinksExportsLayerTars',
#   'start_line': 423,
#   'end_line': 450,
#   'signature': 'void exportLayersWithSymlinksExportsLayerTars()',
#   'code_tokens': ['void',
#    'exportLayersWithSymlinksExportsLayerTars',
#    '(',
#    ')',
#    '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/DockerApiTests.java',
#   'name': 'tagWhenReferenceIsNullThrowsException',
#   'start_line': 451,
#   'end_line': 457,
#   'signature': 'void tagWhenReferenceIsNullThrowsException()',
#   'code_tokens': ['void',
#    'tagWhenReferenceIsNullThrowsException',
#    '(',
#    ')',
#    '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/DockerApiTests.java',
#   'name': 'tagWhenTargetIsNullThrowsException',
#   'start_line': 458,
#   'end_line': 464,
#   'signature': 'void tagWhenTargetIsNullThrowsException()',
#   'code_tokens': ['void',
#    'tagWhenTargetIsNullThrowsException',
#    '(',
#    ')',
#    '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/DockerApiTests.java',
#   'name': 'tagTagsImage',
#   'start_line': 465,
#   'end_line': 474,
#   'signature': 'void tagTagsImage()',
#   'code_tokens': ['void', 'tagTagsImage', '(', ')', '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/DockerApiTests.java',
#   'name': 'tagRenamesImage',
#   'start_line': 475,
#   'end_line': 497,
#   'signature': 'void tagRenamesImage()',
#   'code_tokens': ['void', 'tagRenamesImage', '(', ')', '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/DockerApiTests.java',
#   'name': 'setup',
#   'start_line': 498,
#   'end_line': 502,
#   'signature': 'void setup()',
#   'code_tokens': ['void', 'setup', '(', ')', '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/DockerApiTests.java',
#   'name': 'createWhenConfigIsNullThrowsException',
#   'start_line': 503,
#   'end_line': 508,
#   'signature': 'void createWhenConfigIsNullThrowsException()',
#   'code_tokens': ['void',
#    'createWhenConfigIsNullThrowsException',
#    '(',
#    ')',
#    '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/DockerApiTests.java',
#   'name': 'createCreatesContainer',
#   'start_line': 509,
#   'end_line': 523,
#   'signature': 'void createCreatesContainer()',
#   'code_tokens': ['void', 'createCreatesContainer', '(', ')', '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/DockerApiTests.java',
#   'name': 'createWhenHasContentContainerWithContent',
#   'start_line': 524,
#   'end_line': 548,
#   'signature': 'void createWhenHasContentContainerWithContent()',
#   'code_tokens': ['void',
#    'createWhenHasContentContainerWithContent',
#    '(',
#    ')',
#    '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/DockerApiTests.java',
#   'name': 'createWithPlatformCreatesContainer',
#   'start_line': 549,
#   'end_line': 553,
#   'signature': 'void createWithPlatformCreatesContainer()',
#   'code_tokens': ['void',
#    'createWithPlatformCreatesContainer',
#    '(',
#    ')',
#    '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/DockerApiTests.java',
#   'name': 'createWithPlatformAndUnknownApiVersionAttemptsCreate',
#   'start_line': 554,
#   'end_line': 557,
#   'signature': 'void createWithPlatformAndUnknownApiVersionAttemptsCreate()',
#   'code_tokens': ['void',
#    'createWithPlatformAndUnknownApiVersionAttemptsCreate',
#    '(',
#    ')',
#    '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/DockerApiTests.java',
#   'name': 'createWithPlatform',
#   'start_line': 558,
#   'end_line': 577,
#   'signature': 'private void createWithPlatform(String apiVersion)',
#   'code_tokens': ['private',
#    'void',
#    'createWithPlatform',
#    '(',
#    'String',
#    'apiVersion',
#    ')',
#    '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/DockerApiTests.java',
#   'name': 'createWithPlatformAndKnownInsufficientApiVersionThrowsException',
#   'start_line': 578,
#   'end_line': 589,
#   'signature': 'void createWithPlatformAndKnownInsufficientApiVersionThrowsException()',
#   'code_tokens': ['void',
#    'createWithPlatformAndKnownInsufficientApiVersionThrowsException',
#    '(',
#    ')',
#    '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/DockerApiTests.java',
#   'name': 'startWhenReferenceIsNullThrowsException',
#   'start_line': 590,
#   'end_line': 595,
#   'signature': 'void startWhenReferenceIsNullThrowsException()',
#   'code_tokens': ['void',
#    'startWhenReferenceIsNullThrowsException',
#    '(',
#    ')',
#    '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/DockerApiTests.java',
#   'name': 'startStartsContainer',
#   'start_line': 596,
#   'end_line': 604,
#   'signature': 'void startStartsContainer()',
#   'code_tokens': ['void', 'startStartsContainer', '(', ')', '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/DockerApiTests.java',
#   'name': 'logsWhenReferenceIsNullThrowsException',
#   'start_line': 605,
#   'end_line': 610,
#   'signature': 'void logsWhenReferenceIsNullThrowsException()',
#   'code_tokens': ['void',
#    'logsWhenReferenceIsNullThrowsException',
#    '(',
#    ')',
#    '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/DockerApiTests.java',
#   'name': 'logsWhenListenerIsNullThrowsException',
#   'start_line': 611,
#   'end_line': 617,
#   'signature': 'void logsWhenListenerIsNullThrowsException()',
#   'code_tokens': ['void',
#    'logsWhenListenerIsNullThrowsException',
#    '(',
#    ')',
#    '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/DockerApiTests.java',
#   'name': 'logsProducesEvents',
#   'start_line': 618,
#   'end_line': 629,
#   'signature': 'void logsProducesEvents()',
#   'code_tokens': ['void', 'logsProducesEvents', '(', ')', '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/DockerApiTests.java',
#   'name': 'waitWhenReferenceIsNullThrowsException',
#   'start_line': 630,
#   'end_line': 635,
#   'signature': 'void waitWhenReferenceIsNullThrowsException()',
#   'code_tokens': ['void',
#    'waitWhenReferenceIsNullThrowsException',
#    '(',
#    ')',
#    '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/DockerApiTests.java',
#   'name': 'waitReturnsStatus',
#   'start_line': 636,
#   'end_line': 644,
#   'signature': 'void waitReturnsStatus()',
#   'code_tokens': ['void', 'waitReturnsStatus', '(', ')', '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/DockerApiTests.java',
#   'name': 'removeWhenReferenceIsNullThrowsException',
#   'start_line': 645,
#   'end_line': 650,
#   'signature': 'void removeWhenReferenceIsNullThrowsException()',
#   'code_tokens': ['void',
#    'removeWhenReferenceIsNullThrowsException',
#    '(',
#    ')',
#    '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/DockerApiTests.java',
#   'name': 'removeRemovesContainer',
#   'start_line': 651,
#   'end_line': 659,
#   'signature': 'void removeRemovesContainer()',
#   'code_tokens': ['void', 'removeRemovesContainer', '(', ')', '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/DockerApiTests.java',
#   'name': 'removeWhenForceIsTrueRemovesContainer',
#   'start_line': 660,
#   'end_line': 675,
#   'signature': 'void removeWhenForceIsTrueRemovesContainer()',
#   'code_tokens': ['void',
#    'removeWhenForceIsTrueRemovesContainer',
#    '(',
#    ')',
#    '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/DockerApiTests.java',
#   'name': 'setup',
#   'start_line': 676,
#   'end_line': 680,
#   'signature': 'void setup()',
#   'code_tokens': ['void', 'setup', '(', ')', '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/DockerApiTests.java',
#   'name': 'deleteWhenNameIsNullThrowsException',
#   'start_line': 681,
#   'end_line': 686,
#   'signature': 'void deleteWhenNameIsNullThrowsException()',
#   'code_tokens': ['void',
#    'deleteWhenNameIsNullThrowsException',
#    '(',
#    ')',
#    '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/DockerApiTests.java',
#   'name': 'deleteDeletesContainer',
#   'start_line': 687,
#   'end_line': 695,
#   'signature': 'void deleteDeletesContainer()',
#   'code_tokens': ['void', 'deleteDeletesContainer', '(', ')', '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/DockerApiTests.java',
#   'name': 'deleteWhenForceIsTrueDeletesContainer',
#   'start_line': 696,
#   'end_line': 711,
#   'signature': 'void deleteWhenForceIsTrueDeletesContainer()',
#   'code_tokens': ['void',
#    'deleteWhenForceIsTrueDeletesContainer',
#    '(',
#    ')',
#    '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/DockerApiTests.java',
#   'name': 'setup',
#   'start_line': 712,
#   'end_line': 716,
#   'signature': 'void setup()',
#   'code_tokens': ['void', 'setup', '(', ')', '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/DockerApiTests.java',
#   'name': 'getApiVersionWithVersionHeaderReturnsVersion',
#   'start_line': 717,
#   'end_line': 723,
#   'signature': 'void getApiVersionWithVersionHeaderReturnsVersion()',
#   'code_tokens': ['void',
#    'getApiVersionWithVersionHeaderReturnsVersion',
#    '(',
#    ')',
#    '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/DockerApiTests.java',
#   'name': 'getApiVersionWithEmptyVersionHeaderReturnsUnknownVersion',
#   'start_line': 724,
#   'end_line': 730,
#   'signature': 'void getApiVersionWithEmptyVersionHeaderReturnsUnknownVersion()',
#   'code_tokens': ['void',
#    'getApiVersionWithEmptyVersionHeaderReturnsUnknownVersion',
#    '(',
#    ')',
#    '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/DockerApiTests.java',
#   'name': 'getApiVersionWithNoVersionHeaderReturnsUnknownVersion',
#   'start_line': 731,
#   'end_line': 736,
#   'signature': 'void getApiVersionWithNoVersionHeaderReturnsUnknownVersion()',
#   'code_tokens': ['void',
#    'getApiVersionWithNoVersionHeaderReturnsUnknownVersion',
#    '(',
#    ')',
#    '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/DockerApiTests.java',
#   'name': 'getApiVersionWithExceptionReturnsUnknownVersion',
#   'start_line': 737,
#   'end_line': 745,
#   'signature': 'void getApiVersionWithExceptionReturnsUnknownVersion(CapturedOutput output)',
#   'code_tokens': ['void',
#    'getApiVersionWithExceptionReturnsUnknownVersion',
#    '(',
#    'CapturedOutput',
#    'output',
#    ')',
#    '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/LoadImageUpdateEventTests.java',
#   'name': 'getStreamReturnsStream',
#   'start_line': 35,
#   'end_line': 40,
#   'signature': 'void getStreamReturnsStream()',
#   'code_tokens': ['void', 'getStreamReturnsStream', '(', ')', '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/LoadImageUpdateEventTests.java',
#   'name': 'getErrorDetailReturnsErrorDetail',
#   'start_line': 41,
#   'end_line': 46,
#   'signature': 'void getErrorDetailReturnsErrorDetail()',
#   'code_tokens': ['void', 'getErrorDetailReturnsErrorDetail', '(', ')', '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/LoadImageUpdateEventTests.java',
#   'name': 'createEvent',
#   'start_line': 47,
#   'end_line': 52,
#   'signature': 'protected LoadImageUpdateEvent createEvent(String status, ProgressDetail progressDetail, String progress)',
#   'code_tokens': ['protected',
#    'LoadImageUpdateEvent',
#    'createEvent',
#    '(',
#    'String',
#    'status',
#    ',',
#    'ProgressDetail',
#    'progressDetail',
#    ',',
#    'String',
#    'progress',
#    ')',
#    '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/PullUpdateEventTests.java',
#   'name': 'readValueWhenFullDeserializesJson',
#   'start_line': 34,
#   'end_line': 43,
#   'signature': 'void readValueWhenFullDeserializesJson()',
#   'code_tokens': ['void', 'readValueWhenFullDeserializesJson', '(', ')', '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/PullUpdateEventTests.java',
#   'name': 'readValueWhenMinimalDeserializesJson',
#   'start_line': 44,
#   'end_line': 53,
#   'signature': 'void readValueWhenMinimalDeserializesJson()',
#   'code_tokens': ['void',
#    'readValueWhenMinimalDeserializesJson',
#    '(',
#    ')',
#    '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/PullUpdateEventTests.java',
#   'name': 'readValueWhenEmptyDetailsDeserializesJson',
#   'start_line': 54,
#   'end_line': 63,
#   'signature': 'void readValueWhenEmptyDetailsDeserializesJson()',
#   'code_tokens': ['void',
#    'readValueWhenEmptyDetailsDeserializesJson',
#    '(',
#    ')',
#    '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/LogUpdateEventTests.java',
#   'name': 'readAllWhenSimpleStreamReturnsEvents',
#   'start_line': 36,
#   'end_line': 47,
#   'signature': 'void readAllWhenSimpleStreamReturnsEvents()',
#   'code_tokens': ['void',
#    'readAllWhenSimpleStreamReturnsEvents',
#    '(',
#    ')',
#    '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/LogUpdateEventTests.java',
#   'name': 'readAllWhenAnsiStreamReturnsEvents',
#   'start_line': 48,
#   'end_line': 56,
#   'signature': 'void readAllWhenAnsiStreamReturnsEvents()',
#   'code_tokens': ['void',
#    'readAllWhenAnsiStreamReturnsEvents',
#    '(',
#    ')',
#    '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/LogUpdateEventTests.java',
#   'name': 'readSucceedsWhenStreamTypeIsInvalid',
#   'start_line': 57,
#   'end_line': 62,
#   'signature': 'void readSucceedsWhenStreamTypeIsInvalid()',
#   'code_tokens': ['void',
#    'readSucceedsWhenStreamTypeIsInvalid',
#    '(',
#    ')',
#    '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/LogUpdateEventTests.java',
#   'name': 'readAll',
#   'start_line': 63,
#   'end_line': 71,
#   'signature': 'private List<LogUpdateEvent> readAll(String name)',
#   'code_tokens': ['private',
#    'List',
#    '<',
#    'LogUpdateEvent',
#    '>',
#    'readAll',
#    '(',
#    'String',
#    'name',
#    ')',
#    '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/TotalProgressBarTests.java',
#   'name': 'withPrefixAndBookends',
#   'start_line': 34,
#   'end_line': 46,
#   'signature': 'void withPrefixAndBookends()',
#   'code_tokens': ['void', 'withPrefixAndBookends', '(', ')', '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/TotalProgressBarTests.java',
#   'name': 'withoutPrefix',
#   'start_line': 47,
#   'end_line': 59,
#   'signature': 'void withoutPrefix()',
#   'code_tokens': ['void', 'withoutPrefix', '(', ')', '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/TotalProgressBarTests.java',
#   'name': 'withoutBookends',
#   'start_line': 60,
#   'end_line': 78,
#   'signature': 'void withoutBookends()',
#   'code_tokens': ['void', 'withoutBookends', '(', ')', '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/TotalProgressBarTests.java',
#   'name': 'toString',
#   'start_line': 79,
#   'end_line': 85,
#   'signature': 'public String toString()',
#   'code_tokens': ['public', 'String', 'toString', '(', ')', '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/TotalProgressEventTests.java',
#   'name': 'create',
#   'start_line': 32,
#   'end_line': 38,
#   'signature': 'void create()',
#   'code_tokens': ['void', 'create', '(', ')', '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/TotalProgressEventTests.java',
#   'name': 'createWhenPercentLessThanZeroThrowsException',
#   'start_line': 39,
#   'end_line': 44,
#   'signature': 'void createWhenPercentLessThanZeroThrowsException()',
#   'code_tokens': ['void',
#    'createWhenPercentLessThanZeroThrowsException',
#    '(',
#    ')',
#    '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/TotalProgressEventTests.java',
#   'name': 'createWhenEventMoreThanOneHundredThrowsException',
#   'start_line': 45,
#   'end_line': 50,
#   'signature': 'void createWhenEventMoreThanOneHundredThrowsException()',
#   'code_tokens': ['void',
#    'createWhenEventMoreThanOneHundredThrowsException',
#    '(',
#    ')',
#    '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/configuration/DockerConfigurationMetadataTests.java',
#   'name': 'configWithContextIsRead',
#   'start_line': 47,
#   'end_line': 59,
#   'signature': 'void configWithContextIsRead()',
#   'code_tokens': ['void', 'configWithContextIsRead', '(', ')', '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/configuration/DockerConfigurationMetadataTests.java',
#   'name': 'configWithoutContextIsRead',
#   'start_line': 60,
#   'end_line': 72,
#   'signature': 'void configWithoutContextIsRead()',
#   'code_tokens': ['void', 'configWithoutContextIsRead', '(', ')', '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/configuration/DockerConfigurationMetadataTests.java',
#   'name': 'configWithDefaultContextIsRead',
#   'start_line': 73,
#   'end_line': 85,
#   'signature': 'void configWithDefaultContextIsRead()',
#   'code_tokens': ['void', 'configWithDefaultContextIsRead', '(', ')', '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/configuration/DockerConfigurationMetadataTests.java',
#   'name': 'configIsReadWithProvidedContext',
#   'start_line': 86,
#   'end_line': 96,
#   'signature': 'void configIsReadWithProvidedContext()',
#   'code_tokens': ['void', 'configIsReadWithProvidedContext', '(', ')', '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/configuration/DockerConfigurationMetadataTests.java',
#   'name': 'invalidContextThrowsException',
#   'start_line': 97,
#   'end_line': 104,
#   'signature': 'void invalidContextThrowsException()',
#   'code_tokens': ['void', 'invalidContextThrowsException', '(', ')', '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/configuration/DockerConfigurationMetadataTests.java',
#   'name': 'configIsEmptyWhenConfigFileDoesNotExist',
#   'start_line': 105,
#   'end_line': 116,
#   'signature': 'void configIsEmptyWhenConfigFileDoesNotExist()',
#   'code_tokens': ['void',
#    'configIsEmptyWhenConfigFileDoesNotExist',
#    '(',
#    ')',
#    '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/configuration/DockerConfigurationMetadataTests.java',
#   'name': 'configWithAuthIsRead',
#   'start_line': 117,
#   'end_line': 140,
#   'signature': 'void configWithAuthIsRead()',
#   'code_tokens': ['void', 'configWithAuthIsRead', '(', ')', '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/configuration/DockerConfigurationMetadataTests.java',
#   'name': 'pathToResource',
#   'start_line': 141,
#   'end_line': 146,
#   'signature': 'private String pathToResource(String resource)',
#   'code_tokens': ['private',
#    'String',
#    'pathToResource',
#    '(',
#    'String',
#    'resource',
#    ')',
#    '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/configuration/DockerRegistryTokenAuthenticationTests.java',
#   'name': 'createAuthHeaderReturnsEncodedHeader',
#   'start_line': 38,
#   'end_line': 45,
#   'signature': 'void createAuthHeaderReturnsEncodedHeader()',
#   'code_tokens': ['void',
#    'createAuthHeaderReturnsEncodedHeader',
#    '(',
#    ')',
#    '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/configuration/ResolvedDockerHostTests.java',
#   'name': 'resolveWhenDockerHostIsNullReturnsLinuxDefault',
#   'start_line': 48,
#   'end_line': 57,
#   'signature': 'void resolveWhenDockerHostIsNullReturnsLinuxDefault()',
#   'code_tokens': ['void',
#    'resolveWhenDockerHostIsNullReturnsLinuxDefault',
#    '(',
#    ')',
#    '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/configuration/ResolvedDockerHostTests.java',
#   'name': 'resolveWhenDockerHostIsNullReturnsWindowsDefault',
#   'start_line': 58,
#   'end_line': 67,
#   'signature': 'void resolveWhenDockerHostIsNullReturnsWindowsDefault()',
#   'code_tokens': ['void',
#    'resolveWhenDockerHostIsNullReturnsWindowsDefault',
#    '(',
#    ')',
#    '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/configuration/ResolvedDockerHostTests.java',
#   'name': 'resolveWhenUsingDefaultContextReturnsWindowsDefault',
#   'start_line': 68,
#   'end_line': 77,
#   'signature': 'void resolveWhenUsingDefaultContextReturnsWindowsDefault()',
#   'code_tokens': ['void',
#    'resolveWhenUsingDefaultContextReturnsWindowsDefault',
#    '(',
#    ')',
#    '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/configuration/ResolvedDockerHostTests.java',
#   'name': 'resolveWhenUsingDefaultContextReturnsLinuxDefault',
#   'start_line': 78,
#   'end_line': 86,
#   'signature': 'void resolveWhenUsingDefaultContextReturnsLinuxDefault()',
#   'code_tokens': ['void',
#    'resolveWhenUsingDefaultContextReturnsLinuxDefault',
#    '(',
#    ')',
#    '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/configuration/ResolvedDockerHostTests.java',
#   'name': 'resolveWhenDockerHostAddressIsLocalReturnsAddress',
#   'start_line': 87,
#   'end_line': 98,
#   'signature': 'void resolveWhenDockerHostAddressIsLocalReturnsAddress(Path tempDir)',
#   'code_tokens': ['void',
#    'resolveWhenDockerHostAddressIsLocalReturnsAddress',
#    '(',
#    'Path',
#    'tempDir',
#    ')',
#    '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/configuration/ResolvedDockerHostTests.java',
#   'name': 'resolveWhenDockerHostAddressIsLocalWithSchemeReturnsAddress',
#   'start_line': 99,
#   'end_line': 110,
#   'signature': 'void resolveWhenDockerHostAddressIsLocalWithSchemeReturnsAddress(Path tempDir)',
#   'code_tokens': ['void',
#    'resolveWhenDockerHostAddressIsLocalWithSchemeReturnsAddress',
#    '(',
#    'Path',
#    'tempDir',
#    ')',
#    '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/configuration/ResolvedDockerHostTests.java',
#   'name': 'resolveWhenDockerHostAddressIsHttpReturnsAddress',
#   'start_line': 111,
#   'end_line': 121,
#   'signature': 'void resolveWhenDockerHostAddressIsHttpReturnsAddress()',
#   'code_tokens': ['void',
#    'resolveWhenDockerHostAddressIsHttpReturnsAddress',
#    '(',
#    ')',
#    '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/configuration/ResolvedDockerHostTests.java',
#   'name': 'resolveWhenDockerHostAddressIsHttpsReturnsAddress',
#   'start_line': 122,
#   'end_line': 132,
#   'signature': 'void resolveWhenDockerHostAddressIsHttpsReturnsAddress()',
#   'code_tokens': ['void',
#    'resolveWhenDockerHostAddressIsHttpsReturnsAddress',
#    '(',
#    ')',
#    '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/configuration/ResolvedDockerHostTests.java',
#   'name': 'resolveWhenDockerHostAddressIsTcpReturnsAddress',
#   'start_line': 133,
#   'end_line': 143,
#   'signature': 'void resolveWhenDockerHostAddressIsTcpReturnsAddress()',
#   'code_tokens': ['void',
#    'resolveWhenDockerHostAddressIsTcpReturnsAddress',
#    '(',
#    ')',
#    '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/configuration/ResolvedDockerHostTests.java',
#   'name': 'resolveWhenEnvironmentAddressIsLocalReturnsAddress',
#   'start_line': 144,
#   'end_line': 156,
#   'signature': 'void resolveWhenEnvironmentAddressIsLocalReturnsAddress(Path tempDir)',
#   'code_tokens': ['void',
#    'resolveWhenEnvironmentAddressIsLocalReturnsAddress',
#    '(',
#    'Path',
#    'tempDir',
#    ')',
#    '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/configuration/ResolvedDockerHostTests.java',
#   'name': 'resolveWhenEnvironmentAddressIsLocalWithSchemeReturnsAddress',
#   'start_line': 157,
#   'end_line': 169,
#   'signature': 'void resolveWhenEnvironmentAddressIsLocalWithSchemeReturnsAddress(Path tempDir)',
#   'code_tokens': ['void',
#    'resolveWhenEnvironmentAddressIsLocalWithSchemeReturnsAddress',
#    '(',
#    'Path',
#    'tempDir',
#    ')',
#    '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/test/java/org/springframework/boot/buildpack/platform/docker/configuration/ResolvedDockerHostTests.java',
#   'name': 'resolveWhenEnvironmentAddressIsTcpReturnsAddress',
#   'start_line': 170,
#   'end_line': 183,
#   'signature': 'void resolveWhenEnvironmentAddressIsTcpReturnsAddress()',
#   'code_tokens': ['void',
#    'resolveWhenEnvironmentAddressIsTcpReturnsAddress',
#    '(',
#    ')',
#    '{']},
# ...
#   'name': 'writeTo',
#   'start_line': 64,
#   'end_line': 76,
#   'signature': 'public void writeTo(OutputStream outputStream)',
#   'code_tokens': ['public',
#    'void',
#    'writeTo',
#    '(',
#    'OutputStream',
#    'outputStream',
#    ')',
#    '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/main/java/org/springframework/boot/buildpack/platform/io/ZipFileTarArchive.java',
#   'name': 'assertArchiveHasEntries',
#   'start_line': 77,
#   'end_line': 85,
#   'signature': 'private void assertArchiveHasEntries(File file)',
#   'code_tokens': ['private',
#    'void',
#    'assertArchiveHasEntries',
#    '(',
#    'File',
#    'file',
#    ')',
#    '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/main/java/org/springframework/boot/buildpack/platform/io/ZipFileTarArchive.java',
#   'name': 'copy',
#   'start_line': 86,
#   'end_line': 94,
#   'signature': 'private void copy(ZipArchiveEntry zipEntry, InputStream zip, TarArchiveOutputStream tar)',
#   'code_tokens': ['private',
#    'void',
#    'copy',
#    '(',
#    'ZipArchiveEntry',
#    'zipEntry',
#    ',',
#    'InputStream',
#    'zip',
#    ',',
#    'TarArchiveOutputStream',
#    'tar',
#    ')',
#    '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/main/java/org/springframework/boot/buildpack/platform/io/ZipFileTarArchive.java',
#   'name': 'convert',
#   'start_line': 95,
#   'end_line': 108,
#   'signature': 'private TarArchiveEntry convert(ZipArchiveEntry zipEntry)',
#   'code_tokens': ['private',
#    'TarArchiveEntry',
#    'convert',
#    '(',
#    'ZipArchiveEntry',
#    'zipEntry',
#    ')',
#    '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/main/java/org/springframework/boot/buildpack/platform/io/TarLayoutWriter.java',
#   'name': 'directory',
#   'start_line': 47,
#   'end_line': 52,
#   'signature': 'public void directory(String name, Owner owner, int mode)',
#   'code_tokens': ['public',
#    'void',
#    'directory',
#    '(',
#    'String',
#    'name',
#    ',',
#    'Owner',
#    'owner',
#    ',',
#    'int',
#    'mode',
#    ')',
#    '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/main/java/org/springframework/boot/buildpack/platform/io/TarLayoutWriter.java',
#   'name': 'file',
#   'start_line': 53,
#   'end_line': 58,
#   'signature': 'public void file(String name, Owner owner, int mode, Content content)',
#   'code_tokens': ['public',
#    'void',
#    'file',
#    '(',
#    'String',
#    'name',
#    ',',
#    'Owner',
#    'owner',
#    ',',
#    'int',
#    'mode',
#    ',',
#    'Content',
#    'content',
#    ')',
#    '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/main/java/org/springframework/boot/buildpack/platform/io/TarLayoutWriter.java',
#   'name': 'createDirectoryEntry',
#   'start_line': 59,
#   'end_line': 62,
#   'signature': 'private TarArchiveEntry createDirectoryEntry(String name, Owner owner, int mode)',
#   'code_tokens': ['private',
#    'TarArchiveEntry',
#    'createDirectoryEntry',
#    '(',
#    'String',
#    'name',
#    ',',
#    'Owner',
#    'owner',
#    ',',
#    'int',
#    'mode',
#    ')',
#    '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/main/java/org/springframework/boot/buildpack/platform/io/TarLayoutWriter.java',
#   'name': 'createFileEntry',
#   'start_line': 63,
#   'end_line': 66,
#   'signature': 'private TarArchiveEntry createFileEntry(String name, Owner owner, int mode, int size)',
#   'code_tokens': ['private',
#    'TarArchiveEntry',
#    'createFileEntry',
#    '(',
#    'String',
#    'name',
#    ',',
#    'Owner',
#    'owner',
#    ',',
#    'int',
#    'mode',
#    ',',
#    'int',
#    'size',
#    ')',
#    '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/main/java/org/springframework/boot/buildpack/platform/io/TarLayoutWriter.java',
#   'name': 'createEntry',
#   'start_line': 67,
#   'end_line': 76,
#   'signature': 'private TarArchiveEntry createEntry(String name, Owner owner, byte linkFlag, int mode, int size)',
#   'code_tokens': ['private',
#    'TarArchiveEntry',
#    'createEntry',
#    '(',
#    'String',
#    'name',
#    ',',
#    'Owner',
#    'owner',
#    ',',
#    'byte',
#    'linkFlag',
#    ',',
#    'int',
#    'mode',
#    ',',
#    'int',
#    'size',
#    ')',
#    '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/main/java/org/springframework/boot/buildpack/platform/io/TarLayoutWriter.java',
#   'name': 'finish',
#   'start_line': 77,
#   'end_line': 81,
#   'signature': 'void finish()',
#   'code_tokens': ['void', 'finish', '(', ')', '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/main/java/org/springframework/boot/buildpack/platform/io/TarLayoutWriter.java',
#   'name': 'close',
#   'start_line': 82,
#   'end_line': 86,
#   'signature': 'public void close()',
#   'code_tokens': ['public', 'void', 'close', '(', ')', '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/main/java/org/springframework/boot/buildpack/platform/io/Owner.java',
#   'name': 'getUid',
#   'start_line': 36,
#   'end_line': 41,
#   'signature': 'long getUid()',
#   'code_tokens': ['long', 'getUid', '(', ')', '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/main/java/org/springframework/boot/buildpack/platform/io/Owner.java',
#   'name': 'getGid',
#   'start_line': 42,
#   'end_line': 49,
#   'signature': 'long getGid()',
#   'code_tokens': ['long', 'getGid', '(', ')', '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/main/java/org/springframework/boot/buildpack/platform/io/Owner.java',
#   'name': 'of',
#   'start_line': 50,
#   'end_line': 54,
#   'signature': 'static Owner of(long uid, long gid)',
#   'code_tokens': ['static',
#    'Owner',
#    'of',
#    '(',
#    'long',
#    'uid',
#    ',',
#    'long',
#    'gid',
#    ')',
#    '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/main/java/org/springframework/boot/buildpack/platform/io/FilePermissions.java',
#   'name': 'umaskForPath',
#   'start_line': 47,
#   'end_line': 60,
#   'signature': 'public static int umaskForPath(Path path)',
#   'code_tokens': ['public',
#    'static',
#    'int',
#    'umaskForPath',
#    '(',
#    'Path',
#    'path',
#    ')',
#    '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/main/java/org/springframework/boot/buildpack/platform/io/FilePermissions.java',
#   'name': 'posixPermissionsToUmask',
#   'start_line': 61,
#   'end_line': 71,
#   'signature': 'public static int posixPermissionsToUmask(Collection<PosixFilePermission> permissions)',
#   'code_tokens': ['public',
#    'static',
#    'int',
#    'posixPermissionsToUmask',
#    '(',
#    'Collection',
#    '<',
#    'PosixFilePermission',
#    '>',
#    'permissions',
#    ')',
#    '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/main/java/org/springframework/boot/buildpack/platform/io/FilePermissions.java',
#   'name': 'permissionToUmask',
#   'start_line': 72,
#   'end_line': 87,
#   'signature': 'private static int permissionToUmask(Collection<PosixFilePermission> permissions, PosixFilePermission execute, PosixFilePermission write, PosixFilePermission read)',
#   'code_tokens': ['private',
#    'static',
#    'int',
#    'permissionToUmask',
#    '(',
#    'Collection',
#    '<',
#    'PosixFilePermission',
#    '>',
#    'permissions',
#    ',',
#    'PosixFilePermission',
#    'execute',
#    ',',
#    'PosixFilePermission',
#    'write',
#    ',',
#    'PosixFilePermission',
#    'read',
#    ')',
#    '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/main/java/org/springframework/boot/buildpack/platform/io/IOSupplier.java',
#   'name': 'get',
#   'start_line': 36,
#   'end_line': 38,
#   'signature': 'T get()',
#   'code_tokens': ['T', 'get', '(', ')', '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/main/java/org/springframework/boot/buildpack/platform/io/DefaultOwner.java',
#   'name': 'getUid',
#   'start_line': 37,
#   'end_line': 41,
#   'signature': 'public long getUid()',
#   'code_tokens': ['public', 'long', 'getUid', '(', ')', '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/main/java/org/springframework/boot/buildpack/platform/io/DefaultOwner.java',
#   'name': 'getGid',
#   'start_line': 42,
#   'end_line': 46,
#   'signature': 'public long getGid()',
#   'code_tokens': ['public', 'long', 'getGid', '(', ')', '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/main/java/org/springframework/boot/buildpack/platform/io/DefaultOwner.java',
#   'name': 'toString',
#   'start_line': 47,
#   'end_line': 51,
#   'signature': 'public String toString()',
#   'code_tokens': ['public', 'String', 'toString', '(', ')', '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/main/java/org/springframework/boot/buildpack/platform/io/IOBiConsumer.java',
#   'name': 'accept',
#   'start_line': 38,
#   'end_line': 40,
#   'signature': 'void accept(T t, U u)',
#   'code_tokens': ['void', 'accept', '(', 'T', 't', ',', 'U', 'u', ')', '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/main/java/org/springframework/boot/buildpack/platform/io/Content.java',
#   'name': 'size',
#   'start_line': 42,
#   'end_line': 48,
#   'signature': 'int size()',
#   'code_tokens': ['int', 'size', '(', ')', '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/main/java/org/springframework/boot/buildpack/platform/io/Content.java',
#   'name': 'writeTo',
#   'start_line': 49,
#   'end_line': 55,
#   'signature': 'void writeTo(OutputStream outputStream)',
#   'code_tokens': ['void',
#    'writeTo',
#    '(',
#    'OutputStream',
#    'outputStream',
#    ')',
#    '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/main/java/org/springframework/boot/buildpack/platform/io/Content.java',
#   'name': 'of',
#   'start_line': 56,
#   'end_line': 65,
#   'signature': 'static Content of(String string)',
#   'code_tokens': ['static',
#    'Content',
#    'of',
#    '(',
#    'String',
#    'string',
#    ')',
#    '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/main/java/org/springframework/boot/buildpack/platform/io/Content.java',
#   'name': 'of',
#   'start_line': 66,
#   'end_line': 75,
#   'signature': 'static Content of(byte[] bytes)',
#   'code_tokens': ['static',
#    'Content',
#    'of',
#    '(',
#    'byte',
#    '[',
#    ']',
#    'bytes',
#    ')',
#    '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/main/java/org/springframework/boot/buildpack/platform/io/Content.java',
#   'name': 'of',
#   'start_line': 76,
#   'end_line': 87,
#   'signature': 'static Content of(File file)',
#   'code_tokens': ['static', 'Content', 'of', '(', 'File', 'file', ')', '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/main/java/org/springframework/boot/buildpack/platform/io/Content.java',
#   'name': 'of',
#   'start_line': 88,
#   'end_line': 93,
#   'signature': 'static Content of(int size, IOSupplier<InputStream> supplier)',
#   'code_tokens': ['static',
#    'Content',
#    'of',
#    '(',
#    'int',
#    'size',
#    ',',
#    'IOSupplier',
#    '<',
#    'InputStream',
#    '>',
#    'supplier',
#    ')',
#    '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/main/java/org/springframework/boot/buildpack/platform/io/Content.java',
#   'name': 'size',
#   'start_line': 94,
#   'end_line': 98,
#   'signature': 'public int size()',
#   'code_tokens': ['public', 'int', 'size', '(', ')', '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/main/java/org/springframework/boot/buildpack/platform/io/Content.java',
#   'name': 'writeTo',
#   'start_line': 99,
#   'end_line': 106,
#   'signature': 'public void writeTo(OutputStream outputStream)',
#   'code_tokens': ['public',
#    'void',
#    'writeTo',
#    '(',
#    'OutputStream',
#    'outputStream',
#    ')',
#    '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/main/java/org/springframework/boot/buildpack/platform/system/Environment.java',
#   'name': 'get',
#   'start_line': 43,
#   'end_line': 45,
#   'signature': 'String get(String name)',
#   'code_tokens': ['String', 'get', '(', 'String', 'name', ')', '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/main/java/org/springframework/boot/buildpack/platform/json/SharedObjectMapper.java',
#   'name': 'get',
#   'start_line': 48,
#   'end_line': 52,
#   'signature': 'public static ObjectMapper get()',
#   'code_tokens': ['public', 'static', 'ObjectMapper', 'get', '(', ')', '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/main/java/org/springframework/boot/buildpack/platform/build/Phase.java',
#   'name': 'withApp',
#   'start_line': 67,
#   'end_line': 72,
#   'signature': 'void withApp(String path, Binding binding)',
#   'code_tokens': ['void',
#    'withApp',
#    '(',
#    'String',
#    'path',
#    ',',
#    'Binding',
#    'binding',
#    ')',
#    '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/main/java/org/springframework/boot/buildpack/platform/build/Phase.java',
#   'name': 'withBuildCache',
#   'start_line': 73,
#   'end_line': 80,
#   'signature': 'void withBuildCache(String path, Binding binding)',
#   'code_tokens': ['void',
#    'withBuildCache',
#    '(',
#    'String',
#    'path',
#    ',',
#    'Binding',
#    'binding',
#    ')',
#    '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/main/java/org/springframework/boot/buildpack/platform/build/Phase.java',
#   'name': 'withDaemonAccess',
#   'start_line': 81,
#   'end_line': 85,
#   'signature': 'void withDaemonAccess()',
#   'code_tokens': ['void', 'withDaemonAccess', '(', ')', '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/main/java/org/springframework/boot/buildpack/platform/build/Phase.java',
#   'name': 'withImageName',
#   'start_line': 86,
#   'end_line': 89,
#   'signature': 'void withImageName(ImageReference imageName)',
#   'code_tokens': ['void',
#    'withImageName',
#    '(',
#    'ImageReference',
#    'imageName',
#    ')',
#    '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/main/java/org/springframework/boot/buildpack/platform/build/Phase.java',
#   'name': 'withLaunchCache',
#   'start_line': 90,
#   'end_line': 94,
#   'signature': 'void withLaunchCache(String path, Binding binding)',
#   'code_tokens': ['void',
#    'withLaunchCache',
#    '(',
#    'String',
#    'path',
#    ',',
#    'Binding',
#    'binding',
#    ')',
#    '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/main/java/org/springframework/boot/buildpack/platform/build/Phase.java',
#   'name': 'withLayers',
#   'start_line': 95,
#   'end_line': 99,
#   'signature': 'void withLayers(String path, Binding binding)',
#   'code_tokens': ['void',
#    'withLayers',
#    '(',
#    'String',
#    'path',
#    ',',
#    'Binding',
#    'binding',
#    ')',
#    '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/main/java/org/springframework/boot/buildpack/platform/build/Phase.java',
#   'name': 'withPlatform',
#   'start_line': 100,
#   'end_line': 103,
#   'signature': 'void withPlatform(String path)',
#   'code_tokens': ['void', 'withPlatform', '(', 'String', 'path', ')', '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/main/java/org/springframework/boot/buildpack/platform/build/Phase.java',
#   'name': 'withProcessType',
#   'start_line': 104,
#   'end_line': 107,
#   'signature': 'void withProcessType(String type)',
#   'code_tokens': ['void', 'withProcessType', '(', 'String', 'type', ')', '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/main/java/org/springframework/boot/buildpack/platform/build/Phase.java',
#   'name': 'withRunImage',
#   'start_line': 108,
#   'end_line': 111,
#   'signature': 'void withRunImage(ImageReference runImage)',
#   'code_tokens': ['void',
#    'withRunImage',
#    '(',
#    'ImageReference',
#    'runImage',
#    ')',
#    '{']},
#  {'file': 'spring-boot/buildpack/spring-boot-buildpack-platform/src/main/java/org/springframework/boot/buildpack/platform/build/Phase.java',
#   'name': 'withSkipRestore',
#   'start_line': 112,
#   'end_line': 120,
#   'signature': 'void withSkipRestore()',
#   'code_tokens': ['void', 'withSkipRestore', '(', ')', '{']},
#  ...]

# %%
import csv, random, json

out_file = "methods.csv"
# shuffle methods so random
random.shuffle(methods)
# first 25k = train, reamining = test
train_cutoff = 25000
for i, m in enumerate(methods):
    m["dataset_split"] = "train" if i < train_cutoff else "test"

fieldnames = ["file", "name", "start_line", "end_line", "signature", "code_tokens", "dataset_split"]

with open(out_file, "w", newline="", encoding="utf-8") as f:
    writer = csv.DictWriter(f, fieldnames=fieldnames)
    writer.writeheader()
    for m in methods:
        row = m.copy()
        row["code_tokens"] = json.dumps(m["code_tokens"])
        writer.writerow(row)

# %%
import pandas as pd
df = pd.read_csv('methods.csv')

# %%
df
# Out:
#                                                     file  \
# 0      spring-boot/smoke-test/spring-boot-smoke-test-...
# 1      spring-boot/buildpack/spring-boot-buildpack-pl...
# 2      spring-boot/smoke-test/spring-boot-smoke-test-...
# 3      spring-boot/documentation/spring-boot-docs/src...
# 4      spring-boot/module/spring-boot-security/src/ma...
# ...                                                  ...
# 34298  spring-boot/documentation/spring-boot-docs/src...
# 34299  spring-boot/core/spring-boot-autoconfigure/src...
# 34300  spring-boot/module/spring-boot-servlet/src/tes...
# 34301  spring-boot/module/spring-boot-actuator-autoco...
# 34302  spring-boot/loader/spring-boot-loader-classic/...
#
#                                                     name  start_line  \
# 0                                              configure          52
# 1                   loadJsonFromDistributionManifestList          33
# 2                                          testLegacyDot         165
# 3                                                setHost          41
# 4                                          healthMatcher          78
# ...                                                  ...         ...
# 34298                                   setCheckLocation          41
# 34299                                   expressionIsTrue          45
# 34300                                  dispatcherServlet         251
# 34301  runWhenEnabledPropertyIsFalseShouldNotHaveEndp...          60
# 34302                      inputStreamSkipPastSubsection         265
#
#        end_line                                          signature  \
# 0            56  protected SpringApplicationBuilder configure(S...
# 1            40        void loadJsonFromDistributionManifestList()
# 2           172                               void testLegacyDot()
# 3            52                     public void setHost(Host host)
# 4            81   private ServerWebExchangeMatcher healthMatcher()
# ...         ...                                                ...
# 34298        44  public void setCheckLocation(boolean checkLoca...
# 34299        50                            void expressionIsTrue()
# 34300       260              DispatcherServlet dispatcherServlet()
# 34301        65  void runWhenEnabledPropertyIsFalseShouldNotHav...
# 34302       272               void inputStreamSkipPastSubsection()
#
#                                              code_tokens dataset_split
# 0      ["protected", "SpringApplicationBuilder", "con...         train
# 1      ["void", "loadJsonFromDistributionManifestList...         train
# 2               ["void", "testLegacyDot", "(", ")", "{"]         train
# 3      ["public", "void", "setHost", "(", "Host", "ho...         train
# 4      ["private", "ServerWebExchangeMatcher", "healt...         train
# ...                                                  ...           ...
# 34298  ["public", "void", "setCheckLocation", "(", "b...          test
# 34299        ["void", "expressionIsTrue", "(", ")", "{"]          test
# 34300  ["DispatcherServlet", "dispatcherServlet", "("...          test
# 34301  ["void", "runWhenEnabledPropertyIsFalseShouldN...          test
# 34302  ["void", "inputStreamSkipPastSubsection", "(",...          test
#
# [34303 rows x 7 columns]
